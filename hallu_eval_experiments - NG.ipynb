# %% [markdown]
# ## Connect to your Google Drive or any filesystem you are going to use.

# %%
"""
import sys
from pathlib import Path

IN_COLAB = "google.colab" in sys.modules
if IN_COLAB:
    from google.colab import drive

    drive.mount("/content/gdrive")
base_path = (
    Path("your_path") if IN_COLAB else Path(".")
)

#Fix if you want to use a different path
output_path = base_path / "output"
data_path = base_path / "HaluEval"
output_path.mkdir(exist_ok=True)
"""
# Out:
# '\nimport sys\nfrom pathlib import Path\n\nIN_COLAB = "google.colab" in sys.modules\nif IN_COLAB:\n    from google.colab import drive\n\n    drive.mount("/content/gdrive")\nbase_path = (\n    Path("your_path") if IN_COLAB else Path(".")\n)\n\n#Fix if you want to use a different path\noutput_path = base_path / "output"\ndata_path = base_path / "HaluEval"\noutput_path.mkdir(exist_ok=True)\n'

# %% [markdown]
# ## These are the libraries needed to run this notebook

# %% [markdown]
# ## Deep Learning Installations

# %%
# %pip install transformers datasets evaluate rouge_score
# %pip install --upgrade huggingface_hub
"""
# %pip install accelerate -U
# %pip install transformers[torch]
# %pip install sentencepiece
# %pip install google
# %pip install protobuf
"""
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.9.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: evaluate in /usr/local/lib/python3.12/dist-packages (0.4.6)
# Requirement already satisfied: rouge_score in /usr/local/lib/python3.12/dist-packages (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (1.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers) (0.25.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets) (3.29.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.7.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (from rouge_score) (3.9.1)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from rouge_score) (1.17.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.14.0)
# Requirement already satisfied: click>=8.4.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (8.4.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.5.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2026.5.20)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk->rouge_score) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2026.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.24.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers) (0.1.2)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (1.18.0)
# Requirement already satisfied: click>=8.4.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (1.5.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.67.3)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (0.25.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub) (0.16.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface_hub) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface_hub) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface_hub) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface_hub) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface_hub) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface_hub) (0.1.2)
# '\n%pip install accelerate -U\n%pip install transformers[torch]\n%pip install sentencepiece\n%pip install google\n%pip install protobuf\n'

# %% [markdown]
# ## Libraries

# %%
from datasets import load_dataset
from datasets import Dataset
from transformers import AutoTokenizer
from transformers import DataCollatorForSeq2Seq
from transformers import pipeline
from transformers import AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer
from transformers import AutoTokenizer
from transformers import AutoModelForSeq2SeqLM
import numpy as np
import pandas as pd
import evaluate
import random
import json
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading Dataset
#
# `The method loadDataset receieves the path where the datasets json files of the HaluEval repository are. You just need to pass your path and the name of the dataset you are going to use.`
#
# ## Dataset Names:
# - summarization
# - dialogue
# - qa
# - general

# %%
## As a recomendation keep these two with the same naming if you do not want to change many things
datasetName = "general"
task = datasetName

# %%
import requests

base_url = "https://raw.githubusercontent.com/RUCAIBox/HaluEval-2.0/master/annotation/human_annotation/"


bio_medical = requests.get(base_url + "Bio-Medical.json").json()
education = requests.get(base_url + "Education.json").json()
finance = requests.get(base_url + "Finance.json").json()
open_domain = requests.get(base_url + "Open-Domain.json").json()
science = requests.get(base_url + "Science.json").json()

# %%
"""
def loadDataset(datasetName, path=data_path):
    file_path = path / f"{datasetName}.json"
    return pd.read_json(file_path) #, lines=True)
"""
# Out:
# '\ndef loadDataset(datasetName, path=data_path):\n    file_path = path / f"{datasetName}.json"\n    return pd.read_json(file_path) #, lines=True)\n'

# %%
"""
bio_medical = loadDataset(datasetName="Bio-Medical")
education = loadDataset(datasetName="Education")
finance = loadDataset(datasetName="Finance")
open_domain = loadDataset(datasetName="Open-Domain")
science = loadDataset(datasetName="Science")
"""
# Out:
# '\nbio_medical = loadDataset(datasetName="Bio-Medical")\neducation = loadDataset(datasetName="Education")\nfinance = loadDataset(datasetName="Finance")\nopen_domain = loadDataset(datasetName="Open-Domain")\nscience = loadDataset(datasetName="Science")\n'

# %% [markdown]
# ### Saving the above file with combined domains

# %%
def process_and_save(datasets_dict):

    # 1. Add domain column
    for name, df in datasets_dict.items():
        df["domain"] = name

    # 2. Merge all datasets
    data = pd.concat(datasets_dict.values(), ignore_index=True)

    # 3. Create hallucination label
    def get_label(judges):
        if not isinstance(judges, list) or len(judges) == 0:
            return "unknown"
        judges = [str(j).strip().lower() for j in judges]
        return "yes" if "false" in judges else "no"

    data["hallucination_label"] = data["human_judge"].apply(get_label)

    # 4. Keep only required columns
    data = data[[
        "id",
        "user_query",
        "chatgpt_response",
        "hallucination_label",
        "domain"
    ]]

    # 5. Shuffle
    data = data.sample(frac=1).reset_index(drop=True)

    return data

# %%
import pandas as pd

datasets = {
    "education": pd.DataFrame(education),
    "bio_medical": pd.DataFrame(bio_medical),
    "finance": pd.DataFrame(finance),
    "open_domain": pd.DataFrame(open_domain),
    "science": pd.DataFrame(science)
}

data = process_and_save(datasets)

# %%
data.head()
# Out:
#      id                                         user_query  \
# 0   804  when sally ride 's space craft finally launche...
# 1  3205      Does RUNX2 inhibit astrocyte differentiation?
# 2   455  if there are fish in every tank , and each tan...
# 3   873  Can you clarify whether the claim "Deficiency ...
# 4  3763  Describe efforts on Sarcoma from the 100,000 G...
#
#                                     chatgpt_response hallucination_label  \
# 0  According to Sally Ride, when her space craft ...                 yes
# 1  No, RUNX2 does not inhibit astrocyte different...                 yes
# 2  To determine which statement cannot be true, w...                 yes
# 3  The claim "Deficiency of Tetraspanin-3 causes ...                 yes
# 4  The 100,000 Genomes Project was a pioneering i...                 yes
#
#         domain
# 0    education
# 1  bio_medical
# 2    education
# 3      science
# 4  bio_medical

# %% [markdown]
# ## For this particular example we are loading the general_data.json since is the one that takes the less time to process in case you want to test quickly how it works.

# %% [markdown]
# ### Data Statistics

# %%
len(data)
# Out:
# 1000

# %%
# Get the counts of each unique value in 'domain'
domain_counts = data['domain'].value_counts()
domain_percent = domain_counts/len(data) * 100

print(domain_counts)
print(domain_percent)


domain_counts = data['domain'].value_counts()


plt.figure(figsize=(4, 4))
plt.pie(domain_counts, labels=domain_counts.index, autopct='%1.f%%', startangle=140, colors= plt.cm.Paired.colors)
plt.title('Distribution of Domains')
plt.axis('equal') # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# domain
# education      200
# bio_medical    200
# science        200
# open_domain    200
# finance        200
# Name: count, dtype: int64
# domain
# education      20.0
# bio_medical    20.0
# science        20.0
# open_domain    20.0
# finance        20.0
# Name: count, dtype: float64

# %%
# Get the counts of each unique value in 'hallucination_label'
hallucination_counts = data['hallucination_label'].value_counts()
hallucination_percent = hallucination_counts/len(data) * 100

print(hallucination_counts)
print(hallucination_percent)

# Create a bar chart
plt.figure(figsize=(8, 6))
sns.barplot(x=hallucination_percent.index, y=hallucination_percent.values, hue=hallucination_counts.index, palette='pastel', legend=False)
plt.title('Distribution of Hallucination Labels')
plt.xlabel('Hallucination Label')
plt.ylabel('Count')
plt.show()
# Out:
# hallucination_label
# yes        896
# no          80
# unknown     24
# Name: count, dtype: int64
# hallucination_label
# yes        89.6
# no          8.0
# unknown     2.4
# Name: count, dtype: float64

# %% [markdown]
# ### Hallucination Labels by Domain

# %%
hallucination_by_domain = data.groupby('domain')['hallucination_label'].value_counts().unstack(fill_value=0)
display(hallucination_by_domain)
# Out:
# hallucination_label  no  unknown  yes
# domain
# bio_medical           5        9  186
# education            17        3  180
# finance              46        1  153
# open_domain           5       10  185
# science               7        1  192

# %%
hallucination_by_domain.plot(kind='bar', figsize=(12, 7))
plt.title('Hallucination Labels Counts Across Domains')
plt.xlabel('Domain')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Hallucination Label')
plt.tight_layout()
plt.show()

# %%
data = data[data['hallucination_label'] != 'unknown']

# Display the new counts to verify the removal
print(data['hallucination_label'].value_counts())
# Out:
# hallucination_label
# yes    896
# no      80
# Name: count, dtype: int64

# %%
hallucination_by_domain = data.groupby('domain')['hallucination_label'].value_counts().unstack(fill_value=0)
display(hallucination_by_domain)
# Out:
# hallucination_label  no  yes
# domain
# bio_medical           5  186
# education            17  180
# finance              46  153
# open_domain           5  185
# science               7  192

# %%
data.head()
# Out:
#      id                                         user_query  \
# 0   804  when sally ride 's space craft finally launche...
# 1  3205      Does RUNX2 inhibit astrocyte differentiation?
# 2   455  if there are fish in every tank , and each tan...
# 3   873  Can you clarify whether the claim "Deficiency ...
# 4  3763  Describe efforts on Sarcoma from the 100,000 G...
#
#                                     chatgpt_response hallucination_label  \
# 0  According to Sally Ride, when her space craft ...                 yes
# 1  No, RUNX2 does not inhibit astrocyte different...                 yes
# 2  To determine which statement cannot be true, w...                 yes
# 3  The claim "Deficiency of Tetraspanin-3 causes ...                 yes
# 4  The 100,000 Genomes Project was a pioneering i...                 yes
#
#         domain
# 0    education
# 1  bio_medical
# 2    education
# 3      science
# 4  bio_medical

# %% [markdown]
# ### Token Size of Chat gpt response

# %%
data['chatgpt_response_length'] = data['chatgpt_response'].str.split().apply(len)
#display(data.head())

average_response_length_by_domain = data.groupby('domain')['chatgpt_response_length'].mean().sort_values(ascending=False)
display(average_response_length_by_domain)
# Out:
# domain
# science        280.120603
# finance        187.763819
# bio_medical    125.052356
# education      100.771574
# open_domain     19.073684
# Name: chatgpt_response_length, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=average_response_length_by_domain.index, y=average_response_length_by_domain.values, palette='viridis')
plt.title('Average ChatGPT Response Length by Domain')
plt.xlabel('Domain')
plt.ylabel('Average Response Length')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_36380/2527565532.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=average_response_length_by_domain.index, y=average_response_length_by_domain.values, palette='viridis')

# %% [markdown]
# # Balancing the classes from dataset

# %%
data = data[data["hallucination_label"] != "unknown"]

df_yes = data[data["hallucination_label"] == "yes"]
df_no  = data[data["hallucination_label"] == "no"]

n = len(df_no)

data = pd.concat([
    df_yes.sample(n=n, random_state=42),
    df_no
]).sample(frac=1, random_state=42)  # shuffle

# %%
data.head()
# Out:
#        id                                         user_query  \
# 320   852  How does a lender compute equity requirement f...
# 367  3026  looking at the periodic table , which of the 3...
# 777  1761  Why do employers require you to spread your 40...
# 675  3691  Which drug is the first oral ghrelin receptor ...
# 198   900  how old was ronald mcnair when he tried to che...
#
#                                       chatgpt_response hallucination_label  \
# 320  A lender computes the equity requirement for P...                  no
# 367  The most abundant isotope of tantalum in natur...                  no
# 777  Employers often require employees to spread th...                  no
# 675  The first oral ghrelin receptor inverse agonis...                 yes
# 198  Ronald McNair was merely 9 years old when he a...                  no
#
#           domain  chatgpt_response_length
# 320      finance                      206
# 367    education                       11
# 777      finance                      283
# 675  bio_medical                       39
# 198    education                       17

# %%
len(data)
# Out:
# 160

# %%
# Get the counts of each unique value in 'hallucination_label'
hallucination_counts = data['hallucination_label'].value_counts()
hallucination_percent = hallucination_counts/len(data) * 100

print(hallucination_counts)
print(hallucination_percent)

# Create a bar chart
plt.figure(figsize=(8, 6))
sns.barplot(x=hallucination_percent.index, y=hallucination_percent.values, hue=hallucination_counts.index, palette='pastel', legend=False)
plt.title('Distribution of Hallucination Labels')
plt.xlabel('Hallucination Label')
plt.ylabel('Count')
plt.show()
# Out:
# hallucination_label
# no     80
# yes    80
# Name: count, dtype: int64
# hallucination_label
# no     50.0
# yes    50.0
# Name: count, dtype: float64

# %%
# Get the counts of each unique value in 'domain'
domain_counts = data['domain'].value_counts()
domain_percent = domain_counts/len(data) * 100

print(domain_counts)
print(domain_percent)


domain_counts = data['domain'].value_counts()


plt.figure(figsize=(4, 4))
plt.pie(domain_counts, labels=domain_counts.index, autopct='%1.f%%', startangle=140, colors= plt.cm.Paired.colors)
plt.title('Distribution of Domains')
plt.axis('equal') # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# domain
# finance        57
# education      30
# science        27
# open_domain    24
# bio_medical    22
# Name: count, dtype: int64
# domain
# finance        35.625
# education      18.750
# science        16.875
# open_domain    15.000
# bio_medical    13.750
# Name: count, dtype: float64

# %%
data['chatgpt_response_length'] = data['chatgpt_response'].str.split().apply(len)
#display(data.head())

average_response_length_by_domain = data.groupby('domain')['chatgpt_response_length'].mean().sort_values(ascending=False)
display(average_response_length_by_domain)
# Out:
# domain
# science        288.851852
# finance        211.666667
# bio_medical    103.818182
# education       37.433333
# open_domain     16.750000
# Name: chatgpt_response_length, dtype: float64

# %% [markdown]
# # Setting Device to use the GPU
#
# We use the T4 GPU in Colab since the heaviest computation for us is the inference of the LLM-Evaluator. Therefore, T4 seem as the better fit.

# %%
import torch

print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# ## Generic LLMModel class to reuse the functionality of extracting the features.

# %%
from transformers import BartForConditionalGeneration, BartTokenizer
from transformers import T5Tokenizer, T5ForConditionalGeneration
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from transformers import BartForConditionalGeneration, PegasusForConditionalGeneration
from transformers import LEDForConditionalGeneration, LEDTokenizer
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from transformers import GPT2LMHeadModel, GPT2Tokenizer
from transformers import LlamaForCausalLM, LlamaTokenizer

import torch
import torch.nn.functional as F


class LLMModel:
    def __init__(self):
        self.model = self.model.to(device)
        pass

    def getName(self) -> str:
        return self.model_name

    def getSanitizedName(self) -> str:
        return self.model_name.replace("/", "__")

    def generate(self, inpt):
        pass

    # Move in future commits this method to an utils.py
    def truncate_string_by_len(self, s, truncate_len):
        words = s.split()
        truncated_words = words[:-truncate_len] if truncate_len > 0 else words
        return " ".join(truncated_words)

    # Method to get the vocabulary probabilities of the LLM for a given token on the generated text from LLM-Generator
    def getVocabProbsAtPos(self, pos, token_probs):
        sorted_probs, sorted_indices = torch.sort(token_probs[pos, :], descending=True)
        return sorted_probs

    def getMaxLength(self):
        return self.model.config.max_position_embeddings

    # By default knowledge is the empty string. If you want to add extra knowledge you can do it like in the cases of the qa_data.json and dialogue_data.json
    def extractFeatures(
        self,
        knowledge="",
        conditionted_text="",
        generated_text="",
        features_to_extract={},
    ):
        self.model.eval()

        total_len = len(knowledge) + len(conditionted_text) + len(generated_text)
        truncate_len = min(total_len - self.tokenizer.model_max_length, 0)

        # Truncate knowledge in case is too large
        knowledge = self.truncate_string_by_len(knowledge, truncate_len // 2)
        # Truncate text_A in case is too large
        conditionted_text = self.truncate_string_by_len(
            conditionted_text, truncate_len - (truncate_len // 2)
        )

        inputs = self.tokenizer(
            [knowledge + conditionted_text + generated_text],
            return_tensors="pt",
            max_length=self.getMaxLength(),
            truncation=True,
        )

        for key in inputs:
            inputs[key] = inputs[key].to(device)

        with torch.no_grad():
            outputs = self.model(**inputs)
            logits = outputs.logits

        probs = F.softmax(logits, dim=-1)
        probs = probs.to(device)

        tokens_generated_length = len(self.tokenizer.tokenize(generated_text))
        start_index = logits.shape[1] - tokens_generated_length
        conditional_probs = probs[0, start_index :]

        token_ids_generated = inputs["input_ids"][0, start_index :].tolist()
        token_probs_generated = [
            conditional_probs[i, tid].item()
            for i, tid in enumerate(token_ids_generated)
        ]

        tokens_generated = self.tokenizer.convert_ids_to_tokens(token_ids_generated)

        minimum_token_prob = min(token_probs_generated)
        average_token_prob = sum(token_probs_generated) / len(token_probs_generated)

        maximum_diff_with_vocab = -1
        minimum_vocab_extreme_diff = 100000000000

        if features_to_extract["MDVTP"] == True or features_to_extract["MMDVP"] == True:
            size = len(token_probs_generated)
            for pos in range(size):
                vocabProbs = self.getVocabProbsAtPos(pos, conditional_probs)
                maximum_diff_with_vocab = max(
                    [
                        maximum_diff_with_vocab,
                        self.getDiffVocab(vocabProbs, token_probs_generated[pos]),
                    ]
                )
                minimum_vocab_extreme_diff = min(
                    [
                        minimum_vocab_extreme_diff,
                        self.getDiffMaximumWithMinimum(vocabProbs),
                    ]
                )

        # allFeatures = [minimum_token_prob, average_token_prob, maximum_diff_with_vocab, minimum_vocab_extreme_diff]

        allFeatures = {
            "mtp": minimum_token_prob,
            "avgtp": average_token_prob,
            "MDVTP": maximum_diff_with_vocab,
            "MMDVP": minimum_vocab_extreme_diff,
        }

        selectedFeatures = {}
        for key, feature in features_to_extract.items():
            if feature == True:
                selectedFeatures[key] = allFeatures[key]

        return selectedFeatures

    def getDiffVocab(self, vocabProbs, tprob):
        return (vocabProbs[0] - tprob).item()

    def getDiffMaximumWithMinimum(self, vocabProbs):
        return (vocabProbs[0] - vocabProbs[-1]).item()

# %% [markdown]
# ## Definition of the specific Models

# %%
class Gemma(LLMModel):
    def __init__(self):
        self.model_name = "google/gemma-7b-it"
        self.model = AutoModelForCausalLM.from_pretrained(
            self.model_name
        )
        self.tokenizer = AutoTokenizer.from_pretrained(self.model_name)
        super().__init__()


    def generate(self, inpt):
        inputs = self.tokenizer(
            [inpt], max_length=self.getMaxLength(), return_tensors="pt", truncation=True
        )
        summary_ids = self.model.generate(inputs["input_ids"])

        summary = self.tokenizer.decode(summary_ids[0], skip_special_tokens=True)

        return summary


class LLama(LLMModel):
    def __init__(self):
        self.model_name = "meta-llama/Llama-2-7b-chat-hf"
        self.model = AutoModelForCausalLM.from_pretrained(
            self.model_name,
        )
        self.tokenizer = AutoTokenizer.from_pretrained(self.model_name)
        super().__init__()


    def generate(self, inpt):
        inputs = self.tokenizer(
            [inpt], max_length=1024, return_tensors="pt", truncation=True
        )
        summary_ids = self.model.generate(inputs["input_ids"])

        summary = self.tokenizer.decode(summary_ids[0], skip_special_tokens=True)

        return summary


class Opt(LLMModel):
    def __init__(self):
        self.model_name = "facebook/opt-6.7b"
        self.model = AutoModelForCausalLM.from_pretrained(self.model_name)
        self.tokenizer = AutoTokenizer.from_pretrained(self.model_name)
        super().__init__()


    def generate(self, inpt):
        inputs = self.tokenizer(
            [inpt], max_length=self.getMaxLength(), return_tensors="pt", truncation=True
        )
        summary_ids = self.model.generate(inputs["input_ids"])

        summary = self.tokenizer.decode(summary_ids[0], skip_special_tokens=True)

        return summary


class Gptj(LLMModel):
    def __init__(self):
        self.model_name = "EleutherAI/gpt-j-6B"
        self.model = AutoModelForCausalLM.from_pretrained(self.model_name)
        self.tokenizer = AutoTokenizer.from_pretrained(self.model_name)
        super().__init__()


    def generate(self, inpt):
        inputs = self.tokenizer(
            [inpt], max_length=self.getMaxLength(), return_tensors="pt", truncation=True
        )
        summary_ids = self.model.generate(inputs["input_ids"])

        summary = self.tokenizer.decode(summary_ids[0], skip_special_tokens=True)

        return summary


class BartCNN(LLMModel):
    def __init__(self):
        self.model_name = "facebook/bart-large-cnn"
        self.model = BartForConditionalGeneration.from_pretrained(self.model_name)
        self.tokenizer = BartTokenizer.from_pretrained(self.model_name)
        super().__init__()


    def generate(self, inpt):
        inputs = self.tokenizer(
            [inpt], max_length=self.getMaxLength(), return_tensors="pt", truncation=True
        )
        summary_ids = self.model.generate(inputs["input_ids"])

        summary = self.tokenizer.decode(summary_ids[0], skip_special_tokens=True)

        return summary

class GPT2Generator(LLMModel):
    def __init__(self):
        self.model_name = "gpt2-large"
        self.model = GPT2LMHeadModel.from_pretrained(self.model_name)
        self.tokenizer = GPT2Tokenizer.from_pretrained(self.model_name)
        super().__init__()

    def generate(self, inpt):
        inputs = self.tokenizer.encode(
            inpt, return_tensors="pt", max_length=self.getMaxLength(), truncation=True
        )
        output_ids = self.model.generate(
            inputs, max_length=1024, num_return_sequences=1
        )
        output = self.tokenizer.decode(output_ids[0], skip_special_tokens=True)
        return output


class LED(LLMModel):
    def __init__(self):
        self.model_name = "allenai/led-large-16384-arxiv"
        self.model = LEDForConditionalGeneration.from_pretrained(self.model_name)
        self.tokenizer = LEDTokenizer.from_pretrained(self.model_name)
        super().__init__()

    def generate(self, inpt):
        inputs = self.tokenizer(
            [inpt], max_length=self.getMaxLength(), return_tensors="pt", truncation=True
        )
        summary_ids = self.model.generate(inputs["input_ids"])

        summary = self.tokenizer.decode(summary_ids[0], skip_special_tokens=True)

        return summary

# %% [markdown]
# # The Dictionary `features_to_extract` defines which features will be use in this experiment.
#
# ## Features Meaning:
#
# - `mtp` : Take the minimum of the probabilities that the LLM_E gives to the tokens on the generated-text.
# - `avgtp` : Take the average of the probabilities that the LLM_E
# gives to the tokens on the generated-text.
# - `MDVTP` : Take the maximum from all the differences
# between the token with the highest probability
# according to LLM_E at position i and the
# assigned probability from LLM_E to the token at position i in the generated_text.
# - `MMDVP` : Take the maximum from all the differences between the token with the highest probability according to $LLM_E$ at position $i$ ($v^*$) and the token with the lowest probability according to $LLM_E$ at position $i$ ($v^-$).

# %%
feature_to_extract = 'all'

available_features_to_extract = ["mtp", "avgtp", "MDVTP", "MMDVP"]
if feature_to_extract == 'all':
    features_to_extract = {
        feature: True for feature in available_features_to_extract
    }
else:
    features_to_extract = {
        feature: True if feature == feature_to_extract else False
        for feature in available_features_to_extract
    }

features_to_extract
# Out:
# {'mtp': True, 'avgtp': True, 'MDVTP': True, 'MMDVP': True}

# %% [markdown]
# ## Cleaning Cache on GPU to save memory

# %%
import torch
import gc

gc.collect()
torch.cuda.empty_cache()

# %% [markdown]
# ## This cell is to instantiate the model you intend to use for the experiment

# %%
# model = BartCNN()
# model = LED()
model = GPT2Generator()
# model = LLama()
# model = Gemma()
# model = Opt()
# model = Gptj()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:112: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/436 [00:00<?, ?it/s]

# %% [markdown]
# ## This cell creates the dataset separation of `10%` for training and `90%` for testing depending on what task you are addressing. The following explanation is what happens if summarization is the task used. But the same explanation applies to all tasks and also you cand pass as parameter how many data points you want to include in training.
#
# ## Example: The data is separated on 2000 (1000 of document with right summary and 1000 with the same document but with the hallucinated summary). The rest which is 18000 is used to for testing.
#
# ### As expected from previous cells the task string expected are:
# - `summarization`
# - `qa`
# - `dialogue`
# - `general`

# %%
import random


# Load the data depending on the task
def loadRowData(taskName, row, includeKnowledge=False):
    if taskName == "summarization":
        return "", row["document"], row["right_summary"], row["hallucinated_summary"]
    elif taskName == "qa":
        if includeKnowledge:
            return (
                row["knowledge"],
                row["question"],
                row["right_answer"],
                row["hallucinated_answer"],
            )
        else:
            return "", row["question"], row["right_answer"], row["hallucinated_answer"]

    elif taskName == "dialogue":
        if includeKnowledge:
            return (
                row["knowledge"],
                row["dialogue_history"],
                row["right_response"],
                row["hallucinated_response"],
            )
        else:
            return (
                "",
                row["dialogue_history"],
                row["right_response"],
                row["hallucinated_response"],
            )

    elif taskName == "general":
        return (
            "",
            row["user_query"],
            row["chatgpt_response"],
            row["hallucination_label"],
        )

    else:
        raise Exception("Task not supported")


# Adapt the dataset to have a data point of conditioned-text with right-generation and another with the same conditioned-text and tha hallucinated answer.
def adaptDataset(data, taskName):
    datasetAdapted = None
    if taskName == "general":
        # There is data point that is filling the <mask> token but that gives error with some LLMs
        datasetAdapted = [
            (
                (knowledge, document, response, 1)
                if hallu == "yes"
                else (knowledge, document, response, 0)
            )
            for knowledge, document, response, hallu in data
            if "<mask>" not in document and "<mask>" not in response
        ]

    elif taskName == "summarization" or taskName == "qa" or taskName == "dialogue":
        datasetAdapted = [
            (knowledge, document, right, 1)
            for knowledge, document, right, hallu in data
        ] + [
            (knowledge, document, hallu, 0)
            for knowledge, document, right, hallu in data
        ]

    else:
        raise Exception("Task not supported")

    #random.shuffle(datasetAdapted)
    return datasetAdapted

# %%
def splitDataset(
    data: pd.DataFrame,
    taskName: str,
    trainingSize: int,
    valSize: int,
    includeKnowledge=False,
):

    dataset = []
    for _, row in data.iterrows():
        knowledge, text, right, hallu = loadRowData(taskName, row, includeKnowledge)
        dataset.append((knowledge, text, right, hallu))

    #random.shuffle(dataset)

    dataset_train = dataset[:trainingSize]  # Take only trainingSize
    dataset_val = (
        []
    )  # dataset[trainingSize:trainingSize + valSize] # Take only trainingSize
    dataset_test = dataset[trainingSize:]  # Take the rest as testing

    datasetAdaptedTrain = adaptDataset(dataset_train, taskName)
    datasetAdaptedValidation = adaptDataset(dataset_val, taskName)
    datasetAdaptedTest = adaptDataset(dataset_test, taskName)

    X_train = [(x, q, y) for x, q, y, _ in datasetAdaptedTrain]
    Y_train = [z for _, _, _, z in datasetAdaptedTrain]

    X_val = [(x, q, y) for x, q, y, _ in datasetAdaptedValidation]
    Y_val = [z for _, _, _, z in datasetAdaptedValidation]

    X_test = [(x, q, y) for x, q, y, _ in datasetAdaptedTest]
    Y_test = [z for _, _, _, z in datasetAdaptedTest]

    return X_train, Y_train, X_val, Y_val, X_test, Y_test

# %%
includeKnowledge = True
includeConditioned = True

# %%
"""
X_train, Y_train, X_val, Y_val, X_test, Y_test = splitDataset(
    data, task, 2, 0, includeKnowledge=includeKnowledge
)
"""
# Out:
# '\nX_train, Y_train, X_val, Y_val, X_test, Y_test = splitDataset(\n    data, task, 2, 0, includeKnowledge=includeKnowledge\n)\n'

# %%
from sklearn.model_selection import train_test_split

# for now no validation

train_df, test_df = train_test_split(
    data,
    test_size=0.2,  # 20% test
    stratify=data["hallucination_label"],  # VERY important
    random_state=42
)

# %%
def df_to_XY(df):
    X, Y = [], []
    for _, row in df.iterrows():
        X.append(("", row["user_query"], row["chatgpt_response"]))
        Y.append(1 if row["hallucination_label"] == "yes" else 0)
    return X, Y

X_train, Y_train = df_to_XY(train_df)
X_test, Y_test = df_to_XY(test_df)
#X_val, Y_val = df_to_XY(val_df)

X_val = []
Y_val = []

# %%
print(len(X_train), len(Y_train))
print(len(X_val), len(Y_val))
print(len(X_test), len(Y_test))  # verify the sizes look right
# Out:
# 128 128
# 0 0
# 32 32

# %% [markdown]
# ## To Save the separation if needed

# %%
train_df = pd.DataFrame(
    {
        "Knowledge": [x[0] for x in X_train],
        "Conditioned Text": [x[1] for x in X_train],
        "Generated Text": [x[2] for x in X_train],
        "Label": Y_train,
    }
)

val_df = pd.DataFrame(
    {
        "Knowledge": [x[0] for x in X_val],
        "Conditioned Text": [x[1] for x in X_val],
        "Generated Text": [x[2] for x in X_val],
        "Label": Y_val,
    }
)

test_df = pd.DataFrame(
    {
        "Knowledge": [x[0] for x in X_test],
        "Conditioned Text": [x[1] for x in X_test],
        "Generated Text": [x[2] for x in X_test],
        "Label": Y_test,
    }
)

#Export to CSV
if includeKnowledge:
    train_df.to_csv(output_path / (task + '_knowledge_train_data.csv'), index=False)
    test_df.to_csv(output_path / (task + '_knowledge_test_data.csv'), index=False)
else:
    train_df.to_csv(output_path / (task + '_train_data.csv'), index=False)
    val_df.to_csv(output_path / (task + '_val_data.csv'), index=False)
    test_df.to_csv(output_path / (task + '_test_data.csv'), index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_36380/614916898.py in <cell line: 0>()
#      28 #Export to CSV
#      29 if includeKnowledge:
# ---> 30     train_df.to_csv(output_path / (task + '_knowledge_train_data.csv'), index=False)
#      31     test_df.to_csv(output_path / (task + '_knowledge_test_data.csv'), index=False)
#      32 else:
#
# NameError: name 'output_path' is not defined

# %%
def getXY(df: pd.DataFrame, includeKnowledge=True, includeConditioned=True):
    X = []
    Y = []

    # Iterate over rows using itertuples
    for _, row in df.iterrows():
        x, c, g = (
            row["Knowledge"] if includeKnowledge else "",
            row["Conditioned Text"] if includeConditioned else "",
            row["Generated Text"],
        # g = (row["Generated Text"]
        )
        y = row["Label"]

        # Append values to respective lists
        X.append((x, c, g))
        # X.append(g)
        Y.append(y)
    return X, Y

# %%
X_train, Y_train = getXY(
    train_df, includeKnowledge=includeKnowledge, includeConditioned=includeConditioned
)
X_val, Y_val = getXY(
    val_df, includeKnowledge=includeKnowledge, includeConditioned=includeConditioned
)
X_test, Y_test = getXY(
    test_df, includeKnowledge=includeKnowledge, includeConditioned=includeConditioned
)

# %%
print(len(X_train), len(Y_train))
print(len(X_val), len(Y_val))
print(len(X_test), len(Y_test))  # verify the sizes look right
# Out:
# 128 128
# 0 0
# 32 32

# %%
X_test[0]
# Out:
# ('',
#  'How truthful is the statement that "Physical activity level is associated with the difference in maximal oxygen consumption between black and white youth."? Present a series of factual points about the statement.',
#  'To evaluate the truthfulness of the statement that "Physical activity level is associated with the difference in maximal oxygen consumption between black and white youth," we need to examine relevant scientific evidence and present a series of factual points:\n1. Research studies have consistently shown differences in maximal oxygen consumption (VO2max) between black and white individuals. VO2max is a measure of the body\'s ability to utilize oxygen during exercise, indicating cardiovascular fitness.\n2. Several studies have investigated the association between physical activity and VO2max levels in black and white youth separately. These studies generally acknowledge that physical activity influences cardiovascular fitness and therefore potentially affects VO2max.\n3. A 2010 systematic review published in the Journal of Clinical Epidemiology examined the impact of physical activity on VO2max across different ethnicities, including black and white individuals. The review found that physical activity was indeed associated with higher VO2max levels in both black and white youth.\n4. In the specific context of racial differences in VO2max, an analysis published in 2014 in the British Journal of Sports Medicine examined a large sample of black and white youth aged 7-13 years. The study observed that black youth had, on average, lower VO2max than white youth. However, the analysis did not directly establish a causal relationship between physical activity and these racial differences.\n5. A genetic component related to VO2max differences between racial groups has also been suggested. Some studies have shown that certain genetic variations may contribute to lower VO2max in black individuals compared to white individuals, regardless of physical activity levels.\n6. Acknowledging the importance of physical activity, it is worth noting that the influence of other factors, such as socioeconomic status, access to resources, and cultural influences on physical activity, may also contribute to differences in VO2max between black and white youth.\nIn summary, while physical activity is associated with higher VO2max levels in both black and white youth, the statement that physical activity level is associated with the difference in VO2max between black and white youth does not fully capture the complexity of this issue. Other factors, including genetics, socioeconomic status, and cultural factors, may contribute to the observed differences in maximal oxygen consumption between these racial groups.')

# %%
Y_test[0]
# Out:
# 1

# %% [markdown]
# ## Extracting the features for the Training Data

# %%
import torch
from tqdm import tqdm


def extract_features(
    knowledge: str,
    conditioned_text: str,
    generated_text: str,
    features_to_extract: dict[str, bool],
):
    return model.extractFeatures(
        knowledge, conditioned_text, generated_text, features_to_extract
    )


X_train_features_maps = []

for knowledge, conditioned_text, generated_text in tqdm(X_train, desc="Processing"):
    X_train_features_maps.append(
        extract_features(
            knowledge, conditioned_text, generated_text, features_to_extract
        )
    )
    torch.cuda.empty_cache()  # Clean cache in every step for memory saving.
# Out:
# Processing: 100%|██████████| 128/128 [00:19<00:00,  6.44it/s]

# %%
len(X_train_features_maps)
# Out:
# 128

# %%
X_train_features_maps[0] # for first datapoint
# Out:
# {'mtp': 3.045469876283846e-09,
#  'avgtp': 0.003144459553278446,
#  'MDVTP': 0.9989757537841797,
#  'MMDVP': 0.03137516975402832}

# %%
X_train_features = [list(dic.values()) for dic in X_train_features_maps]

# %%
len(X_train_features) # 4 features for each datapoint
# Out:
# 128

# %%
X_train_features[0]
# Out:
# [3.045469876283846e-09,
#  0.003144459553278446,
#  0.9989757537841797,
#  0.03137516975402832]

# %%
pd.DataFrame(X_train_features).describe()
# Out:
#                   0           1           2           3
# count  1.280000e+02  128.000000  128.000000  128.000000
# mean   1.143537e-07    0.002705    0.994206    0.057522
# std    4.035199e-07    0.003901    0.026104    0.029762
# min    3.864619e-13    0.000048    0.722650    0.012113
# 25%    4.106822e-11    0.000208    0.997942    0.038006
# 50%    6.406336e-10    0.002326    0.999704    0.051360
# 75%    1.054410e-08    0.003680    0.999905    0.068570
# max    2.340968e-06    0.032365    0.999996    0.208493

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_train_features = scaler.fit_transform(X_train_features)

# %%
pd.DataFrame(X_train_features).describe()
# Out:
#                   0             1             2           3
# count  1.280000e+02  1.280000e+02  1.280000e+02  128.000000
# mean  -1.387779e-17 -3.469447e-17 -2.081668e-17    0.000000
# std    1.003929e+00  1.003929e+00  1.003929e+00    1.003929
# min   -2.845031e-01 -6.838505e-01 -1.044355e+01   -1.531741
# 25%   -2.844019e-01 -6.427977e-01  1.437038e-01   -0.658318
# 50%   -2.829102e-01 -9.756893e-02  2.114507e-01   -0.207845
# 75%   -2.582711e-01  2.508884e-01  2.191769e-01    0.372665
# max    5.539661e+00  7.633423e+00  2.226944e-01    5.092579

# %% [markdown]
# ## Training Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression(verbose=1)
"""verbose=1 in logistic regression
(specifically in libraries like scikit-learn) enables the display of progress information,
such as iteration counts and loss values, during the model training process.
It is used to monitor convergence, especially during long training sessions."""

clf.fit(X_train_features, Y_train) # len(X_train_features) = len(Y_train)
# Out:
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# LogisticRegression(verbose=1)

# %% [markdown]
# ## Evaluate accuracy of Logistic Regression on the training set

# %%
from sklearn.metrics import accuracy_score

# Y_Pred = clf.predict(X_train_features)
# NOTE: this is wrong: should be Y_Pred = clf.predict(X_test_features)
# accuracy = accuracy_score(Y_test, Y_Pred)
# could add: model.predict_proba(X_test)


# accuracy = accuracy_score(Y_train, Y_Pred)
# print(f"Accuracy: {accuracy * 100:.2f}%")

# %% [markdown]
# logit(p) = w1 x1 ​+ w2 x2 + w3 x3 + w4 x4 + b

# %%
## they are global weights learnt from entire training data:

# if my features are on different scale:
# from sklearn.preprocessing import StandardScaler

log_odds = clf.coef_[0] # clf.coef_[0] = clf.coef_
odds = np.exp(clf.coef_[0])


""" Safer to know the order:
feature_names = ["mtp", "avgtp", "Mpd", "mps"]

lr_features_log = dict(zip(feature_names, log_odds))
lr_features_no_log = dict(zip(feature_names, odds))
"""


lr_features_log = {k: v for k, v in zip(X_train_features_maps[0].keys(), log_odds)}
lr_features_no_log = {k: v for k, v in zip(X_train_features_maps[0].keys(), odds)}

print("log", lr_features_log)
print("no_log", lr_features_no_log)
# Out:
# log {'mtp': np.float64(0.11708538462961234), 'avgtp': np.float64(0.36329146865990275), 'MDVTP': np.float64(-0.2280425889126344), 'MMDVP': np.float64(-0.12349304434774792)}
# no_log {'mtp': np.float64(1.1242154163095137), 'avgtp': np.float64(1.438054946110908), 'MDVTP': np.float64(0.7960903544909065), 'MMDVP': np.float64(0.883827788821448)}

# %% [markdown]
# ## Extracting the Features of the Validation Set

# %%
X_val_features_map = []

for knowledge, conditioned_text, generated_text in tqdm(X_val, desc="Processing"):
    X_val_features_map.append(
        extract_features(
            knowledge, conditioned_text, generated_text, features_to_extract
        )
    )
    torch.cuda.empty_cache()
# Out:
# Processing: 0it [00:00, ?it/s]

# %%
X_val_features = [list(dic.values()) for dic in X_val_features_map]

# %% [markdown]
# ## Uncomment next cell if you have a validation set and you want to see LR accuracy on it.

# %%
# from sklearn.metrics import accuracy_score

# Y_Pred = clf.predict(X_val_features)

# accuracy = accuracy_score(Y_val, Y_Pred)
# print(f"Accuracy: {accuracy * 100:.2f}%")

# %% [markdown]
# ## Extracting the Features of the Test Set

# %%
from tqdm import tqdm

X_test_features_map = []

for knowledge, conditioned_text, generated_text in tqdm(X_test, desc="Processing"):
    X_test_features_map.append(
        extract_features(
            knowledge, conditioned_text, generated_text, features_to_extract
        )
    )
    torch.cuda.empty_cache()
# Out:
# Processing: 100%|██████████| 32/32 [00:05<00:00,  5.40it/s]

# %%
X_test_features = [list(dic.values()) for dic in X_test_features_map]

# %%
pd.DataFrame(X_test_features).describe()
# Out:
#                   0          1          2          3
# count  3.200000e+01  32.000000  32.000000  32.000000
# mean   6.923610e-08   0.001731   0.994717   0.058972
# std    1.474669e-07   0.001910   0.015794   0.027406
# min    5.581367e-12   0.000044   0.911721   0.019480
# 25%    1.289932e-10   0.000212   0.997459   0.042578
# 50%    1.116349e-09   0.000391   0.999275   0.056714
# 75%    2.041872e-08   0.002928   0.999869   0.069484
# max    5.878092e-07   0.006063   0.999984   0.136168

# %%
X_test_features = scaler.transform(X_test_features)

# %%
pd.DataFrame(X_test_features).describe()
# Out:
#                0          1          2          3
# count  32.000000  32.000000  32.000000  32.000000
# mean   -0.112249  -0.250606   0.019646   0.048923
# std     0.366887   0.491639   0.607393   0.924458
# min    -0.284490  -0.684767  -3.172214  -1.283243
# 25%    -0.284183  -0.641574   0.125119  -0.504103
# 50%    -0.281727  -0.595681   0.194968  -0.027247
# 75%    -0.233704   0.057284   0.217807   0.403522
# max     1.177924   0.864248   0.222227   2.652910

# %% [markdown]
# ## Evaluate accuracy of the LogisticRegression on the testing set

# %%
from sklearn.metrics import accuracy_score

Y_Pred = clf.predict(X_test_features)

lr_accuracy = accuracy_score(Y_test, Y_Pred)
print(f"Accuracy: {lr_accuracy * 100:.2f}%")
# Out:
# Accuracy: 40.62%

# %%
log_odds = clf.coef_[0]
pd.DataFrame(log_odds, X_train_features_maps[0].keys(), columns=["coef"]).sort_values(
    by="coef", ascending=False
)
# Out:
#            coef
# avgtp  0.363291
# mtp    0.117085
# MMDVP -0.123493
# MDVTP -0.228043

# %%
odds = np.exp(clf.coef_[0])
pd.DataFrame(odds, X_train_features_maps[0].keys(), columns=["coef"]).sort_values(
    by="coef", ascending=False
)
# Out:
#            coef
# avgtp  1.438055
# mtp    1.124215
# MMDVP  0.883828
# MDVTP  0.796090

# %%
print(clf.intercept_)
# Out:
# [0.01414214]

# %% [markdown]
# ## Simple Dense NN

# %%
import torch.nn as nn


class SimpleDenseNet(nn.Module):
    def __init__(self, input_dim: int, hidden_dim: int, output_dim=1, dropout_prob=0.3):
        super(SimpleDenseNet, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, output_dim)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        x = self.relu(x)
        x = self.fc3(x)
        x = self.sigmoid(x)
        return x

# %%
denseModel = SimpleDenseNet(
    input_dim=np.array([v for v in features_to_extract.values()]).sum(), hidden_dim=512
).to(device)

# %% [markdown]
# # Code declaring and computing all the metrics to measure

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    roc_auc_score,
    precision_recall_curve,
    auc
)


def compute_metrics(model, input_tensor, true_labels):
    with torch.no_grad(): # torch.no_grad : disable gradient calculation
        outputs = model(input_tensor)
        predicted_probs = torch.sigmoid(outputs).cpu().numpy()
        predicted = (outputs > 0.5).float().cpu().numpy()

        true_labels = true_labels.cpu().numpy()

        acc = accuracy_score(true_labels, predicted)
        precision = precision_score(true_labels, predicted)
        recall = recall_score(true_labels, predicted)
        f1 = f1_score(true_labels, predicted)

        precision_negative = precision_score(true_labels, predicted, pos_label=0)
        recall_negative = recall_score(true_labels, predicted, pos_label=0)
        f1_negative = f1_score(true_labels, predicted, pos_label=0)

        tn, fp, fn, tp = confusion_matrix(true_labels, predicted).ravel()
        roc_auc = roc_auc_score(true_labels, predicted_probs)

        P, R, thre = precision_recall_curve(true_labels, predicted, pos_label=1)
        pr_auc = auc(R, P)

        roc_auc_negative = roc_auc_score(
            true_labels, 1 - predicted_probs
        )  # If predicted_probs is the probability of the positive class
        P_neg, R_neg, _ = precision_recall_curve(true_labels, predicted, pos_label=0)
        pr_auc_negative = auc(R_neg, P_neg)

        return {
            "Accuracy": acc,
            "Precision": precision,
            "Recall": recall,
            "F1": f1,
            "TP": tp,
            "TN": tn,
            "FP": fp,
            "FN": fn,
            "ROC AUC": roc_auc,
            "PR AUC": pr_auc,
            "Precision-Negative": precision_negative,
            "Recall-Negative": recall_negative,
            "F1-Negative": f1_negative,
            "ROC AUC-Negative": roc_auc_negative,
            "PR AUC-Negative": pr_auc_negative,
        }

# %% [markdown]
# ## Code for training the Dense Model and getting the result of all metrics corresponding to the Testing Set.

# %%
def compute_accuracy(model, input_tensor, true_labels):
    with torch.no_grad():
        outputs = model(input_tensor)
        predicted = (outputs > 0.5).float()
        correct = (predicted == true_labels).float().sum()
        accuracy = correct / len(true_labels)
        return accuracy.item()


X_train_tensor = torch.tensor(X_train_features, dtype=torch.float32).to(device)
Y_train_tensor = torch.tensor(Y_train, dtype=torch.float32).view(-1, 1).to(device)

print(X_train_tensor.shape, Y_train_tensor.shape)

# Define loss and optimizer
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(denseModel.parameters(), lr=0.001)

bestValAcc = 0
# Training loop
num_epochs = 5000 # reducing to 5000
for epoch in range(num_epochs):
    denseModel.train()
    optimizer.zero_grad()
    outputs = denseModel(X_train_tensor)
    loss = criterion(outputs, Y_train_tensor)
    loss.backward()
    optimizer.step()

    # Compute training accuracy
    train_accuracy = compute_accuracy(denseModel, X_train_tensor, Y_train_tensor)

    # Uncomment this if you want to see how the accuracy of testing improves during the training process.
    ##Compute testing accuracy
    # X_val_tensor = torch.tensor(X_val_features, dtype=torch.float32).to(device)
    # Y_val_tensor = torch.tensor(Y_val, dtype=torch.float32).view(-1, 1).to(device)

    # val_accuracy = compute_accuracy(denseModel, X_val_tensor, Y_val_tensor)

    # if bestValAcc < val_accuracy:
    #     bestValAcc = val_accuracy
    #     print(f'Saving model with best validation accuracy ...')
    #     torch.save(denseModel.state_dict(), 'llama-' + task + '-best-model')

    if (epoch + 1) % 10 == 0:
        print(
            f"Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}, Training Accuracy: {train_accuracy:.4f}"
        )  # , "Validation Accuracy": {val_accuracy:.4f}')
# Out:
# torch.Size([128, 4]) torch.Size([128, 1])
# Epoch [10/5000], Loss: 0.6250, Training Accuracy: 0.6250
# Epoch [20/5000], Loss: 0.5986, Training Accuracy: 0.6797
# Epoch [30/5000], Loss: 0.5757, Training Accuracy: 0.6953
# Epoch [40/5000], Loss: 0.5529, Training Accuracy: 0.7031
# Epoch [50/5000], Loss: 0.5298, Training Accuracy: 0.7422
# Epoch [60/5000], Loss: 0.5085, Training Accuracy: 0.7578
# Epoch [70/5000], Loss: 0.4860, Training Accuracy: 0.7578
# Epoch [80/5000], Loss: 0.4655, Training Accuracy: 0.7812
# Epoch [90/5000], Loss: 0.4435, Training Accuracy: 0.7891
# Epoch [100/5000], Loss: 0.4261, Training Accuracy: 0.8047
# Epoch [110/5000], Loss: 0.4050, Training Accuracy: 0.8203
# Epoch [120/5000], Loss: 0.3884, Training Accuracy: 0.8359
# Epoch [130/5000], Loss: 0.3712, Training Accuracy: 0.8438
# Epoch [140/5000], Loss: 0.3569, Training Accuracy: 0.8594
# Epoch [150/5000], Loss: 0.3429, Training Accuracy: 0.8594
# Epoch [160/5000], Loss: 0.3295, Training Accuracy: 0.8594
# Epoch [170/5000], Loss: 0.3180, Training Accuracy: 0.8594
# Epoch [180/5000], Loss: 0.3074, Training Accuracy: 0.8672
# Epoch [190/5000], Loss: 0.2978, Training Accuracy: 0.8672
# Epoch [200/5000], Loss: 0.2885, Training Accuracy: 0.8750
# Epoch [210/5000], Loss: 0.2808, Training Accuracy: 0.8828
# Epoch [220/5000], Loss: 0.2728, Training Accuracy: 0.8750
# Epoch [230/5000], Loss: 0.2645, Training Accuracy: 0.8906
# Epoch [240/5000], Loss: 0.2566, Training Accuracy: 0.8750
# Epoch [250/5000], Loss: 0.2496, Training Accuracy: 0.8906
# Epoch [260/5000], Loss: 0.2428, Training Accuracy: 0.9062
# Epoch [270/5000], Loss: 0.2363, Training Accuracy: 0.8984
# Epoch [280/5000], Loss: 0.2298, Training Accuracy: 0.9141
# Epoch [290/5000], Loss: 0.2251, Training Accuracy: 0.9297
# Epoch [300/5000], Loss: 0.2202, Training Accuracy: 0.8984
# Epoch [310/5000], Loss: 0.2138, Training Accuracy: 0.9297
# Epoch [320/5000], Loss: 0.2078, Training Accuracy: 0.9141
# Epoch [330/5000], Loss: 0.2016, Training Accuracy: 0.9531
# Epoch [340/5000], Loss: 0.1979, Training Accuracy: 0.9453
# Epoch [350/5000], Loss: 0.1922, Training Accuracy: 0.9219
# Epoch [360/5000], Loss: 0.1873, Training Accuracy: 0.9453
# Epoch [370/5000], Loss: 0.1842, Training Accuracy: 0.9219
# Epoch [380/5000], Loss: 0.1791, Training Accuracy: 0.9531
# Epoch [390/5000], Loss: 0.1743, Training Accuracy: 0.9453
# Epoch [400/5000], Loss: 0.1692, Training Accuracy: 0.9375
# Epoch [410/5000], Loss: 0.1682, Training Accuracy: 0.9375
# Epoch [420/5000], Loss: 0.1631, Training Accuracy: 0.9453
# Epoch [430/5000], Loss: 0.1580, Training Accuracy: 0.9453
# Epoch [440/5000], Loss: 0.1532, Training Accuracy: 0.9531
# Epoch [450/5000], Loss: 0.1487, Training Accuracy: 0.9531
# Epoch [460/5000], Loss: 0.1474, Training Accuracy: 0.9531
# Epoch [470/5000], Loss: 0.1418, Training Accuracy: 0.9609
# Epoch [480/5000], Loss: 0.1394, Training Accuracy: 0.9766
# Epoch [490/5000], Loss: 0.1353, Training Accuracy: 0.9609
# Epoch [500/5000], Loss: 0.1320, Training Accuracy: 0.9531
# Epoch [510/5000], Loss: 0.1291, Training Accuracy: 0.9688
# Epoch [520/5000], Loss: 0.1266, Training Accuracy: 0.9609
# Epoch [530/5000], Loss: 0.1229, Training Accuracy: 0.9844
# Epoch [540/5000], Loss: 0.1201, Training Accuracy: 0.9844
# Epoch [550/5000], Loss: 0.1187, Training Accuracy: 0.9688
# Epoch [560/5000], Loss: 0.1141, Training Accuracy: 0.9844
# Epoch [570/5000], Loss: 0.1137, Training Accuracy: 0.9844
# Epoch [580/5000], Loss: 0.1090, Training Accuracy: 0.9766
# Epoch [590/5000], Loss: 0.1081, Training Accuracy: 0.9688
# Epoch [600/5000], Loss: 0.1044, Training Accuracy: 0.9844
# Epoch [610/5000], Loss: 0.1025, Training Accuracy: 0.9844
# Epoch [620/5000], Loss: 0.0994, Training Accuracy: 0.9844
# Epoch [630/5000], Loss: 0.0996, Training Accuracy: 0.9844
# Epoch [640/5000], Loss: 0.0963, Training Accuracy: 0.9922
# Epoch [650/5000], Loss: 0.0930, Training Accuracy: 0.9766
# Epoch [660/5000], Loss: 0.0904, Training Accuracy: 0.9844
# Epoch [670/5000], Loss: 0.0889, Training Accuracy: 0.9844
# Epoch [680/5000], Loss: 0.0869, Training Accuracy: 0.9844
# Epoch [690/5000], Loss: 0.0846, Training Accuracy: 0.9844
# Epoch [700/5000], Loss: 0.0833, Training Accuracy: 0.9844
# Epoch [710/5000], Loss: 0.0806, Training Accuracy: 0.9844
# Epoch [720/5000], Loss: 0.0807, Training Accuracy: 0.9922
# Epoch [730/5000], Loss: 0.0773, Training Accuracy: 0.9844
# Epoch [740/5000], Loss: 0.0758, Training Accuracy: 0.9844
# Epoch [750/5000], Loss: 0.0744, Training Accuracy: 0.9922
# Epoch [760/5000], Loss: 0.0725, Training Accuracy: 0.9922
# Epoch [770/5000], Loss: 0.0709, Training Accuracy: 0.9922
# Epoch [780/5000], Loss: 0.0696, Training Accuracy: 0.9844
# Epoch [790/5000], Loss: 0.0685, Training Accuracy: 0.9922
# Epoch [800/5000], Loss: 0.0661, Training Accuracy: 0.9922
# Epoch [810/5000], Loss: 0.0655, Training Accuracy: 0.9922
# Epoch [820/5000], Loss: 0.0634, Training Accuracy: 0.9922
# Epoch [830/5000], Loss: 0.0625, Training Accuracy: 0.9922
# Epoch [840/5000], Loss: 0.0611, Training Accuracy: 1.0000
# Epoch [850/5000], Loss: 0.0599, Training Accuracy: 0.9922
# Epoch [860/5000], Loss: 0.0585, Training Accuracy: 0.9922
# Epoch [870/5000], Loss: 0.0571, Training Accuracy: 0.9922
# Epoch [880/5000], Loss: 0.0564, Training Accuracy: 0.9922
# Epoch [890/5000], Loss: 0.0546, Training Accuracy: 0.9922
# Epoch [900/5000], Loss: 0.0535, Training Accuracy: 1.0000
# Epoch [910/5000], Loss: 0.0530, Training Accuracy: 1.0000
# Epoch [920/5000], Loss: 0.0511, Training Accuracy: 1.0000
# Epoch [930/5000], Loss: 0.0505, Training Accuracy: 0.9922
# Epoch [940/5000], Loss: 0.0492, Training Accuracy: 1.0000
# Epoch [950/5000], Loss: 0.0485, Training Accuracy: 1.0000
# Epoch [960/5000], Loss: 0.0471, Training Accuracy: 1.0000
# Epoch [970/5000], Loss: 0.0462, Training Accuracy: 1.0000
# Epoch [980/5000], Loss: 0.0454, Training Accuracy: 1.0000
# Epoch [990/5000], Loss: 0.0442, Training Accuracy: 1.0000
# Epoch [1000/5000], Loss: 0.0437, Training Accuracy: 1.0000
# Epoch [1010/5000], Loss: 0.0424, Training Accuracy: 1.0000
# Epoch [1020/5000], Loss: 0.0419, Training Accuracy: 1.0000
# Epoch [1030/5000], Loss: 0.0407, Training Accuracy: 1.0000
# Epoch [1040/5000], Loss: 0.0399, Training Accuracy: 1.0000
# Epoch [1050/5000], Loss: 0.0390, Training Accuracy: 1.0000
# Epoch [1060/5000], Loss: 0.0384, Training Accuracy: 1.0000
# Epoch [1070/5000], Loss: 0.0375, Training Accuracy: 1.0000
# Epoch [1080/5000], Loss: 0.0366, Training Accuracy: 1.0000
# Epoch [1090/5000], Loss: 0.0359, Training Accuracy: 1.0000
# Epoch [1100/5000], Loss: 0.0352, Training Accuracy: 1.0000
# Epoch [1110/5000], Loss: 0.0346, Training Accuracy: 1.0000
# Epoch [1120/5000], Loss: 0.0338, Training Accuracy: 1.0000
# Epoch [1130/5000], Loss: 0.0332, Training Accuracy: 1.0000
# Epoch [1140/5000], Loss: 0.0326, Training Accuracy: 1.0000
# Epoch [1150/5000], Loss: 0.0317, Training Accuracy: 1.0000
# Epoch [1160/5000], Loss: 0.0312, Training Accuracy: 1.0000
# Epoch [1170/5000], Loss: 0.0304, Training Accuracy: 1.0000
# Epoch [1180/5000], Loss: 0.0299, Training Accuracy: 1.0000
# Epoch [1190/5000], Loss: 0.0294, Training Accuracy: 1.0000
# Epoch [1200/5000], Loss: 0.0289, Training Accuracy: 1.0000
# Epoch [1210/5000], Loss: 0.0282, Training Accuracy: 1.0000
# Epoch [1220/5000], Loss: 0.0276, Training Accuracy: 1.0000
# Epoch [1230/5000], Loss: 0.0270, Training Accuracy: 1.0000
# Epoch [1240/5000], Loss: 0.0265, Training Accuracy: 1.0000
# Epoch [1250/5000], Loss: 0.0260, Training Accuracy: 1.0000
# Epoch [1260/5000], Loss: 0.0254, Training Accuracy: 1.0000
# Epoch [1270/5000], Loss: 0.0249, Training Accuracy: 1.0000
# Epoch [1280/5000], Loss: 0.0244, Training Accuracy: 1.0000
# Epoch [1290/5000], Loss: 0.0239, Training Accuracy: 1.0000
# Epoch [1300/5000], Loss: 0.0234, Training Accuracy: 1.0000
# Epoch [1310/5000], Loss: 0.0230, Training Accuracy: 1.0000
# Epoch [1320/5000], Loss: 0.0225, Training Accuracy: 1.0000
# Epoch [1330/5000], Loss: 0.0221, Training Accuracy: 1.0000
# Epoch [1340/5000], Loss: 0.0216, Training Accuracy: 1.0000
# Epoch [1350/5000], Loss: 0.0212, Training Accuracy: 1.0000
# Epoch [1360/5000], Loss: 0.0208, Training Accuracy: 1.0000
# Epoch [1370/5000], Loss: 0.0204, Training Accuracy: 1.0000
# Epoch [1380/5000], Loss: 0.0199, Training Accuracy: 1.0000
# Epoch [1390/5000], Loss: 0.0196, Training Accuracy: 1.0000
# Epoch [1400/5000], Loss: 0.0192, Training Accuracy: 1.0000
# Epoch [1410/5000], Loss: 0.0188, Training Accuracy: 1.0000
# Epoch [1420/5000], Loss: 0.0184, Training Accuracy: 1.0000
# Epoch [1430/5000], Loss: 0.0181, Training Accuracy: 1.0000
# Epoch [1440/5000], Loss: 0.0177, Training Accuracy: 1.0000
# Epoch [1450/5000], Loss: 0.0174, Training Accuracy: 1.0000
# Epoch [1460/5000], Loss: 0.0171, Training Accuracy: 1.0000
# Epoch [1470/5000], Loss: 0.0167, Training Accuracy: 1.0000
# Epoch [1480/5000], Loss: 0.0164, Training Accuracy: 1.0000
# Epoch [1490/5000], Loss: 0.0161, Training Accuracy: 1.0000
# Epoch [1500/5000], Loss: 0.0158, Training Accuracy: 1.0000
# Epoch [1510/5000], Loss: 0.0155, Training Accuracy: 1.0000
# Epoch [1520/5000], Loss: 0.0152, Training Accuracy: 1.0000
# Epoch [1530/5000], Loss: 0.0149, Training Accuracy: 1.0000
# Epoch [1540/5000], Loss: 0.0146, Training Accuracy: 1.0000
# Epoch [1550/5000], Loss: 0.0143, Training Accuracy: 1.0000
# Epoch [1560/5000], Loss: 0.0140, Training Accuracy: 1.0000
# Epoch [1570/5000], Loss: 0.0138, Training Accuracy: 1.0000
# Epoch [1580/5000], Loss: 0.0135, Training Accuracy: 1.0000
# Epoch [1590/5000], Loss: 0.0133, Training Accuracy: 1.0000
# Epoch [1600/5000], Loss: 0.0130, Training Accuracy: 1.0000
# Epoch [1610/5000], Loss: 0.0128, Training Accuracy: 1.0000
# Epoch [1620/5000], Loss: 0.0125, Training Accuracy: 1.0000
# Epoch [1630/5000], Loss: 0.0123, Training Accuracy: 1.0000
# Epoch [1640/5000], Loss: 0.0121, Training Accuracy: 1.0000
# Epoch [1650/5000], Loss: 0.0119, Training Accuracy: 1.0000
# Epoch [1660/5000], Loss: 0.0116, Training Accuracy: 1.0000
# Epoch [1670/5000], Loss: 0.0114, Training Accuracy: 1.0000
# Epoch [1680/5000], Loss: 0.0112, Training Accuracy: 1.0000
# Epoch [1690/5000], Loss: 0.0110, Training Accuracy: 1.0000
# Epoch [1700/5000], Loss: 0.0108, Training Accuracy: 1.0000
# Epoch [1710/5000], Loss: 0.0106, Training Accuracy: 1.0000
# Epoch [1720/5000], Loss: 0.0104, Training Accuracy: 1.0000
# Epoch [1730/5000], Loss: 0.0102, Training Accuracy: 1.0000
# Epoch [1740/5000], Loss: 0.0101, Training Accuracy: 1.0000
# Epoch [1750/5000], Loss: 0.0099, Training Accuracy: 1.0000
# Epoch [1760/5000], Loss: 0.0097, Training Accuracy: 1.0000
# Epoch [1770/5000], Loss: 0.0095, Training Accuracy: 1.0000
# Epoch [1780/5000], Loss: 0.0094, Training Accuracy: 1.0000
# Epoch [1790/5000], Loss: 0.0092, Training Accuracy: 1.0000
# Epoch [1800/5000], Loss: 0.0090, Training Accuracy: 1.0000
# Epoch [1810/5000], Loss: 0.0089, Training Accuracy: 1.0000
# Epoch [1820/5000], Loss: 0.0087, Training Accuracy: 1.0000
# Epoch [1830/5000], Loss: 0.0086, Training Accuracy: 1.0000
# Epoch [1840/5000], Loss: 0.0084, Training Accuracy: 1.0000
# Epoch [1850/5000], Loss: 0.0083, Training Accuracy: 1.0000
# Epoch [1860/5000], Loss: 0.0081, Training Accuracy: 1.0000
# Epoch [1870/5000], Loss: 0.0080, Training Accuracy: 1.0000
# Epoch [1880/5000], Loss: 0.0079, Training Accuracy: 1.0000
# Epoch [1890/5000], Loss: 0.0077, Training Accuracy: 1.0000
# Epoch [1900/5000], Loss: 0.0076, Training Accuracy: 1.0000
# Epoch [1910/5000], Loss: 0.0075, Training Accuracy: 1.0000
# Epoch [1920/5000], Loss: 0.0073, Training Accuracy: 1.0000
# Epoch [1930/5000], Loss: 0.0072, Training Accuracy: 1.0000
# Epoch [1940/5000], Loss: 0.0071, Training Accuracy: 1.0000
# Epoch [1950/5000], Loss: 0.0070, Training Accuracy: 1.0000
# Epoch [1960/5000], Loss: 0.0069, Training Accuracy: 1.0000
# Epoch [1970/5000], Loss: 0.0068, Training Accuracy: 1.0000
# Epoch [1980/5000], Loss: 0.0066, Training Accuracy: 1.0000
# Epoch [1990/5000], Loss: 0.0065, Training Accuracy: 1.0000
# Epoch [2000/5000], Loss: 0.0064, Training Accuracy: 1.0000
# Epoch [2010/5000], Loss: 0.0063, Training Accuracy: 1.0000
# Epoch [2020/5000], Loss: 0.0062, Training Accuracy: 1.0000
# Epoch [2030/5000], Loss: 0.0061, Training Accuracy: 1.0000
# Epoch [2040/5000], Loss: 0.0060, Training Accuracy: 1.0000
# Epoch [2050/5000], Loss: 0.0059, Training Accuracy: 1.0000
# Epoch [2060/5000], Loss: 0.0058, Training Accuracy: 1.0000
# Epoch [2070/5000], Loss: 0.0057, Training Accuracy: 1.0000
# Epoch [2080/5000], Loss: 0.0057, Training Accuracy: 1.0000
# Epoch [2090/5000], Loss: 0.0056, Training Accuracy: 1.0000
# Epoch [2100/5000], Loss: 0.0055, Training Accuracy: 1.0000
# Epoch [2110/5000], Loss: 0.0054, Training Accuracy: 1.0000
# Epoch [2120/5000], Loss: 0.0053, Training Accuracy: 1.0000
# Epoch [2130/5000], Loss: 0.0052, Training Accuracy: 1.0000
# Epoch [2140/5000], Loss: 0.0051, Training Accuracy: 1.0000
# Epoch [2150/5000], Loss: 0.0051, Training Accuracy: 1.0000
# Epoch [2160/5000], Loss: 0.0050, Training Accuracy: 1.0000
# Epoch [2170/5000], Loss: 0.0049, Training Accuracy: 1.0000
# Epoch [2180/5000], Loss: 0.0048, Training Accuracy: 1.0000
# Epoch [2190/5000], Loss: 0.0048, Training Accuracy: 1.0000
# Epoch [2200/5000], Loss: 0.0047, Training Accuracy: 1.0000
# Epoch [2210/5000], Loss: 0.0046, Training Accuracy: 1.0000
# Epoch [2220/5000], Loss: 0.0046, Training Accuracy: 1.0000
# Epoch [2230/5000], Loss: 0.0045, Training Accuracy: 1.0000
# Epoch [2240/5000], Loss: 0.0044, Training Accuracy: 1.0000
# Epoch [2250/5000], Loss: 0.0044, Training Accuracy: 1.0000
# Epoch [2260/5000], Loss: 0.0043, Training Accuracy: 1.0000
# Epoch [2270/5000], Loss: 0.0042, Training Accuracy: 1.0000
# Epoch [2280/5000], Loss: 0.0042, Training Accuracy: 1.0000
# Epoch [2290/5000], Loss: 0.0041, Training Accuracy: 1.0000
# Epoch [2300/5000], Loss: 0.0041, Training Accuracy: 1.0000
# Epoch [2310/5000], Loss: 0.0040, Training Accuracy: 1.0000
# Epoch [2320/5000], Loss: 0.0039, Training Accuracy: 1.0000
# Epoch [2330/5000], Loss: 0.0039, Training Accuracy: 1.0000
# Epoch [2340/5000], Loss: 0.0038, Training Accuracy: 1.0000
# Epoch [2350/5000], Loss: 0.0038, Training Accuracy: 1.0000
# Epoch [2360/5000], Loss: 0.0037, Training Accuracy: 1.0000
# Epoch [2370/5000], Loss: 0.0037, Training Accuracy: 1.0000
# Epoch [2380/5000], Loss: 0.0036, Training Accuracy: 1.0000
# Epoch [2390/5000], Loss: 0.0036, Training Accuracy: 1.0000
# Epoch [2400/5000], Loss: 0.0035, Training Accuracy: 1.0000
# Epoch [2410/5000], Loss: 0.0035, Training Accuracy: 1.0000
# Epoch [2420/5000], Loss: 0.0034, Training Accuracy: 1.0000
# Epoch [2430/5000], Loss: 0.0034, Training Accuracy: 1.0000
# Epoch [2440/5000], Loss: 0.0033, Training Accuracy: 1.0000
# Epoch [2450/5000], Loss: 0.0033, Training Accuracy: 1.0000
# Epoch [2460/5000], Loss: 0.0032, Training Accuracy: 1.0000
# Epoch [2470/5000], Loss: 0.0032, Training Accuracy: 1.0000
# Epoch [2480/5000], Loss: 0.0031, Training Accuracy: 1.0000
# Epoch [2490/5000], Loss: 0.0031, Training Accuracy: 1.0000
# Epoch [2500/5000], Loss: 0.0031, Training Accuracy: 1.0000
# Epoch [2510/5000], Loss: 0.0030, Training Accuracy: 1.0000
# Epoch [2520/5000], Loss: 0.0030, Training Accuracy: 1.0000
# Epoch [2530/5000], Loss: 0.0029, Training Accuracy: 1.0000
# Epoch [2540/5000], Loss: 0.0029, Training Accuracy: 1.0000
# Epoch [2550/5000], Loss: 0.0029, Training Accuracy: 1.0000
# Epoch [2560/5000], Loss: 0.0028, Training Accuracy: 1.0000
# Epoch [2570/5000], Loss: 0.0028, Training Accuracy: 1.0000
# Epoch [2580/5000], Loss: 0.0027, Training Accuracy: 1.0000
# Epoch [2590/5000], Loss: 0.0027, Training Accuracy: 1.0000
# Epoch [2600/5000], Loss: 0.0027, Training Accuracy: 1.0000
# Epoch [2610/5000], Loss: 0.0026, Training Accuracy: 1.0000
# Epoch [2620/5000], Loss: 0.0026, Training Accuracy: 1.0000
# Epoch [2630/5000], Loss: 0.0026, Training Accuracy: 1.0000
# Epoch [2640/5000], Loss: 0.0025, Training Accuracy: 1.0000
# Epoch [2650/5000], Loss: 0.0025, Training Accuracy: 1.0000
# Epoch [2660/5000], Loss: 0.0025, Training Accuracy: 1.0000
# Epoch [2670/5000], Loss: 0.0024, Training Accuracy: 1.0000
# Epoch [2680/5000], Loss: 0.0024, Training Accuracy: 1.0000
# Epoch [2690/5000], Loss: 0.0024, Training Accuracy: 1.0000
# Epoch [2700/5000], Loss: 0.0023, Training Accuracy: 1.0000
# Epoch [2710/5000], Loss: 0.0023, Training Accuracy: 1.0000
# Epoch [2720/5000], Loss: 0.0023, Training Accuracy: 1.0000
# Epoch [2730/5000], Loss: 0.0023, Training Accuracy: 1.0000
# Epoch [2740/5000], Loss: 0.0022, Training Accuracy: 1.0000
# Epoch [2750/5000], Loss: 0.0022, Training Accuracy: 1.0000
# Epoch [2760/5000], Loss: 0.0022, Training Accuracy: 1.0000
# Epoch [2770/5000], Loss: 0.0021, Training Accuracy: 1.0000
# Epoch [2780/5000], Loss: 0.0021, Training Accuracy: 1.0000
# Epoch [2790/5000], Loss: 0.0021, Training Accuracy: 1.0000
# Epoch [2800/5000], Loss: 0.0021, Training Accuracy: 1.0000
# Epoch [2810/5000], Loss: 0.0020, Training Accuracy: 1.0000
# Epoch [2820/5000], Loss: 0.0020, Training Accuracy: 1.0000
# Epoch [2830/5000], Loss: 0.0020, Training Accuracy: 1.0000
# Epoch [2840/5000], Loss: 0.0020, Training Accuracy: 1.0000
# Epoch [2850/5000], Loss: 0.0019, Training Accuracy: 1.0000
# Epoch [2860/5000], Loss: 0.0019, Training Accuracy: 1.0000
# Epoch [2870/5000], Loss: 0.0019, Training Accuracy: 1.0000
# Epoch [2880/5000], Loss: 0.0019, Training Accuracy: 1.0000
# Epoch [2890/5000], Loss: 0.0019, Training Accuracy: 1.0000
# Epoch [2900/5000], Loss: 0.0018, Training Accuracy: 1.0000
# Epoch [2910/5000], Loss: 0.0018, Training Accuracy: 1.0000
# Epoch [2920/5000], Loss: 0.0018, Training Accuracy: 1.0000
# Epoch [2930/5000], Loss: 0.0018, Training Accuracy: 1.0000
# Epoch [2940/5000], Loss: 0.0017, Training Accuracy: 1.0000
# Epoch [2950/5000], Loss: 0.0017, Training Accuracy: 1.0000
# Epoch [2960/5000], Loss: 0.0017, Training Accuracy: 1.0000
# Epoch [2970/5000], Loss: 0.0017, Training Accuracy: 1.0000
# Epoch [2980/5000], Loss: 0.0017, Training Accuracy: 1.0000
# Epoch [2990/5000], Loss: 0.0016, Training Accuracy: 1.0000
# Epoch [3000/5000], Loss: 0.0016, Training Accuracy: 1.0000
# Epoch [3010/5000], Loss: 0.0016, Training Accuracy: 1.0000
# Epoch [3020/5000], Loss: 0.0016, Training Accuracy: 1.0000
# Epoch [3030/5000], Loss: 0.0016, Training Accuracy: 1.0000
# Epoch [3040/5000], Loss: 0.0016, Training Accuracy: 1.0000
# Epoch [3050/5000], Loss: 0.0015, Training Accuracy: 1.0000
# Epoch [3060/5000], Loss: 0.0015, Training Accuracy: 1.0000
# Epoch [3070/5000], Loss: 0.0015, Training Accuracy: 1.0000
# Epoch [3080/5000], Loss: 0.0015, Training Accuracy: 1.0000
# Epoch [3090/5000], Loss: 0.0015, Training Accuracy: 1.0000
# Epoch [3100/5000], Loss: 0.0015, Training Accuracy: 1.0000
# Epoch [3110/5000], Loss: 0.0014, Training Accuracy: 1.0000
# Epoch [3120/5000], Loss: 0.0014, Training Accuracy: 1.0000
# Epoch [3130/5000], Loss: 0.0014, Training Accuracy: 1.0000
# Epoch [3140/5000], Loss: 0.0014, Training Accuracy: 1.0000
# Epoch [3150/5000], Loss: 0.0014, Training Accuracy: 1.0000
# Epoch [3160/5000], Loss: 0.0014, Training Accuracy: 1.0000
# Epoch [3170/5000], Loss: 0.0013, Training Accuracy: 1.0000
# Epoch [3180/5000], Loss: 0.0013, Training Accuracy: 1.0000
# Epoch [3190/5000], Loss: 0.0013, Training Accuracy: 1.0000
# Epoch [3200/5000], Loss: 0.0013, Training Accuracy: 1.0000
# Epoch [3210/5000], Loss: 0.0013, Training Accuracy: 1.0000
# Epoch [3220/5000], Loss: 0.0013, Training Accuracy: 1.0000
# Epoch [3230/5000], Loss: 0.0013, Training Accuracy: 1.0000
# Epoch [3240/5000], Loss: 0.0012, Training Accuracy: 1.0000
# Epoch [3250/5000], Loss: 0.0012, Training Accuracy: 1.0000
# Epoch [3260/5000], Loss: 0.0012, Training Accuracy: 1.0000
# Epoch [3270/5000], Loss: 0.0012, Training Accuracy: 1.0000
# Epoch [3280/5000], Loss: 0.0012, Training Accuracy: 1.0000
# Epoch [3290/5000], Loss: 0.0012, Training Accuracy: 1.0000
# Epoch [3300/5000], Loss: 0.0012, Training Accuracy: 1.0000
# Epoch [3310/5000], Loss: 0.0012, Training Accuracy: 1.0000
# Epoch [3320/5000], Loss: 0.0011, Training Accuracy: 1.0000
# Epoch [3330/5000], Loss: 0.0011, Training Accuracy: 1.0000
# Epoch [3340/5000], Loss: 0.0011, Training Accuracy: 1.0000
# Epoch [3350/5000], Loss: 0.0011, Training Accuracy: 1.0000
# Epoch [3360/5000], Loss: 0.0011, Training Accuracy: 1.0000
# Epoch [3370/5000], Loss: 0.0011, Training Accuracy: 1.0000
# Epoch [3380/5000], Loss: 0.0011, Training Accuracy: 1.0000
# Epoch [3390/5000], Loss: 0.0011, Training Accuracy: 1.0000
# Epoch [3400/5000], Loss: 0.0011, Training Accuracy: 1.0000
# Epoch [3410/5000], Loss: 0.0010, Training Accuracy: 1.0000
# Epoch [3420/5000], Loss: 0.0010, Training Accuracy: 1.0000
# Epoch [3430/5000], Loss: 0.0010, Training Accuracy: 1.0000
# Epoch [3440/5000], Loss: 0.0010, Training Accuracy: 1.0000
# Epoch [3450/5000], Loss: 0.0010, Training Accuracy: 1.0000
# Epoch [3460/5000], Loss: 0.0010, Training Accuracy: 1.0000
# Epoch [3470/5000], Loss: 0.0010, Training Accuracy: 1.0000
# Epoch [3480/5000], Loss: 0.0010, Training Accuracy: 1.0000
# Epoch [3490/5000], Loss: 0.0010, Training Accuracy: 1.0000
# Epoch [3500/5000], Loss: 0.0010, Training Accuracy: 1.0000
# Epoch [3510/5000], Loss: 0.0009, Training Accuracy: 1.0000
# Epoch [3520/5000], Loss: 0.0009, Training Accuracy: 1.0000
# Epoch [3530/5000], Loss: 0.0009, Training Accuracy: 1.0000
# Epoch [3540/5000], Loss: 0.0009, Training Accuracy: 1.0000
# Epoch [3550/5000], Loss: 0.0009, Training Accuracy: 1.0000
# Epoch [3560/5000], Loss: 0.0009, Training Accuracy: 1.0000
# Epoch [3570/5000], Loss: 0.0009, Training Accuracy: 1.0000
# Epoch [3580/5000], Loss: 0.0009, Training Accuracy: 1.0000
# Epoch [3590/5000], Loss: 0.0009, Training Accuracy: 1.0000
# Epoch [3600/5000], Loss: 0.0009, Training Accuracy: 1.0000
# Epoch [3610/5000], Loss: 0.0009, Training Accuracy: 1.0000
# Epoch [3620/5000], Loss: 0.0008, Training Accuracy: 1.0000
# Epoch [3630/5000], Loss: 0.0008, Training Accuracy: 1.0000
# Epoch [3640/5000], Loss: 0.0008, Training Accuracy: 1.0000
# Epoch [3650/5000], Loss: 0.0008, Training Accuracy: 1.0000
# Epoch [3660/5000], Loss: 0.0008, Training Accuracy: 1.0000
# Epoch [3670/5000], Loss: 0.0008, Training Accuracy: 1.0000
# Epoch [3680/5000], Loss: 0.0008, Training Accuracy: 1.0000
# Epoch [3690/5000], Loss: 0.0008, Training Accuracy: 1.0000
# Epoch [3700/5000], Loss: 0.0008, Training Accuracy: 1.0000
# Epoch [3710/5000], Loss: 0.0008, Training Accuracy: 1.0000
# Epoch [3720/5000], Loss: 0.0008, Training Accuracy: 1.0000
# Epoch [3730/5000], Loss: 0.0008, Training Accuracy: 1.0000
# Epoch [3740/5000], Loss: 0.0008, Training Accuracy: 1.0000
# Epoch [3750/5000], Loss: 0.0007, Training Accuracy: 1.0000
# Epoch [3760/5000], Loss: 0.0007, Training Accuracy: 1.0000
# Epoch [3770/5000], Loss: 0.0007, Training Accuracy: 1.0000
# Epoch [3780/5000], Loss: 0.0007, Training Accuracy: 1.0000
# Epoch [3790/5000], Loss: 0.0007, Training Accuracy: 1.0000
# Epoch [3800/5000], Loss: 0.0007, Training Accuracy: 1.0000
# Epoch [3810/5000], Loss: 0.0007, Training Accuracy: 1.0000
# Epoch [3820/5000], Loss: 0.0007, Training Accuracy: 1.0000
# Epoch [3830/5000], Loss: 0.0007, Training Accuracy: 1.0000
# Epoch [3840/5000], Loss: 0.0007, Training Accuracy: 1.0000
# Epoch [3850/5000], Loss: 0.0007, Training Accuracy: 1.0000
# Epoch [3860/5000], Loss: 0.0007, Training Accuracy: 1.0000
# Epoch [3870/5000], Loss: 0.0007, Training Accuracy: 1.0000
# Epoch [3880/5000], Loss: 0.0007, Training Accuracy: 1.0000
# Epoch [3890/5000], Loss: 0.0007, Training Accuracy: 1.0000
# Epoch [3900/5000], Loss: 0.0006, Training Accuracy: 1.0000
# Epoch [3910/5000], Loss: 0.0006, Training Accuracy: 1.0000
# Epoch [3920/5000], Loss: 0.0006, Training Accuracy: 1.0000
# Epoch [3930/5000], Loss: 0.0006, Training Accuracy: 1.0000
# Epoch [3940/5000], Loss: 0.0006, Training Accuracy: 1.0000
# Epoch [3950/5000], Loss: 0.0006, Training Accuracy: 1.0000
# Epoch [3960/5000], Loss: 0.0006, Training Accuracy: 1.0000
# Epoch [3970/5000], Loss: 0.0006, Training Accuracy: 1.0000
# Epoch [3980/5000], Loss: 0.0006, Training Accuracy: 1.0000
# Epoch [3990/5000], Loss: 0.0006, Training Accuracy: 1.0000
# Epoch [4000/5000], Loss: 0.0006, Training Accuracy: 1.0000
# Epoch [4010/5000], Loss: 0.0006, Training Accuracy: 1.0000
# Epoch [4020/5000], Loss: 0.0006, Training Accuracy: 1.0000
# Epoch [4030/5000], Loss: 0.0006, Training Accuracy: 1.0000
# Epoch [4040/5000], Loss: 0.0006, Training Accuracy: 1.0000
# Epoch [4050/5000], Loss: 0.0006, Training Accuracy: 1.0000
# Epoch [4060/5000], Loss: 0.0006, Training Accuracy: 1.0000
# Epoch [4070/5000], Loss: 0.0006, Training Accuracy: 1.0000
# Epoch [4080/5000], Loss: 0.0006, Training Accuracy: 1.0000
# Epoch [4090/5000], Loss: 0.0005, Training Accuracy: 1.0000
# Epoch [4100/5000], Loss: 0.0005, Training Accuracy: 1.0000
# Epoch [4110/5000], Loss: 0.0005, Training Accuracy: 1.0000
# Epoch [4120/5000], Loss: 0.0005, Training Accuracy: 1.0000
# Epoch [4130/5000], Loss: 0.0005, Training Accuracy: 1.0000
# Epoch [4140/5000], Loss: 0.0005, Training Accuracy: 1.0000
# Epoch [4150/5000], Loss: 0.0005, Training Accuracy: 1.0000
# Epoch [4160/5000], Loss: 0.0005, Training Accuracy: 1.0000
# Epoch [4170/5000], Loss: 0.0005, Training Accuracy: 1.0000
# Epoch [4180/5000], Loss: 0.0005, Training Accuracy: 1.0000
# Epoch [4190/5000], Loss: 0.0005, Training Accuracy: 1.0000
# Epoch [4200/5000], Loss: 0.0005, Training Accuracy: 1.0000
# Epoch [4210/5000], Loss: 0.0005, Training Accuracy: 1.0000
# Epoch [4220/5000], Loss: 0.0005, Training Accuracy: 1.0000
# Epoch [4230/5000], Loss: 0.0005, Training Accuracy: 1.0000
# Epoch [4240/5000], Loss: 0.0005, Training Accuracy: 1.0000
# Epoch [4250/5000], Loss: 0.0005, Training Accuracy: 1.0000
# Epoch [4260/5000], Loss: 0.0005, Training Accuracy: 1.0000
# Epoch [4270/5000], Loss: 0.0005, Training Accuracy: 1.0000
# Epoch [4280/5000], Loss: 0.0005, Training Accuracy: 1.0000
# Epoch [4290/5000], Loss: 0.0005, Training Accuracy: 1.0000
# Epoch [4300/5000], Loss: 0.0005, Training Accuracy: 1.0000
# Epoch [4310/5000], Loss: 0.0005, Training Accuracy: 1.0000
# Epoch [4320/5000], Loss: 0.0005, Training Accuracy: 1.0000
# Epoch [4330/5000], Loss: 0.0004, Training Accuracy: 1.0000
# Epoch [4340/5000], Loss: 0.0004, Training Accuracy: 1.0000
# Epoch [4350/5000], Loss: 0.0004, Training Accuracy: 1.0000
# Epoch [4360/5000], Loss: 0.0004, Training Accuracy: 1.0000
# Epoch [4370/5000], Loss: 0.0004, Training Accuracy: 1.0000
# Epoch [4380/5000], Loss: 0.0004, Training Accuracy: 1.0000
# Epoch [4390/5000], Loss: 0.0004, Training Accuracy: 1.0000
# Epoch [4400/5000], Loss: 0.0004, Training Accuracy: 1.0000
# Epoch [4410/5000], Loss: 0.0004, Training Accuracy: 1.0000
# Epoch [4420/5000], Loss: 0.0004, Training Accuracy: 1.0000
# Epoch [4430/5000], Loss: 0.0004, Training Accuracy: 1.0000
# Epoch [4440/5000], Loss: 0.0004, Training Accuracy: 1.0000
# Epoch [4450/5000], Loss: 0.0004, Training Accuracy: 1.0000
# Epoch [4460/5000], Loss: 0.0004, Training Accuracy: 1.0000
# Epoch [4470/5000], Loss: 0.0004, Training Accuracy: 1.0000
# Epoch [4480/5000], Loss: 0.0004, Training Accuracy: 1.0000
# Epoch [4490/5000], Loss: 0.0004, Training Accuracy: 1.0000
# Epoch [4500/5000], Loss: 0.0004, Training Accuracy: 1.0000
# Epoch [4510/5000], Loss: 0.0004, Training Accuracy: 1.0000
# Epoch [4520/5000], Loss: 0.0004, Training Accuracy: 1.0000
# Epoch [4530/5000], Loss: 0.0004, Training Accuracy: 1.0000
# Epoch [4540/5000], Loss: 0.0004, Training Accuracy: 1.0000
# Epoch [4550/5000], Loss: 0.0004, Training Accuracy: 1.0000
# Epoch [4560/5000], Loss: 0.0004, Training Accuracy: 1.0000
# Epoch [4570/5000], Loss: 0.0004, Training Accuracy: 1.0000
# Epoch [4580/5000], Loss: 0.0004, Training Accuracy: 1.0000
# Epoch [4590/5000], Loss: 0.0004, Training Accuracy: 1.0000
# Epoch [4600/5000], Loss: 0.0004, Training Accuracy: 1.0000
# Epoch [4610/5000], Loss: 0.0004, Training Accuracy: 1.0000
# Epoch [4620/5000], Loss: 0.0004, Training Accuracy: 1.0000
# Epoch [4630/5000], Loss: 0.0003, Training Accuracy: 1.0000
# Epoch [4640/5000], Loss: 0.0003, Training Accuracy: 1.0000
# Epoch [4650/5000], Loss: 0.0003, Training Accuracy: 1.0000
# Epoch [4660/5000], Loss: 0.0003, Training Accuracy: 1.0000
# Epoch [4670/5000], Loss: 0.0003, Training Accuracy: 1.0000
# Epoch [4680/5000], Loss: 0.0003, Training Accuracy: 1.0000
# Epoch [4690/5000], Loss: 0.0003, Training Accuracy: 1.0000
# Epoch [4700/5000], Loss: 0.0003, Training Accuracy: 1.0000
# Epoch [4710/5000], Loss: 0.0003, Training Accuracy: 1.0000
# Epoch [4720/5000], Loss: 0.0003, Training Accuracy: 1.0000
# Epoch [4730/5000], Loss: 0.0003, Training Accuracy: 1.0000
# Epoch [4740/5000], Loss: 0.0003, Training Accuracy: 1.0000
# Epoch [4750/5000], Loss: 0.0003, Training Accuracy: 1.0000
# Epoch [4760/5000], Loss: 0.0003, Training Accuracy: 1.0000
# Epoch [4770/5000], Loss: 0.0003, Training Accuracy: 1.0000
# Epoch [4780/5000], Loss: 0.0003, Training Accuracy: 1.0000
# Epoch [4790/5000], Loss: 0.0003, Training Accuracy: 1.0000
# Epoch [4800/5000], Loss: 0.0003, Training Accuracy: 1.0000
# Epoch [4810/5000], Loss: 0.0003, Training Accuracy: 1.0000
# Epoch [4820/5000], Loss: 0.0003, Training Accuracy: 1.0000
# Epoch [4830/5000], Loss: 0.0003, Training Accuracy: 1.0000
# Epoch [4840/5000], Loss: 0.0003, Training Accuracy: 1.0000
# Epoch [4850/5000], Loss: 0.0003, Training Accuracy: 1.0000
# Epoch [4860/5000], Loss: 0.0003, Training Accuracy: 1.0000
# Epoch [4870/5000], Loss: 0.0003, Training Accuracy: 1.0000
# Epoch [4880/5000], Loss: 0.0003, Training Accuracy: 1.0000
# Epoch [4890/5000], Loss: 0.0003, Training Accuracy: 1.0000
# Epoch [4900/5000], Loss: 0.0003, Training Accuracy: 1.0000
# Epoch [4910/5000], Loss: 0.0003, Training Accuracy: 1.0000
# Epoch [4920/5000], Loss: 0.0003, Training Accuracy: 1.0000
# Epoch [4930/5000], Loss: 0.0003, Training Accuracy: 1.0000
# Epoch [4940/5000], Loss: 0.0003, Training Accuracy: 1.0000
# Epoch [4950/5000], Loss: 0.0003, Training Accuracy: 1.0000
# Epoch [4960/5000], Loss: 0.0003, Training Accuracy: 1.0000
# Epoch [4970/5000], Loss: 0.0003, Training Accuracy: 1.0000
# Epoch [4980/5000], Loss: 0.0003, Training Accuracy: 1.0000
# Epoch [4990/5000], Loss: 0.0003, Training Accuracy: 1.0000
# Epoch [5000/5000], Loss: 0.0003, Training Accuracy: 1.0000

# %% [markdown]
# ## Uncomment next cell if you want to load a particular model you already trained.

# %%
# loaded_model = SimpleDenseNet(input_dim=len(list(features_to_extract.keys())), hidden_dim=512).to(device)
# loaded_model.load_state_dict(torch.load('llama-' + task + '-best-model'))

# # Set the model to evaluation mode"
# loaded_model.eval()

# %% [markdown]
# #Compute the metrics using the model on the Test Set.

# %%
# basically getting test performance:

X_test_tensor = torch.tensor(X_test_features, dtype=torch.float32).to(device)
Y_test_tensor = torch.tensor(Y_test, dtype=torch.float32).view(-1, 1).to(device)

test_metrics = compute_metrics(denseModel, X_test_tensor, Y_test_tensor)

print(
    f"Testing - Accuracy: {test_metrics['Accuracy']:.4f}, Precision: {test_metrics['Precision']:.4f}, Recall: {test_metrics['Recall']:.4f}, F1: {test_metrics['F1']:.4f}, ROC AUC: {test_metrics['ROC AUC']:.4f}, PR AUC: {test_metrics['PR AUC']:.4f}"
)
print(
    f"Testing - Negative: {test_metrics['Accuracy']:.4f}, Precision-Negative: {test_metrics['Precision-Negative']:.4f}, Recall-Negative: {test_metrics['Recall-Negative']:.4f}, F1-Negative: {test_metrics['F1-Negative']:.4f}, ROC AUC-Negative: {test_metrics['ROC AUC-Negative']:.4f}, PR AUC-Negative: {test_metrics['PR AUC-Negative']:.4f}"
)
# Out:
# Testing - Accuracy: 0.6562, Precision: 0.6923, Recall: 0.5625, F1: 0.6207, ROC AUC: 0.6992, PR AUC: 0.7368
# Testing - Negative: 0.6562, Precision-Negative: 0.6316, Recall-Negative: 0.7500, F1-Negative: 0.6857, ROC AUC-Negative: 0.3008, PR AUC-Negative: 0.4663

# %% [markdown]
# ## Save the results on a CSV if you want.

# %%
model_dataframe = pd.DataFrame(
    columns=[
        "features",
        "model_name",
        "feature_to_extract",
        "method",
        "accuracy",
        "precision",
        "recall",
        "roc auc",
        "pr auc",
        "negative",
        "precision-negative",
        "recall-negative",
        "negative f1",
        "lr_accuracy",
        "lr_features_log",
        "lr_features_no_log",
    ]
)

# %%
d = {
    "features": features_to_extract,
    "model_name": str(model.getName()),
    "feature_to_extract": feature_to_extract,
    "method": "TEST",
    "accuracy": test_metrics["Accuracy"],
    "precision": test_metrics["Precision"],
    "recall": test_metrics["Recall"],
    "f1": test_metrics["F1"],
    "pr auc": test_metrics["PR AUC"],
    "precision-negative": test_metrics["Precision-Negative"],
    "recall-negative": test_metrics["Recall-Negative"],
    "negative-f1": test_metrics["F1-Negative"],
    "lr_accuracy": lr_accuracy,
    "lr_features_log": lr_features_log,
    "lr_features_no_log": lr_features_no_log,
}

model_dataframe.loc[len(model_dataframe.index)] = d

# %%
model_dataframe.head()
# Out:
#                                             features  model_name  \
# 0  {'mtp': True, 'avgtp': True, 'MDVTP': True, 'M...  gpt2-large
#
#   feature_to_extract method  accuracy  precision  recall  roc auc    pr auc  \
# 0                all   TEST   0.65625   0.692308  0.5625      NaN  0.736779
#
#    negative  precision-negative  recall-negative  negative f1  lr_accuracy  \
# 0       NaN            0.631579             0.75          NaN      0.40625
#
#                                      lr_features_log  \
# 0  {'mtp': 0.11708538462961234, 'avgtp': 0.363291...
#
#                                   lr_features_no_log
# 0  {'mtp': 1.1242154163095137, 'avgtp': 1.4380549...

# %%
csv_name = f"{model.getSanitizedName()}_{task}_{includeKnowledge=}_{includeConditioned=}_{'_'.join([f'{k}={v}' for k, v in features_to_extract.items()])}.csv"
model_dataframe.to_csv(output_path / csv_name, index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_12615/524906203.py in <cell line: 0>()
#       1 csv_name = f"{model.getSanitizedName()}_{task}_{includeKnowledge=}_{includeConditioned=}_{'_'.join([f'{k}={v}' for k, v in features_to_extract.items()])}.csv"
# ----> 2 model_dataframe.to_csv(output_path / csv_name, index=False)
#
# NameError: name 'output_path' is not defined
