# %% [markdown]
# ## Connect to your Google Drive or any filesystem you are going to use.

# %%
"""
import sys
from pathlib import Path

IN_COLAB = "google.colab" in sys.modules
if IN_COLAB:
    from google.colab import drive
import sys
from pathlib import Path

IN_COLAB = "google.colab" in sys.modules
if IN_COLAB:
    from google.colab import drive
import sys
from pathlib import Path

IN_COLAB = "google.colab" in sys.modules
if IN_COLAB:
    from google.colab import drive

    drive.mount("/content/gdrive")
base_path = (Path("/content/gdrive/MyDrive/RP1") if IN_COLAB else Path("."))
"""
# Out:
# '\nimport sys\nfrom pathlib import Path\n\nIN_COLAB = "google.colab" in sys.modules\nif IN_COLAB:\n    from google.colab import drive\nimport sys\nfrom pathlib import Path\n\nIN_COLAB = "google.colab" in sys.modules\nif IN_COLAB:\n    from google.colab import drive\nimport sys\nfrom pathlib import Path\n\nIN_COLAB = "google.colab" in sys.modules\nif IN_COLAB:\n    from google.colab import drive\n\n    drive.mount("/content/gdrive")\nbase_path = (Path("/content/gdrive/MyDrive/RP1") if IN_COLAB else Path("."))\n'

# %%
"""
#Fix if you want to use a differenxt path
output_path = base_path / "output"
data_path = base_path / "Datasets"
output_path.mkdir(exist_ok=True)
"""
# Out:
# '\n#Fix if you want to use a differenxt path\noutput_path = base_path / "output"\ndata_path = base_path / "Datasets"\noutput_path.mkdir(exist_ok=True)\n'

# %% [markdown]
# ## These are the libraries needed to run this notebook

# %% [markdown]
# ## Deep Learning Installations

# %%
# %pip install transformers datasets evaluate rouge_score
# %pip install --upgrade huggingface_hub
"""
# %pip install accelerate -U
# %pip install transformers[torch]
# %pip install sentencepiece
# %pip install google
# %pip install protobuf
"""
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.9.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Collecting evaluate
#   Downloading evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (1.17.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers) (0.25.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets) (3.29.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.7.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (from rouge_score) (3.9.1)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from rouge_score) (1.17.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.14.0)
# Requirement already satisfied: click>=8.4.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (8.4.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.5.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2026.5.20)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk->rouge_score) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2026.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.24.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers) (0.1.2)
# Downloading evaluate-0.4.6-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 3.8 MB/s eta 0:00:00
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=b392ca237fad20c6ffe1f77c562c5d990336a61c298c4bda5ac64394acb84640
#   Stored in directory: /root/.cache/pip/wheels/85/9d/af/01feefbe7d55ef5468796f0c68225b6788e85d9d0a281e7a70
# Successfully built rouge_score
# Installing collected packages: rouge_score, evaluate
# Successfully installed evaluate-0.4.6 rouge_score-0.1.2
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (1.17.0)
# Collecting huggingface_hub
#   Downloading huggingface_hub-1.18.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: click>=8.4.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (1.5.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.67.3)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (0.25.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub) (0.16.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface_hub) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface_hub) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface_hub) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface_hub) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface_hub) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface_hub) (0.1.2)
# Downloading huggingface_hub-1.18.0-py3-none-any.whl (684 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 684.4/684.4 kB 12.6 MB/s eta 0:00:00
# Installing collected packages: huggingface_hub
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface_hub 1.17.0
#     Uninstalling huggingface_hub-1.17.0:
#       Successfully uninstalled huggingface_hub-1.17.0
# Successfully installed huggingface_hub-1.18.0
# '\n%pip install accelerate -U\n%pip install transformers[torch]\n%pip install sentencepiece\n%pip install google\n%pip install protobuf\n'

# %% [markdown]
# ## Libraries

# %%
from datasets import load_dataset
from datasets import Dataset
from transformers import AutoTokenizer
from transformers import DataCollatorForSeq2Seq
from transformers import pipeline
from transformers import AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer
from transformers import AutoTokenizer
from transformers import AutoModelForSeq2SeqLM
import numpy as np
import pandas as pd
import evaluate
import random
import json
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading Dataset
#
# `The method loadDataset receieves the path where the datasets json files of the HaluEval repository are. You just need to pass your path and the name of the dataset you are going to use.`
#
# ## Dataset Names:
# - summarization
# - dialogue
# - qa
# - general

# %%
## As a recomendation keep these two with the same naming if you do not want to change many things
datasetName = "general"
task = datasetName

# %%
import requests

base_url = "https://raw.githubusercontent.com/RUCAIBox/HaluEval-2.0/master/annotation/human_annotation/"


bio_medical = requests.get(base_url + "Bio-Medical.json").json()
education = requests.get(base_url + "Education.json").json()
finance = requests.get(base_url + "Finance.json").json()
open_domain = requests.get(base_url + "Open-Domain.json").json()
science = requests.get(base_url + "Science.json").json()

""""
data = (
    bio
    + education
    + finance
    + open_domain
    + science
)

print("Total samples:", len(data))
"""
# Out:
# '"\ndata = (\n    bio\n    + education\n    + finance\n    + open_domain\n    + science\n)\n\nprint("Total samples:", len(data))\n'

# %%
"""
def loadDataset(datasetName, path=data_path):
    file_path = path / f"{datasetName}.json"
    return pd.read_json(file_path) #, lines=True)
"""
# Out:
# '\ndef loadDataset(datasetName, path=data_path):\n    file_path = path / f"{datasetName}.json"\n    return pd.read_json(file_path) #, lines=True)\n'

# %%
"""
bio_medical = loadDataset(datasetName="Bio-Medical")
education = loadDataset(datasetName="Education")
finance = loadDataset(datasetName="Finance")
open_domain = loadDataset(datasetName="Open-Domain")
science = loadDataset(datasetName="Science")
"""
# Out:
# '\nbio_medical = loadDataset(datasetName="Bio-Medical")\neducation = loadDataset(datasetName="Education")\nfinance = loadDataset(datasetName="Finance")\nopen_domain = loadDataset(datasetName="Open-Domain")\nscience = loadDataset(datasetName="Science")\n'

# %% [markdown]
# ### Saving the above file with combined domains

# %%
def process_and_save(datasets_dict):

    # 1. Add domain column
    for name, df in datasets_dict.items():
        df["domain"] = name

    # 2. Merge all datasets
    data = pd.concat(datasets_dict.values(), ignore_index=True)

    # 3. Create hallucination label
    def get_label(judges):
        if not isinstance(judges, list) or len(judges) == 0:
            return "unknown"
        judges = [str(j).strip().lower() for j in judges]
        return "yes" if "false" in judges else "no"

    data["hallucination_label"] = data["human_judge"].apply(get_label)

    # 4. Keep only required columns
    data = data[[
        "id",
        "user_query",
        "chatgpt_response",
        "hallucination_label",
        "domain"
    ]]

    # 5. Shuffle
    data = data.sample(frac=1).reset_index(drop=True)

    return data
"""
    # 6. Save as JSONL
    output_file = output_path / "combined_processed.jsonl"
    data.to_json(output_file, orient="records", lines=True, force_ascii=False)
"""

#    return data
# Out:
# '\n    # 6. Save as JSONL\n    output_file = output_path / "combined_processed.jsonl"\n    data.to_json(output_file, orient="records", lines=True, force_ascii=False)\n'

# %%
import pandas as pd

datasets = {
    "education": pd.DataFrame(education),
    "bio_medical": pd.DataFrame(bio_medical),
    "finance": pd.DataFrame(finance),
    "open_domain": pd.DataFrame(open_domain),
    "science": pd.DataFrame(science)
}

data = process_and_save(datasets)

# %%
data.head()
# Out:
#      id                                         user_query  \
# 0  3234  Why would I vote for an increase in the number...
# 1   974  How truthful is the statement that "N348I muta...
# 2  3434               Can CMB305 be used against sarcomas?
# 3  1342  What is the validity of the assertion that "T ...
# 4  2147  How to calculate lump sum required to generate...
#
#                                     chatgpt_response hallucination_label  \
# 0  Voting in favor of an increase in the number o...                  no
# 1  1. The N348I mutation refers to a specific gen...                 yes
# 2  Yes, CMB305 is a potential treatment option fo...                 yes
# 3  1. T regulatory cells (Tregs) are a type of im...                 yes
# 4  To calculate the lump sum required to generate...                 yes
#
#         domain
# 0      finance
# 1      science
# 2  bio_medical
# 3      science
# 4      finance

# %% [markdown]
# ## For this particular example we are loading the general_data.json since is the one that takes the less time to process in case you want to test quickly how it works.

# %% [markdown]
# ### Data Statistics

# %%
len(data)
# Out:
# 1000

# %%
# Get the counts of each unique value in 'domain'
domain_counts = data['domain'].value_counts()
domain_percent = domain_counts/len(data) * 100

print(domain_counts)
print(domain_percent)


domain_counts = data['domain'].value_counts()


plt.figure(figsize=(4, 4))
plt.pie(domain_counts, labels=domain_counts.index, autopct='%1.f%%', startangle=140, colors= plt.cm.Paired.colors)
plt.title('Distribution of Domains')
plt.axis('equal') # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# domain
# finance        200
# science        200
# bio_medical    200
# open_domain    200
# education      200
# Name: count, dtype: int64
# domain
# finance        20.0
# science        20.0
# bio_medical    20.0
# open_domain    20.0
# education      20.0
# Name: count, dtype: float64

# %%
# Get the counts of each unique value in 'hallucination_label'
hallucination_counts = data['hallucination_label'].value_counts()
hallucination_percent = hallucination_counts/len(data) * 100

print(hallucination_counts)
print(hallucination_percent)

# Create a bar chart
plt.figure(figsize=(8, 6))
sns.barplot(x=hallucination_percent.index, y=hallucination_percent.values, hue=hallucination_counts.index, palette='pastel', legend=False)
plt.title('Distribution of Hallucination Labels')
plt.xlabel('Hallucination Label')
plt.ylabel('Count')
plt.show()
# Out:
# hallucination_label
# yes        896
# no          80
# unknown     24
# Name: count, dtype: int64
# hallucination_label
# yes        89.6
# no          8.0
# unknown     2.4
# Name: count, dtype: float64

# %% [markdown]
# ### Hallucination Labels by Domain

# %%
hallucination_by_domain = data.groupby('domain')['hallucination_label'].value_counts().unstack(fill_value=0)
display(hallucination_by_domain)
# Out:
# hallucination_label  no  unknown  yes
# domain
# bio_medical           5        9  186
# education            17        3  180
# finance              46        1  153
# open_domain           5       10  185
# science               7        1  192

# %%
hallucination_by_domain.plot(kind='bar', figsize=(12, 7))
plt.title('Hallucination Labels Counts Across Domains')
plt.xlabel('Domain')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Hallucination Label')
plt.tight_layout()
plt.show()

# %%
data = data[data['hallucination_label'] != 'unknown']

# Display the new counts to verify the removal
print(data['hallucination_label'].value_counts())
# Out:
# hallucination_label
# yes    896
# no      80
# Name: count, dtype: int64

# %%
hallucination_by_domain = data.groupby('domain')['hallucination_label'].value_counts().unstack(fill_value=0)
display(hallucination_by_domain)
# Out:
# hallucination_label  no  yes
# domain
# bio_medical           5  186
# education            17  180
# finance              46  153
# open_domain           5  185
# science               7  192

# %%
data.head()
# Out:
#      id                                         user_query  \
# 0  3234  Why would I vote for an increase in the number...
# 1   974  How truthful is the statement that "N348I muta...
# 2  3434               Can CMB305 be used against sarcomas?
# 3  1342  What is the validity of the assertion that "T ...
# 4  2147  How to calculate lump sum required to generate...
#
#                                     chatgpt_response hallucination_label  \
# 0  Voting in favor of an increase in the number o...                  no
# 1  1. The N348I mutation refers to a specific gen...                 yes
# 2  Yes, CMB305 is a potential treatment option fo...                 yes
# 3  1. T regulatory cells (Tregs) are a type of im...                 yes
# 4  To calculate the lump sum required to generate...                 yes
#
#         domain
# 0      finance
# 1      science
# 2  bio_medical
# 3      science
# 4      finance

# %% [markdown]
# ### Token Size of Chat gpt response

# %%
data['chatgpt_response_length'] = data['chatgpt_response'].str.split().apply(len)
#display(data.head())

average_response_length_by_domain = data.groupby('domain')['chatgpt_response_length'].mean().sort_values(ascending=False)
display(average_response_length_by_domain)
# Out:
# domain
# science        280.120603
# finance        187.763819
# bio_medical    125.052356
# education      100.771574
# open_domain     19.073684
# Name: chatgpt_response_length, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=average_response_length_by_domain.index, y=average_response_length_by_domain.values, palette='viridis')
plt.title('Average ChatGPT Response Length by Domain')
plt.xlabel('Domain')
plt.ylabel('Average Response Length')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1932/2527565532.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=average_response_length_by_domain.index, y=average_response_length_by_domain.values, palette='viridis')

# %% [markdown]
# # Balancing the classes from dataset

# %%
data = data[data["hallucination_label"] != "unknown"]

df_yes = data[data["hallucination_label"] == "yes"]
df_no  = data[data["hallucination_label"] == "no"]

n = len(df_no)

data = pd.concat([
    df_yes.sample(n=n, random_state=42),
    df_no
]).sample(frac=1, random_state=42)  # shuffle

# %%
data.head()
# Out:
#        id                                         user_query  \
# 299  2559  How do you calculate return on investment for ...
# 319   434  Can Per Diem deductions include family travel,...
# 710  4063  Which filmmaker has directed more feature film...
# 683  4942  in our two-dimensional molecular picture of ic...
# 165  3375  Does the expense ratio of a fund-of-funds incl...
#
#                                       chatgpt_response hallucination_label  \
# 299  To calculate the return on investment (ROI) fo...                  no
# 319  No, per diem deductions generally do not inclu...                  no
# 710  Stephen Hopkins has directed more feature film...                  no
# 683  In a two-dimensional representation of ice, ev...                 yes
# 165  Yes, the expense ratio of a fund-of-funds incl...                  no
#
#           domain  chatgpt_response_length
# 299      finance                      199
# 319      finance                       76
# 710  open_domain                       10
# 683    education                      157
# 165      finance                      123

# %%
len(data)
# Out:
# 160

# %%
# Get the counts of each unique value in 'hallucination_label'
hallucination_counts = data['hallucination_label'].value_counts()
hallucination_percent = hallucination_counts/len(data) * 100

print(hallucination_counts)
print(hallucination_percent)

# Create a bar chart
plt.figure(figsize=(8, 6))
sns.barplot(x=hallucination_percent.index, y=hallucination_percent.values, hue=hallucination_counts.index, palette='pastel', legend=False)
plt.title('Distribution of Hallucination Labels')
plt.xlabel('Hallucination Label')
plt.ylabel('Count')
plt.show()
# Out:
# hallucination_label
# no     80
# yes    80
# Name: count, dtype: int64
# hallucination_label
# no     50.0
# yes    50.0
# Name: count, dtype: float64

# %%
# Get the counts of each unique value in 'domain'
domain_counts = data['domain'].value_counts()
domain_percent = domain_counts/len(data) * 100

print(domain_counts)
print(domain_percent)


domain_counts = data['domain'].value_counts()


plt.figure(figsize=(4, 4))
plt.pie(domain_counts, labels=domain_counts.index, autopct='%1.f%%', startangle=140, colors= plt.cm.Paired.colors)
plt.title('Distribution of Domains')
plt.axis('equal') # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# domain
# finance        58
# education      30
# bio_medical    26
# open_domain    24
# science        22
# Name: count, dtype: int64
# domain
# finance        36.25
# education      18.75
# bio_medical    16.25
# open_domain    15.00
# science        13.75
# Name: count, dtype: float64

# %%
data['chatgpt_response_length'] = data['chatgpt_response'].str.split().apply(len)
#display(data.head())

average_response_length_by_domain = data.groupby('domain')['chatgpt_response_length'].mean().sort_values(ascending=False)
display(average_response_length_by_domain)
# Out:
# domain
# science        290.363636
# finance        202.534483
# bio_medical    109.076923
# education       67.566667
# open_domain     14.500000
# Name: chatgpt_response_length, dtype: float64

# %% [markdown]
# # Setting Device to use the GPU
#
# We use the T4 GPU in Colab since the heaviest computation for us is the inference of the LLM-Evaluator. Therefore, T4 seem as the better fit.

# %%
import torch

print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# ## Generic LLMModel class to reuse the functionality of extracting the features.

# %%
from transformers import BartForConditionalGeneration, BartTokenizer
from transformers import T5Tokenizer, T5ForConditionalGeneration
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from transformers import BartForConditionalGeneration, PegasusForConditionalGeneration
from transformers import LEDForConditionalGeneration, LEDTokenizer
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from transformers import GPT2LMHeadModel, GPT2Tokenizer
from transformers import LlamaForCausalLM, LlamaTokenizer

import torch
import torch.nn.functional as F


class LLMModel:
    def __init__(self):
        self.model = self.model.to(device)
        pass

    def getName(self) -> str:
        return self.model_name

    def getSanitizedName(self) -> str:
        return self.model_name.replace("/", "__")

    def generate(self, inpt):
        pass

    ##Move in future commits this method to an utils.py
    def truncate_string_by_len(self, s, truncate_len):
        words = s.split()
        truncated_words = words[:-truncate_len] if truncate_len > 0 else words
        return " ".join(truncated_words)

    # Method to get the vocabulary probabilities of the LLM for a given token on the generated text from LLM-Generator
    def getVocabProbsAtPos(self, pos, token_probs):
        sorted_probs, sorted_indices = torch.sort(token_probs[pos, :], descending=True)
        return sorted_probs

    def getMaxLength(self):
        return self.model.config.max_position_embeddings

    # By default knowledge is the empty string. If you want to add extra knowledge you can do it like in the cases of the qa_data.json and dialogue_data.json
    def extractFeatures(
        self,
        knowledge="",
        conditionted_text="",
        generated_text="",
        features_to_extract={},
    ):
        self.model.eval()

        total_len = len(knowledge) + len(conditionted_text) + len(generated_text)
        truncate_len = min(total_len - self.tokenizer.model_max_length, 0)

        # Truncate knowledge in case is too large
        knowledge = self.truncate_string_by_len(knowledge, truncate_len // 2)
        # Truncate text_A in case is too large
        conditionted_text = self.truncate_string_by_len(
            conditionted_text, truncate_len - (truncate_len // 2)
        )

        inputs = self.tokenizer(
            [knowledge + conditionted_text + generated_text],
            return_tensors="pt",
            max_length=self.getMaxLength(),
            truncation=True,
        )

        for key in inputs:
            inputs[key] = inputs[key].to(device)

        with torch.no_grad():
            outputs = self.model(**inputs)
            logits = outputs.logits

        probs = F.softmax(logits, dim=-1)
        probs = probs.to(device)

        tokens_generated_length = len(self.tokenizer.tokenize(generated_text))
        start_index = logits.shape[1] - tokens_generated_length
        conditional_probs = probs[0, start_index :]

        token_ids_generated = inputs["input_ids"][0, start_index :].tolist()
        token_probs_generated = [
            conditional_probs[i, tid].item()
            for i, tid in enumerate(token_ids_generated)
        ]

        tokens_generated = self.tokenizer.convert_ids_to_tokens(token_ids_generated)

        minimum_token_prob = min(token_probs_generated)
        average_token_prob = sum(token_probs_generated) / len(token_probs_generated)

        maximum_diff_with_vocab = -1
        minimum_vocab_extreme_diff = 100000000000

        if features_to_extract["MDVTP"] == True or features_to_extract["MMDVP"] == True:
            size = len(token_probs_generated)
            for pos in range(size):
                vocabProbs = self.getVocabProbsAtPos(pos, conditional_probs)
                maximum_diff_with_vocab = max(
                    [
                        maximum_diff_with_vocab,
                        self.getDiffVocab(vocabProbs, token_probs_generated[pos]),
                    ]
                )
                minimum_vocab_extreme_diff = min(
                    [
                        minimum_vocab_extreme_diff,
                        self.getDiffMaximumWithMinimum(vocabProbs),
                    ]
                )

        # allFeatures = [minimum_token_prob, average_token_prob, maximum_diff_with_vocab, minimum_vocab_extreme_diff]

        allFeatures = {
            "mtp": minimum_token_prob,
            "avgtp": average_token_prob,
            "MDVTP": maximum_diff_with_vocab,
            "MMDVP": minimum_vocab_extreme_diff,
        }

        selectedFeatures = {}
        for key, feature in features_to_extract.items():
            if feature == True:
                selectedFeatures[key] = allFeatures[key]

        return selectedFeatures

    def getDiffVocab(self, vocabProbs, tprob):
        return (vocabProbs[0] - tprob).item()

    def getDiffMaximumWithMinimum(self, vocabProbs):
        return (vocabProbs[0] - vocabProbs[-1]).item()

# %% [markdown]
# ## Definition of the specific Models

# %%
class Gemma(LLMModel):
    def __init__(self):
        self.model_name = "google/gemma-7b-it"
        self.model = AutoModelForCausalLM.from_pretrained(
            self.model_name
        )
        self.tokenizer = AutoTokenizer.from_pretrained(self.model_name)
        super().__init__()


    def generate(self, inpt):
        inputs = self.tokenizer(
            [inpt], max_length=self.getMaxLength(), return_tensors="pt", truncation=True
        )
        summary_ids = self.model.generate(inputs["input_ids"])

        summary = self.tokenizer.decode(summary_ids[0], skip_special_tokens=True)

        return summary


class LLama(LLMModel):
    def __init__(self):
        self.model_name = "meta-llama/Llama-2-7b-chat-hf"
        self.model = AutoModelForCausalLM.from_pretrained(
            self.model_name,
        )
        self.tokenizer = AutoTokenizer.from_pretrained(self.model_name)
        super().__init__()


    def generate(self, inpt):
        inputs = self.tokenizer(
            [inpt], max_length=1024, return_tensors="pt", truncation=True
        )
        summary_ids = self.model.generate(inputs["input_ids"])

        summary = self.tokenizer.decode(summary_ids[0], skip_special_tokens=True)

        return summary


class Opt(LLMModel):
    def __init__(self):
        self.model_name = "facebook/opt-6.7b"
        self.model = AutoModelForCausalLM.from_pretrained(self.model_name)
        self.tokenizer = AutoTokenizer.from_pretrained(self.model_name)
        super().__init__()


    def generate(self, inpt):
        inputs = self.tokenizer(
            [inpt], max_length=self.getMaxLength(), return_tensors="pt", truncation=True
        )
        summary_ids = self.model.generate(inputs["input_ids"])

        summary = self.tokenizer.decode(summary_ids[0], skip_special_tokens=True)

        return summary


class Gptj(LLMModel):
    def __init__(self):
        self.model_name = "EleutherAI/gpt-j-6B"
        self.model = AutoModelForCausalLM.from_pretrained(self.model_name)
        self.tokenizer = AutoTokenizer.from_pretrained(self.model_name)
        super().__init__()


    def generate(self, inpt):
        inputs = self.tokenizer(
            [inpt], max_length=self.getMaxLength(), return_tensors="pt", truncation=True
        )
        summary_ids = self.model.generate(inputs["input_ids"])

        summary = self.tokenizer.decode(summary_ids[0], skip_special_tokens=True)

        return summary


class BartCNN(LLMModel):
    def __init__(self):
        self.model_name = "facebook/bart-large-cnn"
        self.model = BartForConditionalGeneration.from_pretrained(self.model_name)
        self.tokenizer = BartTokenizer.from_pretrained(self.model_name)
        super().__init__()


    def generate(self, inpt):
        inputs = self.tokenizer(
            [inpt], max_length=self.getMaxLength(), return_tensors="pt", truncation=True
        )
        summary_ids = self.model.generate(inputs["input_ids"])

        summary = self.tokenizer.decode(summary_ids[0], skip_special_tokens=True)

        return summary

class GPT2Generator(LLMModel):
    def __init__(self):
        self.model_name = "gpt2-large"
        self.model = GPT2LMHeadModel.from_pretrained(self.model_name)
        self.tokenizer = GPT2Tokenizer.from_pretrained(self.model_name)
        super().__init__()

    def generate(self, inpt):
        inputs = self.tokenizer.encode(
            inpt, return_tensors="pt", max_length=self.getMaxLength(), truncation=True
        )
        output_ids = self.model.generate(
            inputs, max_length=1024, num_return_sequences=1
        )
        output = self.tokenizer.decode(output_ids[0], skip_special_tokens=True)
        return output


class LED(LLMModel):
    def __init__(self):
        self.model_name = "allenai/led-large-16384-arxiv"
        self.model = LEDForConditionalGeneration.from_pretrained(self.model_name)
        self.tokenizer = LEDTokenizer.from_pretrained(self.model_name)
        super().__init__()

    def generate(self, inpt):
        inputs = self.tokenizer(
            [inpt], max_length=self.getMaxLength(), return_tensors="pt", truncation=True
        )
        summary_ids = self.model.generate(inputs["input_ids"])

        summary = self.tokenizer.decode(summary_ids[0], skip_special_tokens=True)

        return summary

# %% [markdown]
# # The Dictionary `features_to_extract` defines which features will be use in this experiment.
#
# ## Features Meaning:
#
# - `mtp` : Take the minimum of the probabilities that the LLM_E gives to the tokens on the generated-text.
# - `avgtp` : Take the average of the probabilities that the LLM_E
# gives to the tokens on the generated-text.
# - `MDVTP` : Take the maximum from all the differences
# between the token with the highest probability
# according to LLM_E at position i and the
# assigned probability from LLM_E to the token at position i in the generated_text.
# - `MMDVP` : Take the maximum from all the differences between the token with the highest probability according to $LLM_E$ at position $i$ ($v^*$) and the token with the lowest probability according to $LLM_E$ at position $i$ ($v^-$).

# %%
feature_to_extract = 'all'

available_features_to_extract = ["mtp", "avgtp", "MDVTP", "MMDVP"]
if feature_to_extract == 'all':
    features_to_extract = {
        feature: True for feature in available_features_to_extract
    }
else:
    features_to_extract = {
        feature: True if feature == feature_to_extract else False
        for feature in available_features_to_extract
    }

features_to_extract
# Out:
# {'mtp': True, 'avgtp': True, 'MDVTP': True, 'MMDVP': True}

# %% [markdown]
# ## Cleaning Cache on GPU to save memory

# %%
import torch
import gc

gc.collect()
torch.cuda.empty_cache()

# %% [markdown]
# ## This cell is to instantiate the model you intend to use for the experiment

# %%
# model = BartCNN()
# model = LED()
model = GPT2Generator()
# model = LLama()
# model = Gemma()
# model = Opt()
# model = Gptj()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:112: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/666 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.25G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/436 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %% [markdown]
# ## This cell creates the dataset separation of `10%` for training and `90%` for testing depending on what task you are addressing. The following explanation is what happens if summarization is the task used. But the same explanation applies to all tasks and also you cand pass as parameter how many data points you want to include in training.
#
# ## Example: The data is separated on 2000 (1000 of document with right summary and 1000 with the same document but with the hallucinated summary). The rest which is 18000 is used to for testing.
#
# ### As expected from previous cells the task string expected are:
# - `summarization`
# - `qa`
# - `dialogue`
# - `general`

# %%
import random


# Load the data depending on the task
def loadRowData(taskName, row, includeKnowledge=False):
    if taskName == "summarization":
        return "", row["document"], row["right_summary"], row["hallucinated_summary"]
    elif taskName == "qa":
        if includeKnowledge:
            return (
                row["knowledge"],
                row["question"],
                row["right_answer"],
                row["hallucinated_answer"],
            )
        else:
            return "", row["question"], row["right_answer"], row["hallucinated_answer"]

    elif taskName == "dialogue":
        if includeKnowledge:
            return (
                row["knowledge"],
                row["dialogue_history"],
                row["right_response"],
                row["hallucinated_response"],
            )
        else:
            return (
                "",
                row["dialogue_history"],
                row["right_response"],
                row["hallucinated_response"],
            )

    elif taskName == "general":
        return (
            "",
            row["user_query"],
            row["chatgpt_response"],
            row["hallucination_label"],
        )

    else:
        raise Exception("Task not supported")


# Adapt the dataset to have a data point of conditioned-text with right-generation and another with the same conditioned-text and tha hallucinated answer.
def adaptDataset(data, taskName):
    datasetAdapted = None
    if taskName == "general":
        # There is data point that is filling the <mask> token but that gives error with some LLMs
        datasetAdapted = [
            (
                (knowledge, document, response, 1)
                if hallu == "yes"
                else (knowledge, document, response, 0)
            )
            for knowledge, document, response, hallu in data
            if "<mask>" not in document and "<mask>" not in response
        ]

    elif taskName == "summarization" or taskName == "qa" or taskName == "dialogue":
        datasetAdapted = [
            (knowledge, document, right, 1)
            for knowledge, document, right, hallu in data
        ] + [
            (knowledge, document, hallu, 0)
            for knowledge, document, right, hallu in data
        ]

    else:
        raise Exception("Task not supported")

    #random.shuffle(datasetAdapted)
    return datasetAdapted

# %%
def splitDataset(
    data: pd.DataFrame,
    taskName: str,
    trainingSize: int,
    valSize: int,
    includeKnowledge=False,
):

    dataset = []
    for _, row in data.iterrows():
        knowledge, text, right, hallu = loadRowData(taskName, row, includeKnowledge)
        dataset.append((knowledge, text, right, hallu))

    #random.shuffle(dataset)

    dataset_train = dataset[:trainingSize]  # Take only trainingSize
    dataset_val = (
        []
    )  # dataset[trainingSize:trainingSize + valSize] # Take only trainingSize
    dataset_test = dataset[trainingSize:]  # Take the rest as testing

    datasetAdaptedTrain = adaptDataset(dataset_train, taskName)
    datasetAdaptedValidation = adaptDataset(dataset_val, taskName)
    datasetAdaptedTest = adaptDataset(dataset_test, taskName)

    X_train = [(x, q, y) for x, q, y, _ in datasetAdaptedTrain]
    Y_train = [z for _, _, _, z in datasetAdaptedTrain]

    X_val = [(x, q, y) for x, q, y, _ in datasetAdaptedValidation]
    Y_val = [z for _, _, _, z in datasetAdaptedValidation]

    X_test = [(x, q, y) for x, q, y, _ in datasetAdaptedTest]
    Y_test = [z for _, _, _, z in datasetAdaptedTest]

    return X_train, Y_train, X_val, Y_val, X_test, Y_test

# %%
includeKnowledge = True
includeConditioned = True

# %%
"""
X_train, Y_train, X_val, Y_val, X_test, Y_test = splitDataset(
    data, task, 2, 0, includeKnowledge=includeKnowledge
)
"""
# Out:
# '\nX_train, Y_train, X_val, Y_val, X_test, Y_test = splitDataset(\n    data, task, 2, 0, includeKnowledge=includeKnowledge\n)\n'

# %%
from sklearn.model_selection import train_test_split

# for now no validation

train_df, test_df = train_test_split(
    data,
    test_size=0.2,  # 20% test
    stratify=data["hallucination_label"],  # VERY important
    random_state=42
)

# %%
def df_to_XY(df):
    X, Y = [], []
    for _, row in df.iterrows():
        X.append(("", row["user_query"], row["chatgpt_response"]))
        Y.append(1 if row["hallucination_label"] == "yes" else 0)
    return X, Y

X_train, Y_train = df_to_XY(train_df)
X_test, Y_test = df_to_XY(test_df)
#X_val, Y_val = df_to_XY(val_df)

X_val = []
Y_val = []

# %%
print(len(X_train), len(Y_train))
print(len(X_val), len(Y_val))
print(len(X_test), len(Y_test))  # verify the sizes look right
# Out:
# 128 128
# 0 0
# 32 32

# %% [markdown]
# ## To Save the separation if needed

# %%
train_df = pd.DataFrame(
    {
        "Knowledge": [x[0] for x in X_train],
        "Conditioned Text": [x[1] for x in X_train],
        "Generated Text": [x[2] for x in X_train],
        "Label": Y_train,
    }
)

val_df = pd.DataFrame(
    {
        "Knowledge": [x[0] for x in X_val],
        "Conditioned Text": [x[1] for x in X_val],
        "Generated Text": [x[2] for x in X_val],
        "Label": Y_val,
    }
)

test_df = pd.DataFrame(
    {
        "Knowledge": [x[0] for x in X_test],
        "Conditioned Text": [x[1] for x in X_test],
        "Generated Text": [x[2] for x in X_test],
        "Label": Y_test,
    }
)

#Export to CSV
if includeKnowledge:
    train_df.to_csv(output_path / (task + '_knowledge_train_data.csv'), index=False)
    test_df.to_csv(output_path / (task + '_knowledge_test_data.csv'), index=False)
else:
    train_df.to_csv(output_path / (task + '_train_data.csv'), index=False)
    val_df.to_csv(output_path / (task + '_val_data.csv'), index=False)
    test_df.to_csv(output_path / (task + '_test_data.csv'), index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1932/614916898.py in <cell line: 0>()
#      28 #Export to CSV
#      29 if includeKnowledge:
# ---> 30     train_df.to_csv(output_path / (task + '_knowledge_train_data.csv'), index=False)
#      31     test_df.to_csv(output_path / (task + '_knowledge_test_data.csv'), index=False)
#      32 else:
#
# NameError: name 'output_path' is not defined

# %%
def getXY(df: pd.DataFrame, includeKnowledge=True, includeConditioned=True):
    X = []
    Y = []

    # Iterate over rows using itertuples
    for _, row in df.iterrows():
        x, c, g = (
            row["Knowledge"] if includeKnowledge else "",
            row["Conditioned Text"] if includeConditioned else "",
            row["Generated Text"],
        # g = (row["Generated Text"]
        )
        y = row["Label"]

        # Append values to respective lists
        X.append((x, c, g))
        # X.append(g)
        Y.append(y)
    return X, Y

# %%
X_train, Y_train = getXY(
    train_df, includeKnowledge=includeKnowledge, includeConditioned=includeConditioned
)
X_val, Y_val = getXY(
    val_df, includeKnowledge=includeKnowledge, includeConditioned=includeConditioned
)
X_test, Y_test = getXY(
    test_df, includeKnowledge=includeKnowledge, includeConditioned=includeConditioned
)

# %%
print(len(X_train), len(Y_train))
print(len(X_val), len(Y_val))
print(len(X_test), len(Y_test))  # verify the sizes look right
# Out:
# 128 128
# 0 0
# 32 32

# %%
X_test[0]
# Out:
# ('',
#  'Who won first title at Forest Hills in 1988, Jorge Lozano or Lindsay Davenport?',
#  'Lindsay Davenport won the first title at Forest Hills in 1988.')

# %%
Y_test[0]
# Out:
# 1

# %% [markdown]
# ## Extracting the features for the Training Data

# %%
import torch
from tqdm import tqdm


def extract_features(
    knowledge: str,
    conditioned_text: str,
    generated_text: str,
    features_to_extract: dict[str, bool],
):
    return model.extractFeatures(
        knowledge, conditioned_text, generated_text, features_to_extract
    )


X_train_features_maps = []

for knowledge, conditioned_text, generated_text in tqdm(X_train, desc="Processing"):
    X_train_features_maps.append(
        extract_features(
            knowledge, conditioned_text, generated_text, features_to_extract
        )
    )
    torch.cuda.empty_cache()  # Clean cache in every step for memory saving.
# Out:
# Processing: 100%|██████████| 128/128 [00:20<00:00,  6.33it/s]

# %%
len(X_train_features_maps)
# Out:
# 128

# %%
X_train_features_maps[0] # for first datapoint
# Out:
# {'mtp': 1.1383743725446038e-08,
#  'avgtp': 0.00024972982792391787,
#  'MDVTP': 0.9952964782714844,
#  'MMDVP': 0.0888335183262825}

# %%
X_train_features = [list(dic.values()) for dic in X_train_features_maps]

# %%
len(X_train_features) # 4 features for each datapoint
# Out:
# 128

# %%
X_train_features[0]
# Out:
# [1.1383743725446038e-08,
#  0.00024972982792391787,
#  0.9952964782714844,
#  0.0888335183262825]

# %% [markdown]
# ## Training Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression(verbose=1)
"""verbose=1 in logistic regression
(specifically in libraries like scikit-learn) enables the display of progress information,
such as iteration counts and loss values, during the model training process.
It is used to monitor convergence, especially during long training sessions."""

clf.fit(X_train_features, Y_train) # len(X_train_features) = len(Y_train)
# Out:
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# LogisticRegression(verbose=1)

# %% [markdown]
# ## Evaluate accuracy of Logistic Regression on the training set

# %%
from sklearn.metrics import accuracy_score

Y_Pred = clf.predict(X_train_features)
# NOTE: this is wrong: should be Y_Pred = clf.predict(X_test_features)
# accuracy = accuracy_score(Y_test, Y_Pred)
# could add: model.predict_proba(X_test)


accuracy = accuracy_score(Y_train, Y_Pred)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 53.12%

# %% [markdown]
# logit(p) = w1 x1 ​+ w2 x2 + w3 x3 + w4 x4 + b

# %%
## they are global weights learbt from entire training data:

# if my features are on different scale:
# from sklearn.preprocessing import StandardScaler

log_odds = clf.coef_[0] # clf.coef_[0] = clf.coef_
odds = np.exp(clf.coef_[0])


""" Safer to know the order:
feature_names = ["mtp", "avgtp", "Mpd", "mps"]

lr_features_log = dict(zip(feature_names, log_odds))
lr_features_no_log = dict(zip(feature_names, odds))
"""


lr_features_log = {k: v for k, v in zip(X_train_features_maps[0].keys(), log_odds)}
lr_features_no_log = {k: v for k, v in zip(X_train_features_maps[0].keys(), odds)}

print("log", lr_features_log)
print("no_log", lr_features_no_log)
# Out:
# log {'mtp': np.float64(7.385657538210723e-07), 'avgtp': np.float64(-0.005374788022415458), 'MDVTP': np.float64(-0.2383431745223512), 'MMDVP': np.float64(-0.10986404719126121)}
# no_log {'mtp': np.float64(1.0000007385660266), 'avgtp': np.float64(0.9946396303073396), 'MDVTP': np.float64(0.7879322464192535), 'MMDVP': np.float64(0.8959559347426866)}

# %% [markdown]
# ## Extracting the Features of the Validation Set

# %%
X_val_features_map = []

for knowledge, conditioned_text, generated_text in tqdm(X_val, desc="Processing"):
    X_val_features_map.append(
        extract_features(
            knowledge, conditioned_text, generated_text, features_to_extract
        )
    )
    torch.cuda.empty_cache()
# Out:
# Processing: 0it [00:00, ?it/s]

# %%
X_val_features = [list(dic.values()) for dic in X_val_features_map]

# %% [markdown]
# ## Uncomment next cell if you have a validation set and you want to see LR accuracy on it.

# %%
# from sklearn.metrics import accuracy_score

# Y_Pred = clf.predict(X_val_features)

# accuracy = accuracy_score(Y_val, Y_Pred)
# print(f"Accuracy: {accuracy * 100:.2f}%")

# %% [markdown]
# ## Extracting the Features of the Test Set

# %%
from tqdm import tqdm

X_test_features_map = []

for knowledge, conditioned_text, generated_text in tqdm(X_test, desc="Processing"):
    X_test_features_map.append(
        extract_features(
            knowledge, conditioned_text, generated_text, features_to_extract
        )
    )
    torch.cuda.empty_cache()
# Out:
# Processing: 100%|██████████| 32/32 [00:04<00:00,  7.25it/s]

# %%
X_test_features = [list(dic.values()) for dic in X_test_features_map]

# %% [markdown]
# ## Evaluate accuracy of the LogisticRegression on the testing set

# %%
from sklearn.metrics import accuracy_score

Y_Pred = clf.predict(X_test_features)

lr_accuracy = accuracy_score(Y_test, Y_Pred)
print(f"Accuracy: {lr_accuracy * 100:.2f}%")
# Out:
# Accuracy: 37.50%

# %%
log_odds = clf.coef_[0]
pd.DataFrame(log_odds, X_train_features_maps[0].keys(), columns=["coef"]).sort_values(
    by="coef", ascending=False
)
# Out:
#                coef
# mtp    7.385658e-07
# avgtp -5.374788e-03
# MMDVP -1.098640e-01
# MDVTP -2.383432e-01

# %%
odds = np.exp(clf.coef_[0])
pd.DataFrame(odds, X_train_features_maps[0].keys(), columns=["coef"]).sort_values(
    by="coef", ascending=False
)
# Out:
#            coef
# mtp    1.000001
# avgtp  0.994640
# MMDVP  0.895956
# MDVTP  0.787932

# %% [markdown]
# ## Simple Dense NN

# %%
import torch.nn as nn


class SimpleDenseNet(nn.Module):
    def __init__(self, input_dim: int, hidden_dim: int, output_dim=1, dropout_prob=0.3):
        super(SimpleDenseNet, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, output_dim)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        x = self.relu(x)
        x = self.fc3(x)
        x = self.sigmoid(x)
        return x

# %%
denseModel = SimpleDenseNet(
    input_dim=np.array([v for v in features_to_extract.values()]).sum(), hidden_dim=512
).to(device)

# %% [markdown]
# # Code declaring and computing all the metrics to measure

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    roc_auc_score,
    precision_recall_curve,
    auc
)


def compute_metrics(model, input_tensor, true_labels):
    with torch.no_grad(): # torch.no_grad : disable gradient calculation
        outputs = model(input_tensor)
        predicted_probs = torch.sigmoid(outputs).cpu().numpy()
        predicted = (outputs > 0.5).float().cpu().numpy()

        true_labels = true_labels.cpu().numpy()

        acc = accuracy_score(true_labels, predicted)
        precision = precision_score(true_labels, predicted)
        recall = recall_score(true_labels, predicted)
        f1 = f1_score(true_labels, predicted)

        precision_negative = precision_score(true_labels, predicted, pos_label=0)
        recall_negative = recall_score(true_labels, predicted, pos_label=0)
        f1_negative = f1_score(true_labels, predicted, pos_label=0)

        tn, fp, fn, tp = confusion_matrix(true_labels, predicted).ravel()
        roc_auc = roc_auc_score(true_labels, predicted_probs)

        P, R, thre = precision_recall_curve(true_labels, predicted, pos_label=1)
        pr_auc = auc(R, P)

        roc_auc_negative = roc_auc_score(
            true_labels, 1 - predicted_probs
        )  # If predicted_probs is the probability of the positive class
        P_neg, R_neg, _ = precision_recall_curve(true_labels, predicted, pos_label=0)
        pr_auc_negative = auc(R_neg, P_neg)

        return {
            "Accuracy": acc,
            "Precision": precision,
            "Recall": recall,
            "F1": f1,
            "TP": tp,
            "TN": tn,
            "FP": fp,
            "FN": fn,
            "ROC AUC": roc_auc,
            "PR AUC": pr_auc,
            "Precision-Negative": precision_negative,
            "Recall-Negative": recall_negative,
            "F1-Negative": f1_negative,
            "ROC AUC-Negative": roc_auc_negative,
            "PR AUC-Negative": pr_auc_negative,
        }

# %% [markdown]
# ## Code for training the Dense Model and getting the result of all metrics corresponding to the Testing Set.

# %%
def compute_accuracy(model, input_tensor, true_labels):
    with torch.no_grad():
        outputs = model(input_tensor)
        predicted = (outputs > 0.5).float()
        correct = (predicted == true_labels).float().sum()
        accuracy = correct / len(true_labels)
        return accuracy.item()


X_train_tensor = torch.tensor(X_train_features, dtype=torch.float32).to(device)
Y_train_tensor = torch.tensor(Y_train, dtype=torch.float32).view(-1, 1).to(device)

print(X_train_tensor.shape, Y_train_tensor.shape)

# Define loss and optimizer
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(denseModel.parameters(), lr=0.001)

bestValAcc = 0
# Training loop
num_epochs = 20000
for epoch in range(num_epochs):
    denseModel.train()
    optimizer.zero_grad()
    outputs = denseModel(X_train_tensor)
    loss = criterion(outputs, Y_train_tensor)
    loss.backward()
    optimizer.step()

    # Compute training accuracy
    train_accuracy = compute_accuracy(denseModel, X_train_tensor, Y_train_tensor)

    # Uncomment this if you want to see how the accuracy of testing improves during the training process.
    ##Compute testing accuracy
    # X_val_tensor = torch.tensor(X_val_features, dtype=torch.float32).to(device)
    # Y_val_tensor = torch.tensor(Y_val, dtype=torch.float32).view(-1, 1).to(device)

    # val_accuracy = compute_accuracy(denseModel, X_val_tensor, Y_val_tensor)

    # if bestValAcc < val_accuracy:
    #     bestValAcc = val_accuracy
    #     print(f'Saving model with best validation accuracy ...')
    #     torch.save(denseModel.state_dict(), 'llama-' + task + '-best-model')

    if (epoch + 1) % 10 == 0:
        print(
            f"Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}, Training Accuracy: {train_accuracy:.4f}"
        )  # , "Validation Accuracy": {val_accuracy:.4f}')
# Out:
# torch.Size([128, 4]) torch.Size([128, 1])
# Epoch [10/20000], Loss: 0.6959, Training Accuracy: 0.5078
# Epoch [20/20000], Loss: 0.6910, Training Accuracy: 0.5078
# Epoch [30/20000], Loss: 0.6900, Training Accuracy: 0.5234
# Epoch [40/20000], Loss: 0.6890, Training Accuracy: 0.5469
# Epoch [50/20000], Loss: 0.6878, Training Accuracy: 0.5391
# Epoch [60/20000], Loss: 0.6868, Training Accuracy: 0.5312
# Epoch [70/20000], Loss: 0.6858, Training Accuracy: 0.5469
# Epoch [80/20000], Loss: 0.6850, Training Accuracy: 0.5625
# Epoch [90/20000], Loss: 0.6842, Training Accuracy: 0.5703
# Epoch [100/20000], Loss: 0.6835, Training Accuracy: 0.5859
# Epoch [110/20000], Loss: 0.6831, Training Accuracy: 0.5781
# Epoch [120/20000], Loss: 0.6827, Training Accuracy: 0.5781
# Epoch [130/20000], Loss: 0.6824, Training Accuracy: 0.5781
# Epoch [140/20000], Loss: 0.6822, Training Accuracy: 0.5781
# Epoch [150/20000], Loss: 0.6820, Training Accuracy: 0.5781
# Epoch [160/20000], Loss: 0.6819, Training Accuracy: 0.5781
# Epoch [170/20000], Loss: 0.6817, Training Accuracy: 0.5781
# Epoch [180/20000], Loss: 0.6815, Training Accuracy: 0.5781
# Epoch [190/20000], Loss: 0.6813, Training Accuracy: 0.5859
# Epoch [200/20000], Loss: 0.6811, Training Accuracy: 0.5859
# Epoch [210/20000], Loss: 0.6810, Training Accuracy: 0.5469
# Epoch [220/20000], Loss: 0.6806, Training Accuracy: 0.5703
# Epoch [230/20000], Loss: 0.6804, Training Accuracy: 0.5547
# Epoch [240/20000], Loss: 0.6801, Training Accuracy: 0.5703
# Epoch [250/20000], Loss: 0.6798, Training Accuracy: 0.5625
# Epoch [260/20000], Loss: 0.6795, Training Accuracy: 0.5781
# Epoch [270/20000], Loss: 0.6792, Training Accuracy: 0.5625
# Epoch [280/20000], Loss: 0.6797, Training Accuracy: 0.5547
# Epoch [290/20000], Loss: 0.6787, Training Accuracy: 0.5625
# Epoch [300/20000], Loss: 0.6785, Training Accuracy: 0.5781
# Epoch [310/20000], Loss: 0.6782, Training Accuracy: 0.5781
# Epoch [320/20000], Loss: 0.6778, Training Accuracy: 0.5781
# Epoch [330/20000], Loss: 0.6775, Training Accuracy: 0.5781
# Epoch [340/20000], Loss: 0.6772, Training Accuracy: 0.5703
# Epoch [350/20000], Loss: 0.6770, Training Accuracy: 0.5703
# Epoch [360/20000], Loss: 0.6767, Training Accuracy: 0.5703
# Epoch [370/20000], Loss: 0.6762, Training Accuracy: 0.5703
# Epoch [380/20000], Loss: 0.6757, Training Accuracy: 0.5781
# Epoch [390/20000], Loss: 0.6763, Training Accuracy: 0.5625
# Epoch [400/20000], Loss: 0.6758, Training Accuracy: 0.5625
# Epoch [410/20000], Loss: 0.6747, Training Accuracy: 0.5781
# Epoch [420/20000], Loss: 0.6743, Training Accuracy: 0.5703
# Epoch [430/20000], Loss: 0.6742, Training Accuracy: 0.5781
# Epoch [440/20000], Loss: 0.6737, Training Accuracy: 0.5703
# Epoch [450/20000], Loss: 0.6732, Training Accuracy: 0.5781
# Epoch [460/20000], Loss: 0.6741, Training Accuracy: 0.5781
# Epoch [470/20000], Loss: 0.6726, Training Accuracy: 0.5781
# Epoch [480/20000], Loss: 0.6725, Training Accuracy: 0.5703
# Epoch [490/20000], Loss: 0.6718, Training Accuracy: 0.5938
# Epoch [500/20000], Loss: 0.6781, Training Accuracy: 0.5312
# Epoch [510/20000], Loss: 0.6725, Training Accuracy: 0.5938
# Epoch [520/20000], Loss: 0.6714, Training Accuracy: 0.5781
# Epoch [530/20000], Loss: 0.6707, Training Accuracy: 0.5938
# Epoch [540/20000], Loss: 0.6702, Training Accuracy: 0.5938
# Epoch [550/20000], Loss: 0.6698, Training Accuracy: 0.5938
# Epoch [560/20000], Loss: 0.6695, Training Accuracy: 0.5938
# Epoch [570/20000], Loss: 0.6713, Training Accuracy: 0.5234
# Epoch [580/20000], Loss: 0.6700, Training Accuracy: 0.6172
# Epoch [590/20000], Loss: 0.6686, Training Accuracy: 0.5938
# Epoch [600/20000], Loss: 0.6681, Training Accuracy: 0.6094
# Epoch [610/20000], Loss: 0.6679, Training Accuracy: 0.6250
# Epoch [620/20000], Loss: 0.6674, Training Accuracy: 0.6094
# Epoch [630/20000], Loss: 0.6671, Training Accuracy: 0.5938
# Epoch [640/20000], Loss: 0.6674, Training Accuracy: 0.5859
# Epoch [650/20000], Loss: 0.6668, Training Accuracy: 0.5469
# Epoch [660/20000], Loss: 0.6666, Training Accuracy: 0.6094
# Epoch [670/20000], Loss: 0.6657, Training Accuracy: 0.6016
# Epoch [680/20000], Loss: 0.6652, Training Accuracy: 0.6172
# Epoch [690/20000], Loss: 0.6647, Training Accuracy: 0.6172
# Epoch [700/20000], Loss: 0.6642, Training Accuracy: 0.6016
# Epoch [710/20000], Loss: 0.6669, Training Accuracy: 0.6016
# Epoch [720/20000], Loss: 0.6663, Training Accuracy: 0.5781
# Epoch [730/20000], Loss: 0.6642, Training Accuracy: 0.6172
# Epoch [740/20000], Loss: 0.6632, Training Accuracy: 0.6172
# Epoch [750/20000], Loss: 0.6623, Training Accuracy: 0.6016
# Epoch [760/20000], Loss: 0.6619, Training Accuracy: 0.6016
# Epoch [770/20000], Loss: 0.6615, Training Accuracy: 0.5938
# Epoch [780/20000], Loss: 0.6704, Training Accuracy: 0.5781
# Epoch [790/20000], Loss: 0.6623, Training Accuracy: 0.6094
# Epoch [800/20000], Loss: 0.6606, Training Accuracy: 0.5938
# Epoch [810/20000], Loss: 0.6597, Training Accuracy: 0.5938
# Epoch [820/20000], Loss: 0.6594, Training Accuracy: 0.6172
# Epoch [830/20000], Loss: 0.6589, Training Accuracy: 0.6016
# Epoch [840/20000], Loss: 0.6583, Training Accuracy: 0.6172
# Epoch [850/20000], Loss: 0.6580, Training Accuracy: 0.6016
# Epoch [860/20000], Loss: 0.6663, Training Accuracy: 0.5469
# Epoch [870/20000], Loss: 0.6586, Training Accuracy: 0.5781
# Epoch [880/20000], Loss: 0.6585, Training Accuracy: 0.5938
# Epoch [890/20000], Loss: 0.6570, Training Accuracy: 0.6172
# Epoch [900/20000], Loss: 0.6561, Training Accuracy: 0.6172
# Epoch [910/20000], Loss: 0.6555, Training Accuracy: 0.6016
# Epoch [920/20000], Loss: 0.6549, Training Accuracy: 0.6016
# Epoch [930/20000], Loss: 0.6544, Training Accuracy: 0.6094
# Epoch [940/20000], Loss: 0.6539, Training Accuracy: 0.6094
# Epoch [950/20000], Loss: 0.6534, Training Accuracy: 0.6016
# Epoch [960/20000], Loss: 0.6529, Training Accuracy: 0.6016
# Epoch [970/20000], Loss: 0.6524, Training Accuracy: 0.6016
# Epoch [980/20000], Loss: 0.6523, Training Accuracy: 0.6016
# Epoch [990/20000], Loss: 0.6530, Training Accuracy: 0.5938
# Epoch [1000/20000], Loss: 0.6539, Training Accuracy: 0.6016
# Epoch [1010/20000], Loss: 0.6519, Training Accuracy: 0.5938
# Epoch [1020/20000], Loss: 0.6503, Training Accuracy: 0.5938
# Epoch [1030/20000], Loss: 0.6498, Training Accuracy: 0.5938
# Epoch [1040/20000], Loss: 0.6492, Training Accuracy: 0.6172
# Epoch [1050/20000], Loss: 0.6485, Training Accuracy: 0.5938
# Epoch [1060/20000], Loss: 0.6562, Training Accuracy: 0.5859
# Epoch [1070/20000], Loss: 0.6524, Training Accuracy: 0.5938
# Epoch [1080/20000], Loss: 0.6496, Training Accuracy: 0.5938
# Epoch [1090/20000], Loss: 0.6477, Training Accuracy: 0.5938
# Epoch [1100/20000], Loss: 0.6464, Training Accuracy: 0.6016
# Epoch [1110/20000], Loss: 0.6459, Training Accuracy: 0.6094
# Epoch [1120/20000], Loss: 0.6453, Training Accuracy: 0.6094
# Epoch [1130/20000], Loss: 0.6448, Training Accuracy: 0.5938
# Epoch [1140/20000], Loss: 0.6593, Training Accuracy: 0.5547
# Epoch [1150/20000], Loss: 0.6444, Training Accuracy: 0.5859
# Epoch [1160/20000], Loss: 0.6436, Training Accuracy: 0.5859
# Epoch [1170/20000], Loss: 0.6432, Training Accuracy: 0.5938
# Epoch [1180/20000], Loss: 0.6428, Training Accuracy: 0.6016
# Epoch [1190/20000], Loss: 0.6424, Training Accuracy: 0.5938
# Epoch [1200/20000], Loss: 0.6419, Training Accuracy: 0.6016
# Epoch [1210/20000], Loss: 0.6413, Training Accuracy: 0.5938
# Epoch [1220/20000], Loss: 0.6408, Training Accuracy: 0.6016
# Epoch [1230/20000], Loss: 0.6572, Training Accuracy: 0.5781
# Epoch [1240/20000], Loss: 0.6407, Training Accuracy: 0.6094
# Epoch [1250/20000], Loss: 0.6400, Training Accuracy: 0.6094
# Epoch [1260/20000], Loss: 0.6395, Training Accuracy: 0.5938
# Epoch [1270/20000], Loss: 0.6391, Training Accuracy: 0.6016
# Epoch [1280/20000], Loss: 0.6386, Training Accuracy: 0.6016
# Epoch [1290/20000], Loss: 0.6380, Training Accuracy: 0.5938
# Epoch [1300/20000], Loss: 0.6376, Training Accuracy: 0.6016
# Epoch [1310/20000], Loss: 0.6375, Training Accuracy: 0.6016
# Epoch [1320/20000], Loss: 0.6433, Training Accuracy: 0.6016
# Epoch [1330/20000], Loss: 0.6445, Training Accuracy: 0.5625
# Epoch [1340/20000], Loss: 0.6364, Training Accuracy: 0.6172
# Epoch [1350/20000], Loss: 0.6366, Training Accuracy: 0.6016
# Epoch [1360/20000], Loss: 0.6357, Training Accuracy: 0.6094
# Epoch [1370/20000], Loss: 0.6352, Training Accuracy: 0.6094
# Epoch [1380/20000], Loss: 0.6346, Training Accuracy: 0.5938
# Epoch [1390/20000], Loss: 0.6342, Training Accuracy: 0.5938
# Epoch [1400/20000], Loss: 0.6399, Training Accuracy: 0.6016
# Epoch [1410/20000], Loss: 0.6383, Training Accuracy: 0.5781
# Epoch [1420/20000], Loss: 0.6344, Training Accuracy: 0.5938
# Epoch [1430/20000], Loss: 0.6339, Training Accuracy: 0.5938
# Epoch [1440/20000], Loss: 0.6331, Training Accuracy: 0.6172
# Epoch [1450/20000], Loss: 0.6325, Training Accuracy: 0.5938
# Epoch [1460/20000], Loss: 0.6320, Training Accuracy: 0.6172
# Epoch [1470/20000], Loss: 0.6314, Training Accuracy: 0.6172
# Epoch [1480/20000], Loss: 0.6490, Training Accuracy: 0.5781
# Epoch [1490/20000], Loss: 0.6359, Training Accuracy: 0.6094
# Epoch [1500/20000], Loss: 0.6339, Training Accuracy: 0.5938
# Epoch [1510/20000], Loss: 0.6303, Training Accuracy: 0.6016
# Epoch [1520/20000], Loss: 0.6299, Training Accuracy: 0.5938
# Epoch [1530/20000], Loss: 0.6293, Training Accuracy: 0.6094
# Epoch [1540/20000], Loss: 0.6289, Training Accuracy: 0.6094
# Epoch [1550/20000], Loss: 0.6285, Training Accuracy: 0.6094
# Epoch [1560/20000], Loss: 0.6282, Training Accuracy: 0.6172
# Epoch [1570/20000], Loss: 0.6424, Training Accuracy: 0.5859
# Epoch [1580/20000], Loss: 0.6381, Training Accuracy: 0.5938
# Epoch [1590/20000], Loss: 0.6300, Training Accuracy: 0.5938
# Epoch [1600/20000], Loss: 0.6270, Training Accuracy: 0.6094
# Epoch [1610/20000], Loss: 0.6270, Training Accuracy: 0.6094
# Epoch [1620/20000], Loss: 0.6263, Training Accuracy: 0.6094
# Epoch [1630/20000], Loss: 0.6262, Training Accuracy: 0.5938
# Epoch [1640/20000], Loss: 0.6259, Training Accuracy: 0.6016
# Epoch [1650/20000], Loss: 0.6261, Training Accuracy: 0.6172
# Epoch [1660/20000], Loss: 0.6282, Training Accuracy: 0.5938
# Epoch [1670/20000], Loss: 0.6280, Training Accuracy: 0.6094
# Epoch [1680/20000], Loss: 0.6268, Training Accuracy: 0.5938
# Epoch [1690/20000], Loss: 0.6240, Training Accuracy: 0.6016
# Epoch [1700/20000], Loss: 0.6246, Training Accuracy: 0.6094
# Epoch [1710/20000], Loss: 0.6326, Training Accuracy: 0.5938
# Epoch [1720/20000], Loss: 0.6280, Training Accuracy: 0.5938
# Epoch [1730/20000], Loss: 0.6246, Training Accuracy: 0.6172
# Epoch [1740/20000], Loss: 0.6225, Training Accuracy: 0.5938
# Epoch [1750/20000], Loss: 0.6232, Training Accuracy: 0.6250
# Epoch [1760/20000], Loss: 0.6232, Training Accuracy: 0.6172
# Epoch [1770/20000], Loss: 0.6289, Training Accuracy: 0.6094
# Epoch [1780/20000], Loss: 0.6240, Training Accuracy: 0.6172
# Epoch [1790/20000], Loss: 0.6218, Training Accuracy: 0.6250
# Epoch [1800/20000], Loss: 0.6205, Training Accuracy: 0.6094
# Epoch [1810/20000], Loss: 0.6246, Training Accuracy: 0.5859
# Epoch [1820/20000], Loss: 0.6211, Training Accuracy: 0.6172
# Epoch [1830/20000], Loss: 0.6230, Training Accuracy: 0.6250
# Epoch [1840/20000], Loss: 0.6202, Training Accuracy: 0.6094
# Epoch [1850/20000], Loss: 0.6213, Training Accuracy: 0.5938
# Epoch [1860/20000], Loss: 0.6209, Training Accuracy: 0.6016
# Epoch [1870/20000], Loss: 0.6218, Training Accuracy: 0.6016
# Epoch [1880/20000], Loss: 0.6182, Training Accuracy: 0.6172
# Epoch [1890/20000], Loss: 0.6192, Training Accuracy: 0.6016
# Epoch [1900/20000], Loss: 0.6258, Training Accuracy: 0.6016
# Epoch [1910/20000], Loss: 0.6194, Training Accuracy: 0.6016
# Epoch [1920/20000], Loss: 0.6174, Training Accuracy: 0.6250
# Epoch [1930/20000], Loss: 0.6171, Training Accuracy: 0.6094
# Epoch [1940/20000], Loss: 0.6162, Training Accuracy: 0.6172
# Epoch [1950/20000], Loss: 0.6169, Training Accuracy: 0.6406
# Epoch [1960/20000], Loss: 0.6307, Training Accuracy: 0.5625
# Epoch [1970/20000], Loss: 0.6174, Training Accuracy: 0.6016
# Epoch [1980/20000], Loss: 0.6151, Training Accuracy: 0.6094
# Epoch [1990/20000], Loss: 0.6149, Training Accuracy: 0.6172
# Epoch [2000/20000], Loss: 0.6145, Training Accuracy: 0.6250
# Epoch [2010/20000], Loss: 0.6153, Training Accuracy: 0.6328
# Epoch [2020/20000], Loss: 0.6186, Training Accuracy: 0.6172
# Epoch [2030/20000], Loss: 0.6149, Training Accuracy: 0.5938
# Epoch [2040/20000], Loss: 0.6160, Training Accuracy: 0.6250
# Epoch [2050/20000], Loss: 0.6140, Training Accuracy: 0.6172
# Epoch [2060/20000], Loss: 0.6144, Training Accuracy: 0.6406
# Epoch [2070/20000], Loss: 0.6225, Training Accuracy: 0.5703
# Epoch [2080/20000], Loss: 0.6142, Training Accuracy: 0.6328
# Epoch [2090/20000], Loss: 0.6119, Training Accuracy: 0.6250
# Epoch [2100/20000], Loss: 0.6140, Training Accuracy: 0.6250
# Epoch [2110/20000], Loss: 0.6126, Training Accuracy: 0.6250
# Epoch [2120/20000], Loss: 0.6142, Training Accuracy: 0.6094
# Epoch [2130/20000], Loss: 0.6162, Training Accuracy: 0.6250
# Epoch [2140/20000], Loss: 0.6141, Training Accuracy: 0.6328
# Epoch [2150/20000], Loss: 0.6106, Training Accuracy: 0.6094
# Epoch [2160/20000], Loss: 0.6124, Training Accuracy: 0.6250
# Epoch [2170/20000], Loss: 0.6096, Training Accuracy: 0.6406
# Epoch [2180/20000], Loss: 0.6107, Training Accuracy: 0.6406
# Epoch [2190/20000], Loss: 0.6218, Training Accuracy: 0.6250
# Epoch [2200/20000], Loss: 0.6103, Training Accuracy: 0.6328
# Epoch [2210/20000], Loss: 0.6096, Training Accuracy: 0.6172
# Epoch [2220/20000], Loss: 0.6092, Training Accuracy: 0.6250
# Epoch [2230/20000], Loss: 0.6084, Training Accuracy: 0.6250
# Epoch [2240/20000], Loss: 0.6078, Training Accuracy: 0.6406
# Epoch [2250/20000], Loss: 0.6080, Training Accuracy: 0.6172
# Epoch [2260/20000], Loss: 0.6162, Training Accuracy: 0.5859
# Epoch [2270/20000], Loss: 0.6072, Training Accuracy: 0.6328
# Epoch [2280/20000], Loss: 0.6068, Training Accuracy: 0.6250
# Epoch [2290/20000], Loss: 0.6070, Training Accuracy: 0.6328
# Epoch [2300/20000], Loss: 0.6073, Training Accuracy: 0.6250
# Epoch [2310/20000], Loss: 0.6070, Training Accuracy: 0.6250
# Epoch [2320/20000], Loss: 0.6095, Training Accuracy: 0.6094
# Epoch [2330/20000], Loss: 0.6107, Training Accuracy: 0.6250
# Epoch [2340/20000], Loss: 0.6075, Training Accuracy: 0.6406
# Epoch [2350/20000], Loss: 0.6056, Training Accuracy: 0.6406
# Epoch [2360/20000], Loss: 0.6051, Training Accuracy: 0.6328
# Epoch [2370/20000], Loss: 0.6161, Training Accuracy: 0.6562
# Epoch [2380/20000], Loss: 0.6053, Training Accuracy: 0.6250
# Epoch [2390/20000], Loss: 0.6044, Training Accuracy: 0.6484
# Epoch [2400/20000], Loss: 0.6058, Training Accuracy: 0.6328
# Epoch [2410/20000], Loss: 0.6041, Training Accuracy: 0.6484
# Epoch [2420/20000], Loss: 0.6065, Training Accuracy: 0.6094
# Epoch [2430/20000], Loss: 0.6093, Training Accuracy: 0.6094
# Epoch [2440/20000], Loss: 0.6072, Training Accuracy: 0.6406
# Epoch [2450/20000], Loss: 0.6029, Training Accuracy: 0.6406
# Epoch [2460/20000], Loss: 0.6059, Training Accuracy: 0.6094
# Epoch [2470/20000], Loss: 0.6031, Training Accuracy: 0.6406
# Epoch [2480/20000], Loss: 0.6029, Training Accuracy: 0.6406
# Epoch [2490/20000], Loss: 0.6167, Training Accuracy: 0.6562
# Epoch [2500/20000], Loss: 0.6059, Training Accuracy: 0.6406
# Epoch [2510/20000], Loss: 0.6024, Training Accuracy: 0.6328
# Epoch [2520/20000], Loss: 0.6019, Training Accuracy: 0.6562
# Epoch [2530/20000], Loss: 0.6011, Training Accuracy: 0.6484
# Epoch [2540/20000], Loss: 0.6009, Training Accuracy: 0.6328
# Epoch [2550/20000], Loss: 0.6096, Training Accuracy: 0.6016
# Epoch [2560/20000], Loss: 0.6010, Training Accuracy: 0.6328
# Epoch [2570/20000], Loss: 0.6013, Training Accuracy: 0.6250
# Epoch [2580/20000], Loss: 0.6012, Training Accuracy: 0.6328
# Epoch [2590/20000], Loss: 0.6005, Training Accuracy: 0.6562
# Epoch [2600/20000], Loss: 0.5999, Training Accuracy: 0.6406
# Epoch [2610/20000], Loss: 0.6006, Training Accuracy: 0.6406
# Epoch [2620/20000], Loss: 0.6020, Training Accuracy: 0.6250
# Epoch [2630/20000], Loss: 0.6051, Training Accuracy: 0.6250
# Epoch [2640/20000], Loss: 0.5994, Training Accuracy: 0.6484
# Epoch [2650/20000], Loss: 0.5995, Training Accuracy: 0.6484
# Epoch [2660/20000], Loss: 0.6100, Training Accuracy: 0.6250
# Epoch [2670/20000], Loss: 0.5995, Training Accuracy: 0.6250
# Epoch [2680/20000], Loss: 0.5993, Training Accuracy: 0.6484
# Epoch [2690/20000], Loss: 0.5989, Training Accuracy: 0.6406
# Epoch [2700/20000], Loss: 0.6013, Training Accuracy: 0.6328
# Epoch [2710/20000], Loss: 0.6005, Training Accuracy: 0.6328
# Epoch [2720/20000], Loss: 0.5973, Training Accuracy: 0.6406
# Epoch [2730/20000], Loss: 0.5976, Training Accuracy: 0.6484
# Epoch [2740/20000], Loss: 0.6184, Training Accuracy: 0.6094
# Epoch [2750/20000], Loss: 0.6045, Training Accuracy: 0.6328
# Epoch [2760/20000], Loss: 0.5999, Training Accuracy: 0.6328
# Epoch [2770/20000], Loss: 0.5975, Training Accuracy: 0.6172
# Epoch [2780/20000], Loss: 0.5963, Training Accuracy: 0.6484
# Epoch [2790/20000], Loss: 0.5977, Training Accuracy: 0.6328
# Epoch [2800/20000], Loss: 0.5990, Training Accuracy: 0.6328
# Epoch [2810/20000], Loss: 0.5973, Training Accuracy: 0.6328
# Epoch [2820/20000], Loss: 0.5995, Training Accuracy: 0.6250
# Epoch [2830/20000], Loss: 0.5973, Training Accuracy: 0.6250
# Epoch [2840/20000], Loss: 0.5966, Training Accuracy: 0.6406
# Epoch [2850/20000], Loss: 0.6024, Training Accuracy: 0.6484
# Epoch [2860/20000], Loss: 0.5947, Training Accuracy: 0.6484
# Epoch [2870/20000], Loss: 0.5976, Training Accuracy: 0.6094
# Epoch [2880/20000], Loss: 0.5962, Training Accuracy: 0.6250
# Epoch [2890/20000], Loss: 0.5951, Training Accuracy: 0.6250
# Epoch [2900/20000], Loss: 0.6046, Training Accuracy: 0.6484
# Epoch [2910/20000], Loss: 0.5938, Training Accuracy: 0.6562
# Epoch [2920/20000], Loss: 0.5949, Training Accuracy: 0.6641
# Epoch [2930/20000], Loss: 0.5959, Training Accuracy: 0.6172
# Epoch [2940/20000], Loss: 0.5940, Training Accuracy: 0.6406
# Epoch [2950/20000], Loss: 0.5935, Training Accuracy: 0.6562
# Epoch [2960/20000], Loss: 0.6011, Training Accuracy: 0.6328
# Epoch [2970/20000], Loss: 0.5930, Training Accuracy: 0.6562
# Epoch [2980/20000], Loss: 0.5932, Training Accuracy: 0.6484
# Epoch [2990/20000], Loss: 0.5943, Training Accuracy: 0.6406
# Epoch [3000/20000], Loss: 0.5933, Training Accuracy: 0.6562
# Epoch [3010/20000], Loss: 0.5921, Training Accuracy: 0.6484
# Epoch [3020/20000], Loss: 0.5940, Training Accuracy: 0.6172
# Epoch [3030/20000], Loss: 0.6017, Training Accuracy: 0.6250
# Epoch [3040/20000], Loss: 0.5934, Training Accuracy: 0.6406
# Epoch [3050/20000], Loss: 0.5920, Training Accuracy: 0.6562
# Epoch [3060/20000], Loss: 0.5923, Training Accuracy: 0.6328
# Epoch [3070/20000], Loss: 0.5995, Training Accuracy: 0.6250
# Epoch [3080/20000], Loss: 0.5914, Training Accuracy: 0.6562
# Epoch [3090/20000], Loss: 0.5958, Training Accuracy: 0.6328
# Epoch [3100/20000], Loss: 0.5909, Training Accuracy: 0.6484
# Epoch [3110/20000], Loss: 0.5916, Training Accuracy: 0.6406
# Epoch [3120/20000], Loss: 0.5996, Training Accuracy: 0.6250
# Epoch [3130/20000], Loss: 0.5905, Training Accuracy: 0.6484
# Epoch [3140/20000], Loss: 0.5941, Training Accuracy: 0.6328
# Epoch [3150/20000], Loss: 0.5902, Training Accuracy: 0.6406
# Epoch [3160/20000], Loss: 0.5945, Training Accuracy: 0.6328
# Epoch [3170/20000], Loss: 0.5918, Training Accuracy: 0.6406
# Epoch [3180/20000], Loss: 0.5895, Training Accuracy: 0.6562
# Epoch [3190/20000], Loss: 0.5998, Training Accuracy: 0.6562
# Epoch [3200/20000], Loss: 0.5896, Training Accuracy: 0.6484
# Epoch [3210/20000], Loss: 0.5908, Training Accuracy: 0.6328
# Epoch [3220/20000], Loss: 0.5919, Training Accuracy: 0.6406
# Epoch [3230/20000], Loss: 0.5889, Training Accuracy: 0.6406
# Epoch [3240/20000], Loss: 0.5913, Training Accuracy: 0.6250
# Epoch [3250/20000], Loss: 0.5935, Training Accuracy: 0.6328
# Epoch [3260/20000], Loss: 0.5883, Training Accuracy: 0.6562
# Epoch [3270/20000], Loss: 0.5952, Training Accuracy: 0.6406
# Epoch [3280/20000], Loss: 0.5895, Training Accuracy: 0.6328
# Epoch [3290/20000], Loss: 0.5898, Training Accuracy: 0.6328
# Epoch [3300/20000], Loss: 0.5914, Training Accuracy: 0.6250
# Epoch [3310/20000], Loss: 0.5877, Training Accuracy: 0.6719
# Epoch [3320/20000], Loss: 0.5913, Training Accuracy: 0.6328
# Epoch [3330/20000], Loss: 0.5962, Training Accuracy: 0.6406
# Epoch [3340/20000], Loss: 0.5944, Training Accuracy: 0.6406
# Epoch [3350/20000], Loss: 0.5893, Training Accuracy: 0.6406
# Epoch [3360/20000], Loss: 0.5873, Training Accuracy: 0.6562
# Epoch [3370/20000], Loss: 0.5895, Training Accuracy: 0.6406
# Epoch [3380/20000], Loss: 0.5878, Training Accuracy: 0.6328
# Epoch [3390/20000], Loss: 0.5896, Training Accuracy: 0.6250
# Epoch [3400/20000], Loss: 0.5939, Training Accuracy: 0.6406
# Epoch [3410/20000], Loss: 0.5885, Training Accuracy: 0.6484
# Epoch [3420/20000], Loss: 0.5883, Training Accuracy: 0.6562
# Epoch [3430/20000], Loss: 0.5868, Training Accuracy: 0.6484
# Epoch [3440/20000], Loss: 0.5933, Training Accuracy: 0.6406
# Epoch [3450/20000], Loss: 0.5879, Training Accuracy: 0.6406
# Epoch [3460/20000], Loss: 0.5882, Training Accuracy: 0.6250
# Epoch [3470/20000], Loss: 0.5928, Training Accuracy: 0.6406
# Epoch [3480/20000], Loss: 0.5859, Training Accuracy: 0.6484
# Epoch [3490/20000], Loss: 0.5874, Training Accuracy: 0.6562
# Epoch [3500/20000], Loss: 0.5896, Training Accuracy: 0.6328
# Epoch [3510/20000], Loss: 0.5905, Training Accuracy: 0.6328
# Epoch [3520/20000], Loss: 0.5867, Training Accuracy: 0.6484
# Epoch [3530/20000], Loss: 0.5897, Training Accuracy: 0.6406
# Epoch [3540/20000], Loss: 0.5894, Training Accuracy: 0.6328
# Epoch [3550/20000], Loss: 0.5850, Training Accuracy: 0.6562
# Epoch [3560/20000], Loss: 0.5881, Training Accuracy: 0.6406
# Epoch [3570/20000], Loss: 0.5907, Training Accuracy: 0.6484
# Epoch [3580/20000], Loss: 0.5890, Training Accuracy: 0.6328
# Epoch [3590/20000], Loss: 0.5852, Training Accuracy: 0.6641
# Epoch [3600/20000], Loss: 0.5861, Training Accuracy: 0.6484
# Epoch [3610/20000], Loss: 0.5862, Training Accuracy: 0.6484
# Epoch [3620/20000], Loss: 0.5868, Training Accuracy: 0.6328
# Epoch [3630/20000], Loss: 0.5930, Training Accuracy: 0.6406
# Epoch [3640/20000], Loss: 0.5840, Training Accuracy: 0.6641
# Epoch [3650/20000], Loss: 0.5860, Training Accuracy: 0.6641
# Epoch [3660/20000], Loss: 0.5903, Training Accuracy: 0.6484
# Epoch [3670/20000], Loss: 0.5840, Training Accuracy: 0.6484
# Epoch [3680/20000], Loss: 0.5837, Training Accuracy: 0.6562
# Epoch [3690/20000], Loss: 0.5903, Training Accuracy: 0.6562
# Epoch [3700/20000], Loss: 0.5852, Training Accuracy: 0.6562
# Epoch [3710/20000], Loss: 0.5900, Training Accuracy: 0.6406
# Epoch [3720/20000], Loss: 0.5849, Training Accuracy: 0.6562
# Epoch [3730/20000], Loss: 0.5847, Training Accuracy: 0.6562
# Epoch [3740/20000], Loss: 0.5859, Training Accuracy: 0.6484
# Epoch [3750/20000], Loss: 0.5851, Training Accuracy: 0.6406
# Epoch [3760/20000], Loss: 0.5847, Training Accuracy: 0.6484
# Epoch [3770/20000], Loss: 0.5896, Training Accuracy: 0.6562
# Epoch [3780/20000], Loss: 0.5829, Training Accuracy: 0.6484
# Epoch [3790/20000], Loss: 0.5884, Training Accuracy: 0.6484
# Epoch [3800/20000], Loss: 0.5842, Training Accuracy: 0.6328
# Epoch [3810/20000], Loss: 0.5840, Training Accuracy: 0.6328
# Epoch [3820/20000], Loss: 0.5894, Training Accuracy: 0.6406
# Epoch [3830/20000], Loss: 0.5829, Training Accuracy: 0.6484
# Epoch [3840/20000], Loss: 0.5826, Training Accuracy: 0.6484
# Epoch [3850/20000], Loss: 0.5923, Training Accuracy: 0.6641
# Epoch [3860/20000], Loss: 0.5822, Training Accuracy: 0.6484
# Epoch [3870/20000], Loss: 0.5860, Training Accuracy: 0.6406
# Epoch [3880/20000], Loss: 0.5830, Training Accuracy: 0.6484
# Epoch [3890/20000], Loss: 0.5835, Training Accuracy: 0.6484
# Epoch [3900/20000], Loss: 0.5821, Training Accuracy: 0.6641
# Epoch [3910/20000], Loss: 0.5825, Training Accuracy: 0.6406
# Epoch [3920/20000], Loss: 0.6013, Training Accuracy: 0.6406
# Epoch [3930/20000], Loss: 0.5890, Training Accuracy: 0.6562
# Epoch [3940/20000], Loss: 0.5834, Training Accuracy: 0.6328
# Epoch [3950/20000], Loss: 0.5820, Training Accuracy: 0.6641
# Epoch [3960/20000], Loss: 0.5820, Training Accuracy: 0.6562
# Epoch [3970/20000], Loss: 0.5813, Training Accuracy: 0.6484
# Epoch [3980/20000], Loss: 0.5819, Training Accuracy: 0.6484
# Epoch [3990/20000], Loss: 0.5864, Training Accuracy: 0.6562
# Epoch [4000/20000], Loss: 0.5844, Training Accuracy: 0.6484
# Epoch [4010/20000], Loss: 0.5882, Training Accuracy: 0.6641
# Epoch [4020/20000], Loss: 0.5816, Training Accuracy: 0.6484
# Epoch [4030/20000], Loss: 0.5842, Training Accuracy: 0.6406
# Epoch [4040/20000], Loss: 0.5848, Training Accuracy: 0.6719
# Epoch [4050/20000], Loss: 0.5816, Training Accuracy: 0.6562
# Epoch [4060/20000], Loss: 0.5807, Training Accuracy: 0.6562
# Epoch [4070/20000], Loss: 0.5831, Training Accuracy: 0.6562
# Epoch [4080/20000], Loss: 0.5877, Training Accuracy: 0.6641
# Epoch [4090/20000], Loss: 0.5870, Training Accuracy: 0.6484
# Epoch [4100/20000], Loss: 0.5824, Training Accuracy: 0.6562
# Epoch [4110/20000], Loss: 0.5815, Training Accuracy: 0.6562
# Epoch [4120/20000], Loss: 0.5804, Training Accuracy: 0.6484
# Epoch [4130/20000], Loss: 0.5806, Training Accuracy: 0.6484
# Epoch [4140/20000], Loss: 0.5972, Training Accuracy: 0.6484
# Epoch [4150/20000], Loss: 0.5840, Training Accuracy: 0.6562
# Epoch [4160/20000], Loss: 0.5800, Training Accuracy: 0.6406
# Epoch [4170/20000], Loss: 0.5805, Training Accuracy: 0.6484
# Epoch [4180/20000], Loss: 0.5803, Training Accuracy: 0.6562
# Epoch [4190/20000], Loss: 0.5801, Training Accuracy: 0.6484
# Epoch [4200/20000], Loss: 0.5826, Training Accuracy: 0.6484
# Epoch [4210/20000], Loss: 0.5842, Training Accuracy: 0.6484
# Epoch [4220/20000], Loss: 0.5804, Training Accuracy: 0.6562
# Epoch [4230/20000], Loss: 0.5820, Training Accuracy: 0.6641
# Epoch [4240/20000], Loss: 0.5856, Training Accuracy: 0.6484
# Epoch [4250/20000], Loss: 0.5795, Training Accuracy: 0.6484
# Epoch [4260/20000], Loss: 0.5807, Training Accuracy: 0.6484
# Epoch [4270/20000], Loss: 0.5877, Training Accuracy: 0.6562
# Epoch [4280/20000], Loss: 0.5794, Training Accuracy: 0.6406
# Epoch [4290/20000], Loss: 0.5822, Training Accuracy: 0.6562
# Epoch [4300/20000], Loss: 0.5795, Training Accuracy: 0.6562
# Epoch [4310/20000], Loss: 0.5817, Training Accuracy: 0.6719
# Epoch [4320/20000], Loss: 0.5828, Training Accuracy: 0.6719
# Epoch [4330/20000], Loss: 0.5796, Training Accuracy: 0.6562
# Epoch [4340/20000], Loss: 0.5817, Training Accuracy: 0.6719
# Epoch [4350/20000], Loss: 0.5858, Training Accuracy: 0.6484
# Epoch [4360/20000], Loss: 0.5792, Training Accuracy: 0.6406
# Epoch [4370/20000], Loss: 0.5807, Training Accuracy: 0.6406
# Epoch [4380/20000], Loss: 0.5801, Training Accuracy: 0.6484
# Epoch [4390/20000], Loss: 0.5845, Training Accuracy: 0.6562
# Epoch [4400/20000], Loss: 0.5817, Training Accuracy: 0.6484
# Epoch [4410/20000], Loss: 0.5803, Training Accuracy: 0.6562
# Epoch [4420/20000], Loss: 0.5839, Training Accuracy: 0.6406
# Epoch [4430/20000], Loss: 0.5788, Training Accuracy: 0.6406
# Epoch [4440/20000], Loss: 0.5829, Training Accuracy: 0.6484
# Epoch [4450/20000], Loss: 0.5822, Training Accuracy: 0.6406
# Epoch [4460/20000], Loss: 0.5794, Training Accuracy: 0.6484
# Epoch [4470/20000], Loss: 0.5819, Training Accuracy: 0.6797
# Epoch [4480/20000], Loss: 0.5788, Training Accuracy: 0.6562
# Epoch [4490/20000], Loss: 0.5800, Training Accuracy: 0.6641
# Epoch [4500/20000], Loss: 0.5852, Training Accuracy: 0.6562
# Epoch [4510/20000], Loss: 0.5788, Training Accuracy: 0.6484
# Epoch [4520/20000], Loss: 0.5801, Training Accuracy: 0.6562
# Epoch [4530/20000], Loss: 0.5850, Training Accuracy: 0.6406
# Epoch [4540/20000], Loss: 0.5785, Training Accuracy: 0.6406
# Epoch [4550/20000], Loss: 0.5812, Training Accuracy: 0.6797
# Epoch [4560/20000], Loss: 0.5798, Training Accuracy: 0.6484
# Epoch [4570/20000], Loss: 0.5780, Training Accuracy: 0.6484
# Epoch [4580/20000], Loss: 0.5809, Training Accuracy: 0.6484
# Epoch [4590/20000], Loss: 0.5859, Training Accuracy: 0.6484
# Epoch [4600/20000], Loss: 0.5828, Training Accuracy: 0.6406
# Epoch [4610/20000], Loss: 0.5775, Training Accuracy: 0.6406
# Epoch [4620/20000], Loss: 0.5795, Training Accuracy: 0.6484
# Epoch [4630/20000], Loss: 0.5779, Training Accuracy: 0.6484
# Epoch [4640/20000], Loss: 0.5816, Training Accuracy: 0.6641
# Epoch [4650/20000], Loss: 0.5799, Training Accuracy: 0.6562
# Epoch [4660/20000], Loss: 0.5780, Training Accuracy: 0.6406
# Epoch [4670/20000], Loss: 0.5802, Training Accuracy: 0.6719
# Epoch [4680/20000], Loss: 0.5848, Training Accuracy: 0.6484
# Epoch [4690/20000], Loss: 0.5771, Training Accuracy: 0.6641
# Epoch [4700/20000], Loss: 0.5816, Training Accuracy: 0.6719
# Epoch [4710/20000], Loss: 0.5835, Training Accuracy: 0.6641
# Epoch [4720/20000], Loss: 0.5832, Training Accuracy: 0.6484
# Epoch [4730/20000], Loss: 0.5782, Training Accuracy: 0.6484
# Epoch [4740/20000], Loss: 0.5785, Training Accuracy: 0.6562
# Epoch [4750/20000], Loss: 0.5772, Training Accuracy: 0.6406
# Epoch [4760/20000], Loss: 0.5809, Training Accuracy: 0.6719
# Epoch [4770/20000], Loss: 0.5814, Training Accuracy: 0.6797
# Epoch [4780/20000], Loss: 0.5766, Training Accuracy: 0.6484
# Epoch [4790/20000], Loss: 0.5772, Training Accuracy: 0.6406
# Epoch [4800/20000], Loss: 0.5852, Training Accuracy: 0.6562
# Epoch [4810/20000], Loss: 0.5775, Training Accuracy: 0.6406
# Epoch [4820/20000], Loss: 0.5802, Training Accuracy: 0.6797
# Epoch [4830/20000], Loss: 0.5787, Training Accuracy: 0.6719
# Epoch [4840/20000], Loss: 0.5769, Training Accuracy: 0.6484
# Epoch [4850/20000], Loss: 0.5774, Training Accuracy: 0.6406
# Epoch [4860/20000], Loss: 0.5880, Training Accuracy: 0.6484
# Epoch [4870/20000], Loss: 0.5768, Training Accuracy: 0.6719
# Epoch [4880/20000], Loss: 0.5776, Training Accuracy: 0.6719
# Epoch [4890/20000], Loss: 0.5786, Training Accuracy: 0.6719
# Epoch [4900/20000], Loss: 0.5768, Training Accuracy: 0.6641
# Epoch [4910/20000], Loss: 0.5778, Training Accuracy: 0.6562
# Epoch [4920/20000], Loss: 0.5773, Training Accuracy: 0.6719
# Epoch [4930/20000], Loss: 0.5813, Training Accuracy: 0.6719
# Epoch [4940/20000], Loss: 0.5852, Training Accuracy: 0.6484
# Epoch [4950/20000], Loss: 0.5796, Training Accuracy: 0.6797
# Epoch [4960/20000], Loss: 0.5765, Training Accuracy: 0.6562
# Epoch [4970/20000], Loss: 0.5792, Training Accuracy: 0.6484
# Epoch [4980/20000], Loss: 0.5765, Training Accuracy: 0.6484
# Epoch [4990/20000], Loss: 0.5763, Training Accuracy: 0.6406
# Epoch [5000/20000], Loss: 0.5839, Training Accuracy: 0.6562
# Epoch [5010/20000], Loss: 0.5774, Training Accuracy: 0.6406
# Epoch [5020/20000], Loss: 0.5796, Training Accuracy: 0.6719
# Epoch [5030/20000], Loss: 0.5763, Training Accuracy: 0.6406
# Epoch [5040/20000], Loss: 0.5785, Training Accuracy: 0.6641
# Epoch [5050/20000], Loss: 0.5776, Training Accuracy: 0.6562
# Epoch [5060/20000], Loss: 0.5770, Training Accuracy: 0.6484
# Epoch [5070/20000], Loss: 0.5845, Training Accuracy: 0.6562
# Epoch [5080/20000], Loss: 0.5766, Training Accuracy: 0.6328
# Epoch [5090/20000], Loss: 0.5783, Training Accuracy: 0.6562
# Epoch [5100/20000], Loss: 0.5768, Training Accuracy: 0.6484
# Epoch [5110/20000], Loss: 0.5765, Training Accuracy: 0.6641
# Epoch [5120/20000], Loss: 0.5813, Training Accuracy: 0.6562
# Epoch [5130/20000], Loss: 0.5785, Training Accuracy: 0.6562
# Epoch [5140/20000], Loss: 0.5769, Training Accuracy: 0.6641
# Epoch [5150/20000], Loss: 0.5786, Training Accuracy: 0.6641
# Epoch [5160/20000], Loss: 0.5759, Training Accuracy: 0.6328
# Epoch [5170/20000], Loss: 0.5771, Training Accuracy: 0.6562
# Epoch [5180/20000], Loss: 0.5829, Training Accuracy: 0.6641
# Epoch [5190/20000], Loss: 0.5766, Training Accuracy: 0.6484
# Epoch [5200/20000], Loss: 0.5767, Training Accuracy: 0.6562
# Epoch [5210/20000], Loss: 0.5787, Training Accuracy: 0.6641
# Epoch [5220/20000], Loss: 0.5758, Training Accuracy: 0.6562
# Epoch [5230/20000], Loss: 0.5758, Training Accuracy: 0.6484
# Epoch [5240/20000], Loss: 0.5820, Training Accuracy: 0.6641
# Epoch [5250/20000], Loss: 0.5788, Training Accuracy: 0.6562
# Epoch [5260/20000], Loss: 0.5797, Training Accuracy: 0.6719
# Epoch [5270/20000], Loss: 0.5755, Training Accuracy: 0.6641
# Epoch [5280/20000], Loss: 0.5759, Training Accuracy: 0.6719
# Epoch [5290/20000], Loss: 0.5749, Training Accuracy: 0.6406
# Epoch [5300/20000], Loss: 0.5774, Training Accuracy: 0.6641
# Epoch [5310/20000], Loss: 0.5788, Training Accuracy: 0.6719
# Epoch [5320/20000], Loss: 0.5749, Training Accuracy: 0.6484
# Epoch [5330/20000], Loss: 0.5753, Training Accuracy: 0.6484
# Epoch [5340/20000], Loss: 0.5829, Training Accuracy: 0.6562
# Epoch [5350/20000], Loss: 0.5789, Training Accuracy: 0.6562
# Epoch [5360/20000], Loss: 0.5796, Training Accuracy: 0.6719
# Epoch [5370/20000], Loss: 0.5752, Training Accuracy: 0.6328
# Epoch [5380/20000], Loss: 0.5778, Training Accuracy: 0.6719
# Epoch [5390/20000], Loss: 0.5758, Training Accuracy: 0.6484
# Epoch [5400/20000], Loss: 0.5754, Training Accuracy: 0.6406
# Epoch [5410/20000], Loss: 0.5766, Training Accuracy: 0.6562
# Epoch [5420/20000], Loss: 0.5857, Training Accuracy: 0.6641
# Epoch [5430/20000], Loss: 0.5749, Training Accuracy: 0.6484
# Epoch [5440/20000], Loss: 0.5791, Training Accuracy: 0.6797
# Epoch [5450/20000], Loss: 0.5745, Training Accuracy: 0.6406
# Epoch [5460/20000], Loss: 0.5762, Training Accuracy: 0.6641
# Epoch [5470/20000], Loss: 0.5782, Training Accuracy: 0.6641
# Epoch [5480/20000], Loss: 0.5751, Training Accuracy: 0.6641
# Epoch [5490/20000], Loss: 0.5753, Training Accuracy: 0.6641
# Epoch [5500/20000], Loss: 0.5839, Training Accuracy: 0.6641
# Epoch [5510/20000], Loss: 0.5744, Training Accuracy: 0.6406
# Epoch [5520/20000], Loss: 0.5775, Training Accuracy: 0.6719
# Epoch [5530/20000], Loss: 0.5761, Training Accuracy: 0.6484
# Epoch [5540/20000], Loss: 0.5743, Training Accuracy: 0.6406
# Epoch [5550/20000], Loss: 0.5756, Training Accuracy: 0.6562
# Epoch [5560/20000], Loss: 0.5867, Training Accuracy: 0.6562
# Epoch [5570/20000], Loss: 0.5758, Training Accuracy: 0.6562
# Epoch [5580/20000], Loss: 0.5765, Training Accuracy: 0.6484
# Epoch [5590/20000], Loss: 0.5766, Training Accuracy: 0.6641
# Epoch [5600/20000], Loss: 0.5741, Training Accuracy: 0.6562
# Epoch [5610/20000], Loss: 0.5764, Training Accuracy: 0.6641
# Epoch [5620/20000], Loss: 0.5744, Training Accuracy: 0.6562
# Epoch [5630/20000], Loss: 0.5754, Training Accuracy: 0.6562
# Epoch [5640/20000], Loss: 0.5822, Training Accuracy: 0.6562
# Epoch [5650/20000], Loss: 0.5741, Training Accuracy: 0.6406
# Epoch [5660/20000], Loss: 0.5764, Training Accuracy: 0.6719
# Epoch [5670/20000], Loss: 0.5763, Training Accuracy: 0.6562
# Epoch [5680/20000], Loss: 0.5740, Training Accuracy: 0.6484
# Epoch [5690/20000], Loss: 0.5748, Training Accuracy: 0.6641
# Epoch [5700/20000], Loss: 0.5808, Training Accuracy: 0.6719
# Epoch [5710/20000], Loss: 0.5741, Training Accuracy: 0.6406
# Epoch [5720/20000], Loss: 0.5763, Training Accuracy: 0.6562
# Epoch [5730/20000], Loss: 0.5746, Training Accuracy: 0.6641
# Epoch [5740/20000], Loss: 0.5740, Training Accuracy: 0.6562
# Epoch [5750/20000], Loss: 0.5766, Training Accuracy: 0.6719
# Epoch [5760/20000], Loss: 0.5822, Training Accuracy: 0.6484
# Epoch [5770/20000], Loss: 0.5742, Training Accuracy: 0.6562
# Epoch [5780/20000], Loss: 0.5764, Training Accuracy: 0.6719
# Epoch [5790/20000], Loss: 0.5734, Training Accuracy: 0.6328
# Epoch [5800/20000], Loss: 0.5738, Training Accuracy: 0.6562
# Epoch [5810/20000], Loss: 0.5784, Training Accuracy: 0.6719
# Epoch [5820/20000], Loss: 0.5784, Training Accuracy: 0.6641
# Epoch [5830/20000], Loss: 0.5763, Training Accuracy: 0.6797
# Epoch [5840/20000], Loss: 0.5744, Training Accuracy: 0.6484
# Epoch [5850/20000], Loss: 0.5738, Training Accuracy: 0.6641
# Epoch [5860/20000], Loss: 0.5789, Training Accuracy: 0.6797
# Epoch [5870/20000], Loss: 0.5750, Training Accuracy: 0.6641
# Epoch [5880/20000], Loss: 0.5741, Training Accuracy: 0.6484
# Epoch [5890/20000], Loss: 0.5776, Training Accuracy: 0.6641
# Epoch [5900/20000], Loss: 0.5781, Training Accuracy: 0.6719
# Epoch [5910/20000], Loss: 0.5738, Training Accuracy: 0.6484
# Epoch [5920/20000], Loss: 0.5749, Training Accuracy: 0.6562
# Epoch [5930/20000], Loss: 0.5745, Training Accuracy: 0.6562
# Epoch [5940/20000], Loss: 0.5757, Training Accuracy: 0.6797
# Epoch [5950/20000], Loss: 0.5772, Training Accuracy: 0.6875
# Epoch [5960/20000], Loss: 0.5741, Training Accuracy: 0.6484
# Epoch [5970/20000], Loss: 0.5747, Training Accuracy: 0.6719
# Epoch [5980/20000], Loss: 0.5812, Training Accuracy: 0.6719
# Epoch [5990/20000], Loss: 0.5734, Training Accuracy: 0.6562
# Epoch [6000/20000], Loss: 0.5768, Training Accuracy: 0.6719
# Epoch [6010/20000], Loss: 0.5730, Training Accuracy: 0.6406
# Epoch [6020/20000], Loss: 0.5772, Training Accuracy: 0.6797
# Epoch [6030/20000], Loss: 0.5756, Training Accuracy: 0.6484
# Epoch [6040/20000], Loss: 0.5732, Training Accuracy: 0.6484
# Epoch [6050/20000], Loss: 0.5736, Training Accuracy: 0.6484
# Epoch [6060/20000], Loss: 0.5818, Training Accuracy: 0.6484
# Epoch [6070/20000], Loss: 0.5739, Training Accuracy: 0.6484
# Epoch [6080/20000], Loss: 0.5755, Training Accuracy: 0.6641
# Epoch [6090/20000], Loss: 0.5734, Training Accuracy: 0.6562
# Epoch [6100/20000], Loss: 0.5722, Training Accuracy: 0.6406
# Epoch [6110/20000], Loss: 0.5723, Training Accuracy: 0.6406
# Epoch [6120/20000], Loss: 0.5726, Training Accuracy: 0.6484
# Epoch [6130/20000], Loss: 0.5788, Training Accuracy: 0.6641
# Epoch [6140/20000], Loss: 0.5751, Training Accuracy: 0.6562
# Epoch [6150/20000], Loss: 0.5774, Training Accuracy: 0.6641
# Epoch [6160/20000], Loss: 0.5737, Training Accuracy: 0.6719
# Epoch [6170/20000], Loss: 0.5724, Training Accuracy: 0.6484
# Epoch [6180/20000], Loss: 0.5734, Training Accuracy: 0.6562
# Epoch [6190/20000], Loss: 0.5746, Training Accuracy: 0.6719
# Epoch [6200/20000], Loss: 0.5773, Training Accuracy: 0.6719
# Epoch [6210/20000], Loss: 0.5740, Training Accuracy: 0.6641
# Epoch [6220/20000], Loss: 0.5725, Training Accuracy: 0.6562
# Epoch [6230/20000], Loss: 0.5796, Training Accuracy: 0.6562
# Epoch [6240/20000], Loss: 0.5722, Training Accuracy: 0.6562
# Epoch [6250/20000], Loss: 0.5747, Training Accuracy: 0.6875
# Epoch [6260/20000], Loss: 0.5733, Training Accuracy: 0.6562
# Epoch [6270/20000], Loss: 0.5727, Training Accuracy: 0.6562
# Epoch [6280/20000], Loss: 0.5741, Training Accuracy: 0.6641
# Epoch [6290/20000], Loss: 0.5783, Training Accuracy: 0.6875
# Epoch [6300/20000], Loss: 0.5728, Training Accuracy: 0.6484
# Epoch [6310/20000], Loss: 0.5737, Training Accuracy: 0.6641
# Epoch [6320/20000], Loss: 0.5790, Training Accuracy: 0.6719
# Epoch [6330/20000], Loss: 0.5723, Training Accuracy: 0.6641
# Epoch [6340/20000], Loss: 0.5795, Training Accuracy: 0.6875
# Epoch [6350/20000], Loss: 0.5716, Training Accuracy: 0.6406
# Epoch [6360/20000], Loss: 0.5737, Training Accuracy: 0.6719
# Epoch [6370/20000], Loss: 0.5721, Training Accuracy: 0.6484
# Epoch [6380/20000], Loss: 0.5791, Training Accuracy: 0.6719
# Epoch [6390/20000], Loss: 0.5723, Training Accuracy: 0.6484
# Epoch [6400/20000], Loss: 0.5727, Training Accuracy: 0.6641
# Epoch [6410/20000], Loss: 0.5722, Training Accuracy: 0.6641
# Epoch [6420/20000], Loss: 0.5725, Training Accuracy: 0.6562
# Epoch [6430/20000], Loss: 0.5731, Training Accuracy: 0.6719
# Epoch [6440/20000], Loss: 0.5859, Training Accuracy: 0.6562
# Epoch [6450/20000], Loss: 0.5729, Training Accuracy: 0.6719
# Epoch [6460/20000], Loss: 0.5718, Training Accuracy: 0.6484
# Epoch [6470/20000], Loss: 0.5725, Training Accuracy: 0.6641
# Epoch [6480/20000], Loss: 0.5720, Training Accuracy: 0.6562
# Epoch [6490/20000], Loss: 0.5725, Training Accuracy: 0.6562
# Epoch [6500/20000], Loss: 0.5717, Training Accuracy: 0.6406
# Epoch [6510/20000], Loss: 0.5743, Training Accuracy: 0.6719
# Epoch [6520/20000], Loss: 0.5733, Training Accuracy: 0.6641
# Epoch [6530/20000], Loss: 0.5739, Training Accuracy: 0.6719
# Epoch [6540/20000], Loss: 0.5730, Training Accuracy: 0.6562
# Epoch [6550/20000], Loss: 0.5727, Training Accuracy: 0.6641
# Epoch [6560/20000], Loss: 0.5751, Training Accuracy: 0.6797
# Epoch [6570/20000], Loss: 0.5730, Training Accuracy: 0.6562
# Epoch [6580/20000], Loss: 0.5719, Training Accuracy: 0.6484
# Epoch [6590/20000], Loss: 0.5712, Training Accuracy: 0.6406
# Epoch [6600/20000], Loss: 0.5801, Training Accuracy: 0.6562
# Epoch [6610/20000], Loss: 0.5713, Training Accuracy: 0.6484
# Epoch [6620/20000], Loss: 0.5743, Training Accuracy: 0.6719
# Epoch [6630/20000], Loss: 0.5737, Training Accuracy: 0.6641
# Epoch [6640/20000], Loss: 0.5708, Training Accuracy: 0.6406
# Epoch [6650/20000], Loss: 0.5714, Training Accuracy: 0.6406
# Epoch [6660/20000], Loss: 0.5719, Training Accuracy: 0.6562
# Epoch [6670/20000], Loss: 0.5811, Training Accuracy: 0.6641
# Epoch [6680/20000], Loss: 0.5710, Training Accuracy: 0.6562
# Epoch [6690/20000], Loss: 0.5742, Training Accuracy: 0.6719
# Epoch [6700/20000], Loss: 0.5710, Training Accuracy: 0.6562
# Epoch [6710/20000], Loss: 0.5708, Training Accuracy: 0.6484
# Epoch [6720/20000], Loss: 0.5707, Training Accuracy: 0.6641
# Epoch [6730/20000], Loss: 0.5776, Training Accuracy: 0.6562
# Epoch [6740/20000], Loss: 0.5753, Training Accuracy: 0.6719
# Epoch [6750/20000], Loss: 0.5771, Training Accuracy: 0.6641
# Epoch [6760/20000], Loss: 0.5711, Training Accuracy: 0.6484
# Epoch [6770/20000], Loss: 0.5734, Training Accuracy: 0.6641
# Epoch [6780/20000], Loss: 0.5702, Training Accuracy: 0.6484
# Epoch [6790/20000], Loss: 0.5705, Training Accuracy: 0.6484
# Epoch [6800/20000], Loss: 0.5747, Training Accuracy: 0.6875
# Epoch [6810/20000], Loss: 0.5717, Training Accuracy: 0.6406
# Epoch [6820/20000], Loss: 0.5706, Training Accuracy: 0.6719
# Epoch [6830/20000], Loss: 0.5721, Training Accuracy: 0.6641
# Epoch [6840/20000], Loss: 0.5751, Training Accuracy: 0.6797
# Epoch [6850/20000], Loss: 0.5751, Training Accuracy: 0.6719
# Epoch [6860/20000], Loss: 0.5705, Training Accuracy: 0.6406
# Epoch [6870/20000], Loss: 0.5703, Training Accuracy: 0.6406
# Epoch [6880/20000], Loss: 0.5741, Training Accuracy: 0.6875
# Epoch [6890/20000], Loss: 0.5731, Training Accuracy: 0.6641
# Epoch [6900/20000], Loss: 0.5702, Training Accuracy: 0.6406
# Epoch [6910/20000], Loss: 0.5728, Training Accuracy: 0.6719
# Epoch [6920/20000], Loss: 0.5763, Training Accuracy: 0.6797
# Epoch [6930/20000], Loss: 0.5702, Training Accuracy: 0.6562
# Epoch [6940/20000], Loss: 0.5752, Training Accuracy: 0.6875
# Epoch [6950/20000], Loss: 0.5723, Training Accuracy: 0.6562
# Epoch [6960/20000], Loss: 0.5692, Training Accuracy: 0.6484
# Epoch [6970/20000], Loss: 0.5691, Training Accuracy: 0.6484
# Epoch [6980/20000], Loss: 0.5697, Training Accuracy: 0.6797
# Epoch [6990/20000], Loss: 0.5855, Training Accuracy: 0.6484
# Epoch [7000/20000], Loss: 0.5717, Training Accuracy: 0.6797
# Epoch [7010/20000], Loss: 0.5701, Training Accuracy: 0.6484
# Epoch [7020/20000], Loss: 0.5701, Training Accuracy: 0.6641
# Epoch [7030/20000], Loss: 0.5710, Training Accuracy: 0.6641
# Epoch [7040/20000], Loss: 0.5720, Training Accuracy: 0.6797
# Epoch [7050/20000], Loss: 0.5696, Training Accuracy: 0.6406
# Epoch [7060/20000], Loss: 0.5689, Training Accuracy: 0.6484
# Epoch [7070/20000], Loss: 0.5711, Training Accuracy: 0.6719
# Epoch [7080/20000], Loss: 0.5826, Training Accuracy: 0.6484
# Epoch [7090/20000], Loss: 0.5725, Training Accuracy: 0.6719
# Epoch [7100/20000], Loss: 0.5688, Training Accuracy: 0.6484
# Epoch [7110/20000], Loss: 0.5704, Training Accuracy: 0.6797
# Epoch [7120/20000], Loss: 0.5693, Training Accuracy: 0.6484
# Epoch [7130/20000], Loss: 0.5691, Training Accuracy: 0.6562
# Epoch [7140/20000], Loss: 0.5781, Training Accuracy: 0.6484
# Epoch [7150/20000], Loss: 0.5693, Training Accuracy: 0.6562
# Epoch [7160/20000], Loss: 0.5715, Training Accuracy: 0.6562
# Epoch [7170/20000], Loss: 0.5708, Training Accuracy: 0.6719
# Epoch [7180/20000], Loss: 0.5707, Training Accuracy: 0.6797
# Epoch [7190/20000], Loss: 0.5687, Training Accuracy: 0.6484
# Epoch [7200/20000], Loss: 0.5698, Training Accuracy: 0.6484
# Epoch [7210/20000], Loss: 0.5733, Training Accuracy: 0.6875
# Epoch [7220/20000], Loss: 0.5711, Training Accuracy: 0.6641
# Epoch [7230/20000], Loss: 0.5716, Training Accuracy: 0.6797
# Epoch [7240/20000], Loss: 0.5703, Training Accuracy: 0.6562
# Epoch [7250/20000], Loss: 0.5697, Training Accuracy: 0.6484
# Epoch [7260/20000], Loss: 0.5729, Training Accuracy: 0.6875
# Epoch [7270/20000], Loss: 0.5708, Training Accuracy: 0.6562
# Epoch [7280/20000], Loss: 0.5686, Training Accuracy: 0.6406
# Epoch [7290/20000], Loss: 0.5716, Training Accuracy: 0.6719
# Epoch [7300/20000], Loss: 0.5729, Training Accuracy: 0.6719
# Epoch [7310/20000], Loss: 0.5686, Training Accuracy: 0.6406
# Epoch [7320/20000], Loss: 0.5682, Training Accuracy: 0.6406
# Epoch [7330/20000], Loss: 0.5691, Training Accuracy: 0.6875
# Epoch [7340/20000], Loss: 0.5854, Training Accuracy: 0.6484
# Epoch [7350/20000], Loss: 0.5721, Training Accuracy: 0.6797
# Epoch [7360/20000], Loss: 0.5682, Training Accuracy: 0.6641
# Epoch [7370/20000], Loss: 0.5687, Training Accuracy: 0.6484
# Epoch [7380/20000], Loss: 0.5691, Training Accuracy: 0.6562
# Epoch [7390/20000], Loss: 0.5696, Training Accuracy: 0.6484
# Epoch [7400/20000], Loss: 0.5713, Training Accuracy: 0.6797
# Epoch [7410/20000], Loss: 0.5705, Training Accuracy: 0.6484
# Epoch [7420/20000], Loss: 0.5683, Training Accuracy: 0.6641
# Epoch [7430/20000], Loss: 0.5698, Training Accuracy: 0.6641
# Epoch [7440/20000], Loss: 0.5737, Training Accuracy: 0.6875
# Epoch [7450/20000], Loss: 0.5679, Training Accuracy: 0.6406
# Epoch [7460/20000], Loss: 0.5679, Training Accuracy: 0.6406
# Epoch [7470/20000], Loss: 0.5694, Training Accuracy: 0.6875
# Epoch [7480/20000], Loss: 0.5792, Training Accuracy: 0.6719
# Epoch [7490/20000], Loss: 0.5731, Training Accuracy: 0.6719
# Epoch [7500/20000], Loss: 0.5684, Training Accuracy: 0.6641
# Epoch [7510/20000], Loss: 0.5677, Training Accuracy: 0.6484
# Epoch [7520/20000], Loss: 0.5687, Training Accuracy: 0.6719
# Epoch [7530/20000], Loss: 0.5706, Training Accuracy: 0.6797
# Epoch [7540/20000], Loss: 0.5697, Training Accuracy: 0.6953
# Epoch [7550/20000], Loss: 0.5678, Training Accuracy: 0.6641
# Epoch [7560/20000], Loss: 0.5708, Training Accuracy: 0.6719
# Epoch [7570/20000], Loss: 0.5705, Training Accuracy: 0.6797
# Epoch [7580/20000], Loss: 0.5674, Training Accuracy: 0.6406
# Epoch [7590/20000], Loss: 0.5670, Training Accuracy: 0.6641
# Epoch [7600/20000], Loss: 0.5737, Training Accuracy: 0.6797
# Epoch [7610/20000], Loss: 0.5689, Training Accuracy: 0.6641
# Epoch [7620/20000], Loss: 0.5706, Training Accuracy: 0.6797
# Epoch [7630/20000], Loss: 0.5673, Training Accuracy: 0.6406
# Epoch [7640/20000], Loss: 0.5677, Training Accuracy: 0.6953
# Epoch [7650/20000], Loss: 0.5694, Training Accuracy: 0.6797
# Epoch [7660/20000], Loss: 0.5683, Training Accuracy: 0.6953
# Epoch [7670/20000], Loss: 0.5691, Training Accuracy: 0.6797
# Epoch [7680/20000], Loss: 0.5690, Training Accuracy: 0.7031
# Epoch [7690/20000], Loss: 0.5684, Training Accuracy: 0.6797
# Epoch [7700/20000], Loss: 0.5698, Training Accuracy: 0.6797
# Epoch [7710/20000], Loss: 0.5720, Training Accuracy: 0.6797
# Epoch [7720/20000], Loss: 0.5663, Training Accuracy: 0.6562
# Epoch [7730/20000], Loss: 0.5673, Training Accuracy: 0.6562
# Epoch [7740/20000], Loss: 0.5700, Training Accuracy: 0.6797
# Epoch [7750/20000], Loss: 0.5694, Training Accuracy: 0.6875
# Epoch [7760/20000], Loss: 0.5663, Training Accuracy: 0.6406
# Epoch [7770/20000], Loss: 0.5666, Training Accuracy: 0.6562
# Epoch [7780/20000], Loss: 0.5731, Training Accuracy: 0.6719
# Epoch [7790/20000], Loss: 0.5670, Training Accuracy: 0.6406
# Epoch [7800/20000], Loss: 0.5675, Training Accuracy: 0.6875
# Epoch [7810/20000], Loss: 0.5708, Training Accuracy: 0.6797
# Epoch [7820/20000], Loss: 0.5665, Training Accuracy: 0.6641
# Epoch [7830/20000], Loss: 0.5663, Training Accuracy: 0.6328
# Epoch [7840/20000], Loss: 0.5665, Training Accuracy: 0.6797
# Epoch [7850/20000], Loss: 0.5768, Training Accuracy: 0.6484
# Epoch [7860/20000], Loss: 0.5658, Training Accuracy: 0.6484
# Epoch [7870/20000], Loss: 0.5690, Training Accuracy: 0.6797
# Epoch [7880/20000], Loss: 0.5654, Training Accuracy: 0.6406
# Epoch [7890/20000], Loss: 0.5700, Training Accuracy: 0.6797
# Epoch [7900/20000], Loss: 0.5673, Training Accuracy: 0.6953
# Epoch [7910/20000], Loss: 0.5652, Training Accuracy: 0.6484
# Epoch [7920/20000], Loss: 0.5692, Training Accuracy: 0.6797
# Epoch [7930/20000], Loss: 0.5682, Training Accuracy: 0.6719
# Epoch [7940/20000], Loss: 0.5701, Training Accuracy: 0.6797
# Epoch [7950/20000], Loss: 0.5686, Training Accuracy: 0.6797
# Epoch [7960/20000], Loss: 0.5654, Training Accuracy: 0.6562
# Epoch [7970/20000], Loss: 0.5650, Training Accuracy: 0.6484
# Epoch [7980/20000], Loss: 0.5646, Training Accuracy: 0.6406
# Epoch [7990/20000], Loss: 0.5646, Training Accuracy: 0.6484
# Epoch [8000/20000], Loss: 0.5644, Training Accuracy: 0.6484
# Epoch [8010/20000], Loss: 0.5706, Training Accuracy: 0.6719
# ...
# Epoch [17390/20000], Loss: 0.4945, Training Accuracy: 0.7109
# Epoch [17400/20000], Loss: 0.5025, Training Accuracy: 0.7031
# Epoch [17410/20000], Loss: 0.4922, Training Accuracy: 0.7188
# Epoch [17420/20000], Loss: 0.4863, Training Accuracy: 0.6953
# Epoch [17430/20000], Loss: 0.4960, Training Accuracy: 0.6953
# Epoch [17440/20000], Loss: 0.4859, Training Accuracy: 0.6875
# Epoch [17450/20000], Loss: 0.4966, Training Accuracy: 0.7109
# Epoch [17460/20000], Loss: 0.4879, Training Accuracy: 0.6797
# Epoch [17470/20000], Loss: 0.5023, Training Accuracy: 0.7031
# Epoch [17480/20000], Loss: 0.4852, Training Accuracy: 0.7109
# Epoch [17490/20000], Loss: 0.5018, Training Accuracy: 0.7031
# Epoch [17500/20000], Loss: 0.4888, Training Accuracy: 0.7031
# Epoch [17510/20000], Loss: 0.4923, Training Accuracy: 0.6875
# Epoch [17520/20000], Loss: 0.4890, Training Accuracy: 0.7188
# Epoch [17530/20000], Loss: 0.4919, Training Accuracy: 0.7109
# Epoch [17540/20000], Loss: 0.4852, Training Accuracy: 0.6875
# Epoch [17550/20000], Loss: 0.5006, Training Accuracy: 0.7031
# Epoch [17560/20000], Loss: 0.4874, Training Accuracy: 0.7188
# Epoch [17570/20000], Loss: 0.4919, Training Accuracy: 0.7031
# Epoch [17580/20000], Loss: 0.4883, Training Accuracy: 0.6953
# Epoch [17590/20000], Loss: 0.4870, Training Accuracy: 0.6797
# Epoch [17600/20000], Loss: 0.4853, Training Accuracy: 0.6953
# Epoch [17610/20000], Loss: 0.5011, Training Accuracy: 0.7031
# Epoch [17620/20000], Loss: 0.4846, Training Accuracy: 0.6953
# Epoch [17630/20000], Loss: 0.4960, Training Accuracy: 0.7031
# Epoch [17640/20000], Loss: 0.4839, Training Accuracy: 0.6953
# Epoch [17650/20000], Loss: 0.5051, Training Accuracy: 0.7031
# Epoch [17660/20000], Loss: 0.4856, Training Accuracy: 0.7109
# Epoch [17670/20000], Loss: 0.4931, Training Accuracy: 0.7188
# Epoch [17680/20000], Loss: 0.4922, Training Accuracy: 0.7031
# Epoch [17690/20000], Loss: 0.4865, Training Accuracy: 0.6875
# Epoch [17700/20000], Loss: 0.4920, Training Accuracy: 0.7031
# Epoch [17710/20000], Loss: 0.4868, Training Accuracy: 0.7188
# Epoch [17720/20000], Loss: 0.4890, Training Accuracy: 0.7188
# Epoch [17730/20000], Loss: 0.4933, Training Accuracy: 0.7031
# Epoch [17740/20000], Loss: 0.4871, Training Accuracy: 0.7188
# Epoch [17750/20000], Loss: 0.4950, Training Accuracy: 0.7266
# Epoch [17760/20000], Loss: 0.4861, Training Accuracy: 0.6875
# Epoch [17770/20000], Loss: 0.5024, Training Accuracy: 0.7188
# Epoch [17780/20000], Loss: 0.4829, Training Accuracy: 0.6953
# Epoch [17790/20000], Loss: 0.5066, Training Accuracy: 0.7031
# Epoch [17800/20000], Loss: 0.4892, Training Accuracy: 0.7031
# Epoch [17810/20000], Loss: 0.4878, Training Accuracy: 0.7266
# Epoch [17820/20000], Loss: 0.4868, Training Accuracy: 0.6953
# Epoch [17830/20000], Loss: 0.5061, Training Accuracy: 0.7031
# Epoch [17840/20000], Loss: 0.4884, Training Accuracy: 0.7109
# Epoch [17850/20000], Loss: 0.4876, Training Accuracy: 0.7109
# Epoch [17860/20000], Loss: 0.4942, Training Accuracy: 0.7031
# Epoch [17870/20000], Loss: 0.4880, Training Accuracy: 0.6953
# Epoch [17880/20000], Loss: 0.4881, Training Accuracy: 0.7188
# Epoch [17890/20000], Loss: 0.4907, Training Accuracy: 0.7188
# Epoch [17900/20000], Loss: 0.5002, Training Accuracy: 0.7031
# Epoch [17910/20000], Loss: 0.4841, Training Accuracy: 0.7188
# Epoch [17920/20000], Loss: 0.4877, Training Accuracy: 0.7031
# Epoch [17930/20000], Loss: 0.4855, Training Accuracy: 0.6875
# Epoch [17940/20000], Loss: 0.4923, Training Accuracy: 0.7031
# Epoch [17950/20000], Loss: 0.4842, Training Accuracy: 0.7109
# Epoch [17960/20000], Loss: 0.4981, Training Accuracy: 0.7109
# Epoch [17970/20000], Loss: 0.4864, Training Accuracy: 0.7109
# Epoch [17980/20000], Loss: 0.4897, Training Accuracy: 0.7109
# Epoch [17990/20000], Loss: 0.4840, Training Accuracy: 0.7188
# Epoch [18000/20000], Loss: 0.4925, Training Accuracy: 0.7109
# Epoch [18010/20000], Loss: 0.4840, Training Accuracy: 0.6953
# Epoch [18020/20000], Loss: 0.4923, Training Accuracy: 0.7188
# Epoch [18030/20000], Loss: 0.4808, Training Accuracy: 0.7031
# Epoch [18040/20000], Loss: 0.4834, Training Accuracy: 0.7109
# Epoch [18050/20000], Loss: 0.5026, Training Accuracy: 0.7188
# Epoch [18060/20000], Loss: 0.4844, Training Accuracy: 0.7109
# Epoch [18070/20000], Loss: 0.4904, Training Accuracy: 0.7266
# Epoch [18080/20000], Loss: 0.4829, Training Accuracy: 0.7109
# Epoch [18090/20000], Loss: 0.4994, Training Accuracy: 0.7188
# Epoch [18100/20000], Loss: 0.4811, Training Accuracy: 0.6875
# Epoch [18110/20000], Loss: 0.5136, Training Accuracy: 0.7109
# Epoch [18120/20000], Loss: 0.4916, Training Accuracy: 0.7109
# Epoch [18130/20000], Loss: 0.4800, Training Accuracy: 0.7031
# Epoch [18140/20000], Loss: 0.4876, Training Accuracy: 0.6953
# Epoch [18150/20000], Loss: 0.4858, Training Accuracy: 0.7031
# Epoch [18160/20000], Loss: 0.4845, Training Accuracy: 0.7109
# Epoch [18170/20000], Loss: 0.5010, Training Accuracy: 0.7109
# Epoch [18180/20000], Loss: 0.4853, Training Accuracy: 0.7188
# Epoch [18190/20000], Loss: 0.4828, Training Accuracy: 0.7031
# Epoch [18200/20000], Loss: 0.4918, Training Accuracy: 0.7188
# Epoch [18210/20000], Loss: 0.4801, Training Accuracy: 0.7188
# Epoch [18220/20000], Loss: 0.4876, Training Accuracy: 0.7109
# Epoch [18230/20000], Loss: 0.4821, Training Accuracy: 0.7109
# Epoch [18240/20000], Loss: 0.4967, Training Accuracy: 0.7188
# Epoch [18250/20000], Loss: 0.4804, Training Accuracy: 0.7031
# Epoch [18260/20000], Loss: 0.4807, Training Accuracy: 0.7109
# Epoch [18270/20000], Loss: 0.5005, Training Accuracy: 0.7188
# Epoch [18280/20000], Loss: 0.4810, Training Accuracy: 0.7188
# Epoch [18290/20000], Loss: 0.4931, Training Accuracy: 0.7266
# Epoch [18300/20000], Loss: 0.4809, Training Accuracy: 0.7109
# Epoch [18310/20000], Loss: 0.4972, Training Accuracy: 0.7031
# Epoch [18320/20000], Loss: 0.4795, Training Accuracy: 0.7031
# Epoch [18330/20000], Loss: 0.4905, Training Accuracy: 0.7188
# Epoch [18340/20000], Loss: 0.4819, Training Accuracy: 0.7344
# Epoch [18350/20000], Loss: 0.4840, Training Accuracy: 0.7109
# Epoch [18360/20000], Loss: 0.4950, Training Accuracy: 0.7266
# Epoch [18370/20000], Loss: 0.4829, Training Accuracy: 0.7188
# Epoch [18380/20000], Loss: 0.4878, Training Accuracy: 0.7188
# Epoch [18390/20000], Loss: 0.4846, Training Accuracy: 0.7109
# Epoch [18400/20000], Loss: 0.4860, Training Accuracy: 0.7109
# Epoch [18410/20000], Loss: 0.4779, Training Accuracy: 0.6953
# Epoch [18420/20000], Loss: 0.4922, Training Accuracy: 0.6953
# Epoch [18430/20000], Loss: 0.4793, Training Accuracy: 0.6953
# Epoch [18440/20000], Loss: 0.4945, Training Accuracy: 0.7109
# Epoch [18450/20000], Loss: 0.4777, Training Accuracy: 0.6953
# Epoch [18460/20000], Loss: 0.4909, Training Accuracy: 0.7031
# Epoch [18470/20000], Loss: 0.4781, Training Accuracy: 0.7031
# Epoch [18480/20000], Loss: 0.4927, Training Accuracy: 0.7344
# Epoch [18490/20000], Loss: 0.4772, Training Accuracy: 0.7031
# Epoch [18500/20000], Loss: 0.4948, Training Accuracy: 0.6953
# Epoch [18510/20000], Loss: 0.4780, Training Accuracy: 0.6953
# Epoch [18520/20000], Loss: 0.4935, Training Accuracy: 0.7266
# Epoch [18530/20000], Loss: 0.4780, Training Accuracy: 0.6953
# Epoch [18540/20000], Loss: 0.4785, Training Accuracy: 0.6953
# Epoch [18550/20000], Loss: 0.5019, Training Accuracy: 0.7031
# Epoch [18560/20000], Loss: 0.4794, Training Accuracy: 0.7031
# Epoch [18570/20000], Loss: 0.4782, Training Accuracy: 0.7188
# Epoch [18580/20000], Loss: 0.5146, Training Accuracy: 0.7344
# Epoch [18590/20000], Loss: 0.4959, Training Accuracy: 0.7109
# Epoch [18600/20000], Loss: 0.4886, Training Accuracy: 0.7109
# Epoch [18610/20000], Loss: 0.4802, Training Accuracy: 0.7031
# Epoch [18620/20000], Loss: 0.4769, Training Accuracy: 0.7031
# Epoch [18630/20000], Loss: 0.4777, Training Accuracy: 0.7031
# Epoch [18640/20000], Loss: 0.4921, Training Accuracy: 0.7266
# Epoch [18650/20000], Loss: 0.4778, Training Accuracy: 0.6875
# Epoch [18660/20000], Loss: 0.4932, Training Accuracy: 0.7188
# Epoch [18670/20000], Loss: 0.4790, Training Accuracy: 0.6953
# Epoch [18680/20000], Loss: 0.4856, Training Accuracy: 0.7266
# Epoch [18690/20000], Loss: 0.4797, Training Accuracy: 0.7266
# Epoch [18700/20000], Loss: 0.4902, Training Accuracy: 0.7031
# Epoch [18710/20000], Loss: 0.4781, Training Accuracy: 0.6875
# Epoch [18720/20000], Loss: 0.4794, Training Accuracy: 0.7188
# Epoch [18730/20000], Loss: 0.4910, Training Accuracy: 0.7109
# Epoch [18740/20000], Loss: 0.4789, Training Accuracy: 0.7031
# Epoch [18750/20000], Loss: 0.5015, Training Accuracy: 0.7109
# Epoch [18760/20000], Loss: 0.4747, Training Accuracy: 0.7031
# Epoch [18770/20000], Loss: 0.4811, Training Accuracy: 0.7266
# Epoch [18780/20000], Loss: 0.4836, Training Accuracy: 0.7109
# Epoch [18790/20000], Loss: 0.4778, Training Accuracy: 0.7109
# Epoch [18800/20000], Loss: 0.4924, Training Accuracy: 0.7188
# Epoch [18810/20000], Loss: 0.4750, Training Accuracy: 0.6953
# Epoch [18820/20000], Loss: 0.4747, Training Accuracy: 0.6953
# Epoch [18830/20000], Loss: 0.4786, Training Accuracy: 0.7109
# Epoch [18840/20000], Loss: 0.4851, Training Accuracy: 0.6719
# Epoch [18850/20000], Loss: 0.4951, Training Accuracy: 0.7188
# Epoch [18860/20000], Loss: 0.4750, Training Accuracy: 0.7109
# Epoch [18870/20000], Loss: 0.4738, Training Accuracy: 0.7031
# Epoch [18880/20000], Loss: 0.4765, Training Accuracy: 0.7188
# Epoch [18890/20000], Loss: 0.5303, Training Accuracy: 0.6875
# Epoch [18900/20000], Loss: 0.4827, Training Accuracy: 0.7188
# Epoch [18910/20000], Loss: 0.4808, Training Accuracy: 0.6953
# Epoch [18920/20000], Loss: 0.5090, Training Accuracy: 0.7109
# Epoch [18930/20000], Loss: 0.4748, Training Accuracy: 0.6953
# Epoch [18940/20000], Loss: 0.4895, Training Accuracy: 0.7188
# Epoch [18950/20000], Loss: 0.4737, Training Accuracy: 0.6875
# Epoch [18960/20000], Loss: 0.4949, Training Accuracy: 0.7031
# Epoch [18970/20000], Loss: 0.4731, Training Accuracy: 0.7188
# Epoch [18980/20000], Loss: 0.5083, Training Accuracy: 0.6953
# Epoch [18990/20000], Loss: 0.4833, Training Accuracy: 0.7188
# Epoch [19000/20000], Loss: 0.4751, Training Accuracy: 0.6875
# Epoch [19010/20000], Loss: 0.4738, Training Accuracy: 0.7031
# Epoch [19020/20000], Loss: 0.4908, Training Accuracy: 0.7109
# Epoch [19030/20000], Loss: 0.4734, Training Accuracy: 0.7031
# Epoch [19040/20000], Loss: 0.4978, Training Accuracy: 0.7188
# Epoch [19050/20000], Loss: 0.4750, Training Accuracy: 0.7031
# Epoch [19060/20000], Loss: 0.4842, Training Accuracy: 0.7109
# Epoch [19070/20000], Loss: 0.4806, Training Accuracy: 0.7109
# Epoch [19080/20000], Loss: 0.4728, Training Accuracy: 0.6953
# Epoch [19090/20000], Loss: 0.4849, Training Accuracy: 0.7109
# Epoch [19100/20000], Loss: 0.4755, Training Accuracy: 0.6875
# Epoch [19110/20000], Loss: 0.4726, Training Accuracy: 0.7109
# Epoch [19120/20000], Loss: 0.4869, Training Accuracy: 0.7266
# Epoch [19130/20000], Loss: 0.4740, Training Accuracy: 0.7031
# Epoch [19140/20000], Loss: 0.4934, Training Accuracy: 0.7031
# Epoch [19150/20000], Loss: 0.4746, Training Accuracy: 0.7109
# Epoch [19160/20000], Loss: 0.4769, Training Accuracy: 0.7188
# Epoch [19170/20000], Loss: 0.4889, Training Accuracy: 0.7266
# Epoch [19180/20000], Loss: 0.4733, Training Accuracy: 0.7031
# Epoch [19190/20000], Loss: 0.4715, Training Accuracy: 0.7109
# Epoch [19200/20000], Loss: 0.4937, Training Accuracy: 0.7109
# Epoch [19210/20000], Loss: 0.4728, Training Accuracy: 0.7109
# Epoch [19220/20000], Loss: 0.4740, Training Accuracy: 0.7031
# Epoch [19230/20000], Loss: 0.4936, Training Accuracy: 0.7031
# Epoch [19240/20000], Loss: 0.4751, Training Accuracy: 0.7188
# Epoch [19250/20000], Loss: 0.4810, Training Accuracy: 0.7188
# Epoch [19260/20000], Loss: 0.4709, Training Accuracy: 0.7031
# Epoch [19270/20000], Loss: 0.4769, Training Accuracy: 0.7188
# Epoch [19280/20000], Loss: 0.4812, Training Accuracy: 0.6953
# Epoch [19290/20000], Loss: 0.4902, Training Accuracy: 0.7266
# Epoch [19300/20000], Loss: 0.4717, Training Accuracy: 0.7266
# Epoch [19310/20000], Loss: 0.4747, Training Accuracy: 0.7266
# Epoch [19320/20000], Loss: 0.4865, Training Accuracy: 0.7344
# Epoch [19330/20000], Loss: 0.4708, Training Accuracy: 0.7109
# Epoch [19340/20000], Loss: 0.4717, Training Accuracy: 0.6875
# Epoch [19350/20000], Loss: 0.5088, Training Accuracy: 0.7109
# Epoch [19360/20000], Loss: 0.4793, Training Accuracy: 0.7266
# Epoch [19370/20000], Loss: 0.4727, Training Accuracy: 0.7188
# Epoch [19380/20000], Loss: 0.4884, Training Accuracy: 0.7109
# Epoch [19390/20000], Loss: 0.4737, Training Accuracy: 0.7031
# Epoch [19400/20000], Loss: 0.4721, Training Accuracy: 0.7109
# Epoch [19410/20000], Loss: 0.4937, Training Accuracy: 0.7266
# Epoch [19420/20000], Loss: 0.4717, Training Accuracy: 0.7031
# Epoch [19430/20000], Loss: 0.4790, Training Accuracy: 0.7266
# Epoch [19440/20000], Loss: 0.4732, Training Accuracy: 0.7031
# Epoch [19450/20000], Loss: 0.4792, Training Accuracy: 0.7188
# Epoch [19460/20000], Loss: 0.4787, Training Accuracy: 0.6953
# Epoch [19470/20000], Loss: 0.4869, Training Accuracy: 0.7344
# Epoch [19480/20000], Loss: 0.4713, Training Accuracy: 0.6875
# Epoch [19490/20000], Loss: 0.4840, Training Accuracy: 0.7188
# Epoch [19500/20000], Loss: 0.4698, Training Accuracy: 0.6953
# Epoch [19510/20000], Loss: 0.4769, Training Accuracy: 0.7344
# Epoch [19520/20000], Loss: 0.4745, Training Accuracy: 0.6953
# Epoch [19530/20000], Loss: 0.4813, Training Accuracy: 0.7188
# Epoch [19540/20000], Loss: 0.4790, Training Accuracy: 0.7266
# Epoch [19550/20000], Loss: 0.4696, Training Accuracy: 0.6953
# Epoch [19560/20000], Loss: 0.4751, Training Accuracy: 0.7344
# Epoch [19570/20000], Loss: 0.4834, Training Accuracy: 0.7109
# Epoch [19580/20000], Loss: 0.4901, Training Accuracy: 0.7188
# Epoch [19590/20000], Loss: 0.4775, Training Accuracy: 0.7422
# Epoch [19600/20000], Loss: 0.4729, Training Accuracy: 0.7188
# Epoch [19610/20000], Loss: 0.4718, Training Accuracy: 0.7188
# Epoch [19620/20000], Loss: 0.4865, Training Accuracy: 0.7188
# Epoch [19630/20000], Loss: 0.4690, Training Accuracy: 0.7109
# Epoch [19640/20000], Loss: 0.4694, Training Accuracy: 0.6875
# Epoch [19650/20000], Loss: 0.4929, Training Accuracy: 0.7109
# Epoch [19660/20000], Loss: 0.4682, Training Accuracy: 0.7031
# Epoch [19670/20000], Loss: 0.4687, Training Accuracy: 0.7188
# Epoch [19680/20000], Loss: 0.5151, Training Accuracy: 0.7031
# Epoch [19690/20000], Loss: 0.4794, Training Accuracy: 0.7109
# Epoch [19700/20000], Loss: 0.4695, Training Accuracy: 0.7109
# Epoch [19710/20000], Loss: 0.4931, Training Accuracy: 0.7109
# Epoch [19720/20000], Loss: 0.4679, Training Accuracy: 0.6953
# Epoch [19730/20000], Loss: 0.4811, Training Accuracy: 0.7188
# Epoch [19740/20000], Loss: 0.4692, Training Accuracy: 0.7031
# Epoch [19750/20000], Loss: 0.4754, Training Accuracy: 0.7188
# Epoch [19760/20000], Loss: 0.4764, Training Accuracy: 0.7188
# Epoch [19770/20000], Loss: 0.4679, Training Accuracy: 0.7109
# Epoch [19780/20000], Loss: 0.4940, Training Accuracy: 0.7109
# Epoch [19790/20000], Loss: 0.4674, Training Accuracy: 0.7031
# Epoch [19800/20000], Loss: 0.4929, Training Accuracy: 0.7031
# Epoch [19810/20000], Loss: 0.4672, Training Accuracy: 0.7031
# Epoch [19820/20000], Loss: 0.4876, Training Accuracy: 0.7266
# Epoch [19830/20000], Loss: 0.4670, Training Accuracy: 0.7109
# Epoch [19840/20000], Loss: 0.4881, Training Accuracy: 0.7109
# Epoch [19850/20000], Loss: 0.4670, Training Accuracy: 0.6797
# Epoch [19860/20000], Loss: 0.4872, Training Accuracy: 0.7266
# Epoch [19870/20000], Loss: 0.4669, Training Accuracy: 0.7188
# Epoch [19880/20000], Loss: 0.4679, Training Accuracy: 0.6875
# Epoch [19890/20000], Loss: 0.4945, Training Accuracy: 0.7188
# Epoch [19900/20000], Loss: 0.4665, Training Accuracy: 0.7031
# Epoch [19910/20000], Loss: 0.4901, Training Accuracy: 0.7109
# Epoch [19920/20000], Loss: 0.4677, Training Accuracy: 0.7266
# Epoch [19930/20000], Loss: 0.4738, Training Accuracy: 0.7344
# Epoch [19940/20000], Loss: 0.4827, Training Accuracy: 0.7344
# Epoch [19950/20000], Loss: 0.4872, Training Accuracy: 0.7109
# Epoch [19960/20000], Loss: 0.4680, Training Accuracy: 0.7031
# Epoch [19970/20000], Loss: 0.4678, Training Accuracy: 0.6875
# Epoch [19980/20000], Loss: 0.4865, Training Accuracy: 0.7031
# Epoch [19990/20000], Loss: 0.4675, Training Accuracy: 0.6875
# Epoch [20000/20000], Loss: 0.4767, Training Accuracy: 0.7188

# %% [markdown]
# ## Uncomment next cell if you want to load a particular model you already trained.

# %%
# loaded_model = SimpleDenseNet(input_dim=len(list(features_to_extract.keys())), hidden_dim=512).to(device)
# loaded_model.load_state_dict(torch.load('llama-' + task + '-best-model'))

# # Set the model to evaluation mode"
# loaded_model.eval()

# %% [markdown]
# #Compute the metrics using the model on the Test Set.

# %%
# basically getting test performance:

X_test_tensor = torch.tensor(X_test_features, dtype=torch.float32).to(device)
Y_test_tensor = torch.tensor(Y_test, dtype=torch.float32).view(-1, 1).to(device)

test_metrics = compute_metrics(denseModel, X_test_tensor, Y_test_tensor)

print(
    f"Testing - Accuracy: {test_metrics['Accuracy']:.4f}, Precision: {test_metrics['Precision']:.4f}, Recall: {test_metrics['Recall']:.4f}, F1: {test_metrics['F1']:.4f}, ROC AUC: {test_metrics['ROC AUC']:.4f}, PR AUC: {test_metrics['PR AUC']:.4f}"
)
print(
    f"Testing - Negative: {test_metrics['Accuracy']:.4f}, Precision-Negative: {test_metrics['Precision-Negative']:.4f}, Recall-Negative: {test_metrics['Recall-Negative']:.4f}, F1-Negative: {test_metrics['F1-Negative']:.4f}, ROC AUC-Negative: {test_metrics['ROC AUC-Negative']:.4f}, PR AUC-Negative: {test_metrics['PR AUC-Negative']:.4f}"
)
# Out:
# Testing - Accuracy: 0.4688, Precision: 0.4444, Recall: 0.2500, F1: 0.3200, ROC AUC: 0.5039, PR AUC: 0.5347
# Testing - Negative: 0.4688, Precision-Negative: 0.4783, Recall-Negative: 0.6875, F1-Negative: 0.5641, ROC AUC-Negative: 0.4961, PR AUC-Negative: 0.6059

# %% [markdown]
# ## Save the results on a CSV if you want.

# %%
model_dataframe = pd.DataFrame(
    columns=[
        "features",
        "model_name",
        "feature_to_extract",
        "method",
        "accuracy",
        "precision",
        "recall",
        "roc auc",
        "pr auc",
        "negative",
        "precision-negative",
        "recall-negative",
        "negative f1",
        "lr_accuracy",
        "lr_features_log",
        "lr_features_no_log",
    ]
)

# %%
d = {
    "features": features_to_extract,
    "model_name": str(model.getName()),
    "feature_to_extract": feature_to_extract,
    "method": "TEST",
    "accuracy": test_metrics["Accuracy"],
    "precision": test_metrics["Precision"],
    "recall": test_metrics["Recall"],
    "f1": test_metrics["F1"],
    "pr auc": test_metrics["PR AUC"],
    "precision-negative": test_metrics["Precision-Negative"],
    "recall-negative": test_metrics["Recall-Negative"],
    "negative-f1": test_metrics["F1-Negative"],
    "lr_accuracy": lr_accuracy,
    "lr_features_log": lr_features_log,
    "lr_features_no_log": lr_features_no_log,
}

model_dataframe.loc[len(model_dataframe.index)] = d

# %%
model_dataframe.head()
# Out:
#                                             features  model_name  \
# 0  {'mtp': True, 'avgtp': True, 'MDVTP': True, 'M...  gpt2-large
#
#   feature_to_extract method  accuracy  precision  recall  roc auc    pr auc  \
# 0                all   TEST   0.46875   0.444444    0.25      NaN  0.534722
#
#    negative  precision-negative  recall-negative  negative f1  lr_accuracy  \
# 0       NaN            0.478261           0.6875          NaN        0.375
#
#                                      lr_features_log  \
# 0  {'mtp': 7.385657538210723e-07, 'avgtp': -0.005...
#
#                                   lr_features_no_log
# 0  {'mtp': 1.0000007385660266, 'avgtp': 0.9946396...

# %%
csv_name = f"{model.getSanitizedName()}_{task}_{includeKnowledge=}_{includeConditioned=}_{'_'.join([f'{k}={v}' for k, v in features_to_extract.items()])}.csv"
model_dataframe.to_csv(output_path / csv_name, index=False)
