# %% [markdown]
# ## Connect to your Google Drive or any filesystem you are going to use.

# %%
"""
import sys
from pathlib import Path

IN_COLAB = "google.colab" in sys.modules
if IN_COLAB:
    from google.colab import drive

    drive.mount("/content/gdrive")
base_path = (
    Path("your_path") if IN_COLAB else Path(".")
)

#Fix if you want to use a different path
output_path = base_path / "output"
data_path = base_path / "HaluEval"
output_path.mkdir(exist_ok=True)
"""
# Out:
# '\nimport sys\nfrom pathlib import Path\n\nIN_COLAB = "google.colab" in sys.modules\nif IN_COLAB:\n    from google.colab import drive\n\n    drive.mount("/content/gdrive")\nbase_path = (\n    Path("your_path") if IN_COLAB else Path(".")\n)\n\n#Fix if you want to use a different path\noutput_path = base_path / "output"\ndata_path = base_path / "HaluEval"\noutput_path.mkdir(exist_ok=True)\n'

# %% [markdown]
# ## These are the libraries needed to run this notebook

# %% [markdown]
# ## Deep Learning Installations

# %%
# %pip install transformers datasets evaluate rouge_score
# %pip install --upgrade huggingface_hub
"""
# %pip install accelerate -U
# %pip install transformers[torch]
# %pip install sentencepiece
# %pip install google
# %pip install protobuf
"""
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.9.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Collecting evaluate
#   Downloading evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (1.17.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers) (0.25.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets) (3.29.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.7.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (from rouge_score) (3.9.1)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from rouge_score) (1.17.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.14.0)
# Requirement already satisfied: click>=8.4.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (8.4.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.5.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2026.5.20)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk->rouge_score) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2026.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.24.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers) (0.1.2)
# Downloading evaluate-0.4.6-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 4.0 MB/s eta 0:00:00
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=178ede8cfd083bd67aa779f2dfc156663a2ab43614956c614a3cf92921a701de
#   Stored in directory: /root/.cache/pip/wheels/85/9d/af/01feefbe7d55ef5468796f0c68225b6788e85d9d0a281e7a70
# Successfully built rouge_score
# Installing collected packages: rouge_score, evaluate
# Successfully installed evaluate-0.4.6 rouge_score-0.1.2
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (1.17.0)
# Collecting huggingface_hub
#   Downloading huggingface_hub-1.18.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: click>=8.4.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (1.5.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.67.3)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (0.25.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub) (0.16.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface_hub) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface_hub) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface_hub) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface_hub) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface_hub) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface_hub) (0.1.2)
# Downloading huggingface_hub-1.18.0-py3-none-any.whl (684 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 684.4/684.4 kB 12.7 MB/s eta 0:00:00
# Installing collected packages: huggingface_hub
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface_hub 1.17.0
#     Uninstalling huggingface_hub-1.17.0:
#       Successfully uninstalled huggingface_hub-1.17.0
# Successfully installed huggingface_hub-1.18.0
# '\n%pip install accelerate -U\n%pip install transformers[torch]\n%pip install sentencepiece\n%pip install google\n%pip install protobuf\n'

# %% [markdown]
# ## Libraries

# %%
from datasets import load_dataset
from datasets import Dataset
from transformers import AutoTokenizer
from transformers import DataCollatorForSeq2Seq
from transformers import pipeline
from transformers import AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer
from transformers import AutoTokenizer
from transformers import AutoModelForSeq2SeqLM
import numpy as np
import pandas as pd
import evaluate
import random
import json
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading Dataset
#
# `The method loadDataset receieves the path where the datasets json files of the HaluEval repository are. You just need to pass your path and the name of the dataset you are going to use.`
#
# ## Dataset Names:
# - summarization
# - dialogue
# - qa
# - general

# %%
## As a recomendation keep these two with the same naming if you do not want to change many things
datasetName = "general"
task = datasetName

# %%
import requests

base_url = "https://raw.githubusercontent.com/RUCAIBox/HaluEval-2.0/master/annotation/human_annotation/"


bio_medical = requests.get(base_url + "Bio-Medical.json").json()
education = requests.get(base_url + "Education.json").json()
finance = requests.get(base_url + "Finance.json").json()
open_domain = requests.get(base_url + "Open-Domain.json").json()
science = requests.get(base_url + "Science.json").json()

# %%
"""
def loadDataset(datasetName, path=data_path):
    file_path = path / f"{datasetName}.json"
    return pd.read_json(file_path) #, lines=True)
"""
# Out:
# '\ndef loadDataset(datasetName, path=data_path):\n    file_path = path / f"{datasetName}.json"\n    return pd.read_json(file_path) #, lines=True)\n'

# %%
"""
bio_medical = loadDataset(datasetName="Bio-Medical")
education = loadDataset(datasetName="Education")
finance = loadDataset(datasetName="Finance")
open_domain = loadDataset(datasetName="Open-Domain")
science = loadDataset(datasetName="Science")
"""
# Out:
# '\nbio_medical = loadDataset(datasetName="Bio-Medical")\neducation = loadDataset(datasetName="Education")\nfinance = loadDataset(datasetName="Finance")\nopen_domain = loadDataset(datasetName="Open-Domain")\nscience = loadDataset(datasetName="Science")\n'

# %% [markdown]
# ### Saving the above file with combined domains

# %%
def process_and_save(datasets_dict):

    # 1. Add domain column
    for name, df in datasets_dict.items():
        df["domain"] = name

    # 2. Merge all datasets
    data = pd.concat(datasets_dict.values(), ignore_index=True)

    # 3. Create hallucination label
    def get_label(judges):
        if not isinstance(judges, list) or len(judges) == 0:
            return "unknown"
        judges = [str(j).strip().lower() for j in judges]
        return "yes" if "false" in judges else "no"

    data["hallucination_label"] = data["human_judge"].apply(get_label)

    # 4. Keep only required columns
    data = data[[
        "id",
        "user_query",
        "chatgpt_response",
        "hallucination_label",
        "domain"
    ]]

    # 5. Shuffle
    data = data.sample(frac=1).reset_index(drop=True)

    return data

# %%
import pandas as pd

datasets = {
    "education": pd.DataFrame(education),
    "bio_medical": pd.DataFrame(bio_medical),
    "finance": pd.DataFrame(finance),
    "open_domain": pd.DataFrame(open_domain),
    "science": pd.DataFrame(science)
}

data = process_and_save(datasets)

# %%
data.head()
# Out:
#      id                                         user_query  \
# 0  1062  What is the validity of the assertion that "Th...
# 1   488  Can you clarify whether the claim "Nigerian ph...
# 2  2338  Did Susan Hill or Jane Gardam win more literar...
# 3   455  if there are fish in every tank , and each tan...
# 4  1498  What if 40% of the remaining 60% Loan To Value...
#
#                                     chatgpt_response hallucination_label  \
# 0  To determine the validity of the assertion tha...                 yes
# 1  The claim that "Nigerian physicians constitute...                 yes
# 2  Jane Gardam has won more literary awards than ...             unknown
# 3  To determine which statement cannot be true, w...                 yes
# 4  If 40% of the remaining 60% Loan To Value (LTV...                  no
#
#         domain
# 0      science
# 1      science
# 2  open_domain
# 3    education
# 4      finance

# %% [markdown]
# ## For this particular example we are loading the general_data.json since is the one that takes the less time to process in case you want to test quickly how it works.

# %% [markdown]
# ### Data Statistics

# %%
len(data)
# Out:
# 1000

# %%
# Get the counts of each unique value in 'domain'
domain_counts = data['domain'].value_counts()
domain_percent = domain_counts/len(data) * 100

print(domain_counts)
print(domain_percent)


domain_counts = data['domain'].value_counts()


plt.figure(figsize=(4, 4))
plt.pie(domain_counts, labels=domain_counts.index, autopct='%1.f%%', startangle=140, colors= plt.cm.Paired.colors)
plt.title('Distribution of Domains')
plt.axis('equal') # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# domain
# science        200
# open_domain    200
# education      200
# finance        200
# bio_medical    200
# Name: count, dtype: int64
# domain
# science        20.0
# open_domain    20.0
# education      20.0
# finance        20.0
# bio_medical    20.0
# Name: count, dtype: float64

# %%
# Get the counts of each unique value in 'hallucination_label'
hallucination_counts = data['hallucination_label'].value_counts()
hallucination_percent = hallucination_counts/len(data) * 100

print(hallucination_counts)
print(hallucination_percent)

# Create a bar chart
plt.figure(figsize=(8, 6))
sns.barplot(x=hallucination_percent.index, y=hallucination_percent.values, hue=hallucination_counts.index, palette='pastel', legend=False)
plt.title('Distribution of Hallucination Labels')
plt.xlabel('Hallucination Label')
plt.ylabel('Count')
plt.show()
# Out:
# hallucination_label
# yes        896
# no          80
# unknown     24
# Name: count, dtype: int64
# hallucination_label
# yes        89.6
# no          8.0
# unknown     2.4
# Name: count, dtype: float64

# %% [markdown]
# ### Hallucination Labels by Domain

# %%
hallucination_by_domain = data.groupby('domain')['hallucination_label'].value_counts().unstack(fill_value=0)
display(hallucination_by_domain)
# Out:
# hallucination_label  no  unknown  yes
# domain
# bio_medical           5        9  186
# education            17        3  180
# finance              46        1  153
# open_domain           5       10  185
# science               7        1  192

# %%
hallucination_by_domain.plot(kind='bar', figsize=(12, 7))
plt.title('Hallucination Labels Counts Across Domains')
plt.xlabel('Domain')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Hallucination Label')
plt.tight_layout()
plt.show()

# %%
data = data[data['hallucination_label'] != 'unknown']

# Display the new counts to verify the removal
print(data['hallucination_label'].value_counts())
# Out:
# hallucination_label
# yes    896
# no      80
# Name: count, dtype: int64

# %%
hallucination_by_domain = data.groupby('domain')['hallucination_label'].value_counts().unstack(fill_value=0)
display(hallucination_by_domain)
# Out:
# hallucination_label  no  yes
# domain
# bio_medical           5  186
# education            17  180
# finance              46  153
# open_domain           5  185
# science               7  192

# %%
data.head()
# Out:
#      id                                         user_query  \
# 0  1062  What is the validity of the assertion that "Th...
# 1   488  Can you clarify whether the claim "Nigerian ph...
# 3   455  if there are fish in every tank , and each tan...
# 4  1498  What if 40% of the remaining 60% Loan To Value...
# 5     0  Consider the following statement: "0-dimension...
#
#                                     chatgpt_response hallucination_label  \
# 0  To determine the validity of the assertion tha...                 yes
# 1  The claim that "Nigerian physicians constitute...                 yes
# 3  To determine which statement cannot be true, w...                 yes
# 4  If 40% of the remaining 60% Loan To Value (LTV...                  no
# 5  The statement, "0-dimensional biomaterials lac...                 yes
#
#       domain
# 0    science
# 1    science
# 3  education
# 4    finance
# 5    science

# %% [markdown]
# ### Token Size of Chat gpt response

# %%
data['chatgpt_response_length'] = data['chatgpt_response'].str.split().apply(len)
#display(data.head())

average_response_length_by_domain = data.groupby('domain')['chatgpt_response_length'].mean().sort_values(ascending=False)
display(average_response_length_by_domain)
# Out:
# domain
# science        280.120603
# finance        187.763819
# bio_medical    125.052356
# education      100.771574
# open_domain     19.073684
# Name: chatgpt_response_length, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=average_response_length_by_domain.index, y=average_response_length_by_domain.values, palette='viridis')
plt.title('Average ChatGPT Response Length by Domain')
plt.xlabel('Domain')
plt.ylabel('Average Response Length')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_12615/2527565532.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=average_response_length_by_domain.index, y=average_response_length_by_domain.values, palette='viridis')

# %% [markdown]
# # Balancing the classes from dataset

# %%
data = data[data["hallucination_label"] != "unknown"]

df_yes = data[data["hallucination_label"] == "yes"]
df_no  = data[data["hallucination_label"] == "no"]

n = len(df_no)

data = pd.concat([
    df_yes.sample(n=n, random_state=42),
    df_no
]).sample(frac=1, random_state=42)  # shuffle

# %%
data.head()
# Out:
#        id                                         user_query  \
# 303  3933  when was the treadmill first patented in the u...
# 337   489  As a shareholder, what are the pros and cons o...
# 719  3394        Is SIPC coverage on cash as strong as FDIC?
# 686    51  Do you agree with the claim that "Active caspa...
# 173  3416  Can stockholders choose NOT to elect a board o...
#
#                                       chatgpt_response hallucination_label  \
# 303  The treadmill was first patented in the United...                  no
# 337  Pros of a Share Consolidation:\n1. Increased s...                  no
# 719  No, SIPC (Securities Investor Protection Corpo...                  no
# 686  The claim states that active caspase-11 is inv...                 yes
# 173  No, stockholders cannot choose not to elect a ...                  no
#
#         domain  chatgpt_response_length
# 303  education                       17
# 337    finance                      504
# 719    finance                      137
# 686    science                      209
# 173    finance                       94

# %%
len(data)
# Out:
# 160

# %%
# Get the counts of each unique value in 'hallucination_label'
hallucination_counts = data['hallucination_label'].value_counts()
hallucination_percent = hallucination_counts/len(data) * 100

print(hallucination_counts)
print(hallucination_percent)

# Create a bar chart
plt.figure(figsize=(8, 6))
sns.barplot(x=hallucination_percent.index, y=hallucination_percent.values, hue=hallucination_counts.index, palette='pastel', legend=False)
plt.title('Distribution of Hallucination Labels')
plt.xlabel('Hallucination Label')
plt.ylabel('Count')
plt.show()
# Out:
# hallucination_label
# no     80
# yes    80
# Name: count, dtype: int64
# hallucination_label
# no     50.0
# yes    50.0
# Name: count, dtype: float64

# %%
# Get the counts of each unique value in 'domain'
domain_counts = data['domain'].value_counts()
domain_percent = domain_counts/len(data) * 100

print(domain_counts)
print(domain_percent)


domain_counts = data['domain'].value_counts()


plt.figure(figsize=(4, 4))
plt.pie(domain_counts, labels=domain_counts.index, autopct='%1.f%%', startangle=140, colors= plt.cm.Paired.colors)
plt.title('Distribution of Domains')
plt.axis('equal') # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# domain
# finance        58
# education      37
# science        23
# open_domain    21
# bio_medical    21
# Name: count, dtype: int64
# domain
# finance        36.250
# education      23.125
# science        14.375
# open_domain    13.125
# bio_medical    13.125
# Name: count, dtype: float64

# %%
data['chatgpt_response_length'] = data['chatgpt_response'].str.split().apply(len)
#display(data.head())

average_response_length_by_domain = data.groupby('domain')['chatgpt_response_length'].mean().sort_values(ascending=False)
display(average_response_length_by_domain)
# Out:
# domain
# science        272.434783
# finance        210.413793
# bio_medical     92.238095
# education       64.702703
# open_domain     16.142857
# Name: chatgpt_response_length, dtype: float64

# %% [markdown]
# # Setting Device to use the GPU
#
# We use the T4 GPU in Colab since the heaviest computation for us is the inference of the LLM-Evaluator. Therefore, T4 seem as the better fit.

# %%
import torch

print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# ## Generic LLMModel class to reuse the functionality of extracting the features.

# %%
from transformers import BartForConditionalGeneration, BartTokenizer
from transformers import T5Tokenizer, T5ForConditionalGeneration
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from transformers import BartForConditionalGeneration, PegasusForConditionalGeneration
from transformers import LEDForConditionalGeneration, LEDTokenizer
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from transformers import GPT2LMHeadModel, GPT2Tokenizer
from transformers import LlamaForCausalLM, LlamaTokenizer

import torch
import torch.nn.functional as F


class LLMModel:
    def __init__(self):
        self.model = self.model.to(device)
        pass

    def getName(self) -> str:
        return self.model_name

    def getSanitizedName(self) -> str:
        return self.model_name.replace("/", "__")

    def generate(self, inpt):
        pass

    # Move in future commits this method to an utils.py
    def truncate_string_by_len(self, s, truncate_len):
        words = s.split()
        truncated_words = words[:-truncate_len] if truncate_len > 0 else words
        return " ".join(truncated_words)

    # Method to get the vocabulary probabilities of the LLM for a given token on the generated text from LLM-Generator
    def getVocabProbsAtPos(self, pos, token_probs):
        sorted_probs, sorted_indices = torch.sort(token_probs[pos, :], descending=True)
        return sorted_probs

    def getMaxLength(self):
        return self.model.config.max_position_embeddings

    # By default knowledge is the empty string. If you want to add extra knowledge you can do it like in the cases of the qa_data.json and dialogue_data.json
    def extractFeatures(
        self,
        knowledge="",
        conditionted_text="",
        generated_text="",
        features_to_extract={},
    ):
        self.model.eval()

        total_len = len(knowledge) + len(conditionted_text) + len(generated_text)
        truncate_len = min(total_len - self.tokenizer.model_max_length, 0)

        # Truncate knowledge in case is too large
        knowledge = self.truncate_string_by_len(knowledge, truncate_len // 2)
        # Truncate text_A in case is too large
        conditionted_text = self.truncate_string_by_len(
            conditionted_text, truncate_len - (truncate_len // 2)
        )

        inputs = self.tokenizer(
            [knowledge + conditionted_text + generated_text],
            return_tensors="pt",
            max_length=self.getMaxLength(),
            truncation=True,
        )

        for key in inputs:
            inputs[key] = inputs[key].to(device)

        with torch.no_grad():
            outputs = self.model(**inputs)
            logits = outputs.logits

        probs = F.softmax(logits, dim=-1)
        probs = probs.to(device)

        tokens_generated_length = len(self.tokenizer.tokenize(generated_text))
        start_index = logits.shape[1] - tokens_generated_length
        conditional_probs = probs[0, start_index :]

        token_ids_generated = inputs["input_ids"][0, start_index :].tolist()
        token_probs_generated = [
            conditional_probs[i, tid].item()
            for i, tid in enumerate(token_ids_generated)
        ]

        tokens_generated = self.tokenizer.convert_ids_to_tokens(token_ids_generated)

        minimum_token_prob = min(token_probs_generated)
        average_token_prob = sum(token_probs_generated) / len(token_probs_generated)

        maximum_diff_with_vocab = -1
        minimum_vocab_extreme_diff = 100000000000

        if features_to_extract["MDVTP"] == True or features_to_extract["MMDVP"] == True:
            size = len(token_probs_generated)
            for pos in range(size):
                vocabProbs = self.getVocabProbsAtPos(pos, conditional_probs)
                maximum_diff_with_vocab = max(
                    [
                        maximum_diff_with_vocab,
                        self.getDiffVocab(vocabProbs, token_probs_generated[pos]),
                    ]
                )
                minimum_vocab_extreme_diff = min(
                    [
                        minimum_vocab_extreme_diff,
                        self.getDiffMaximumWithMinimum(vocabProbs),
                    ]
                )

        # allFeatures = [minimum_token_prob, average_token_prob, maximum_diff_with_vocab, minimum_vocab_extreme_diff]

        allFeatures = {
            "mtp": minimum_token_prob,
            "avgtp": average_token_prob,
            "MDVTP": maximum_diff_with_vocab,
            "MMDVP": minimum_vocab_extreme_diff,
        }

        selectedFeatures = {}
        for key, feature in features_to_extract.items():
            if feature == True:
                selectedFeatures[key] = allFeatures[key]

        return selectedFeatures

    def getDiffVocab(self, vocabProbs, tprob):
        return (vocabProbs[0] - tprob).item()

    def getDiffMaximumWithMinimum(self, vocabProbs):
        return (vocabProbs[0] - vocabProbs[-1]).item()

# %% [markdown]
# ## Definition of the specific Models

# %%
class Gemma(LLMModel):
    def __init__(self):
        self.model_name = "google/gemma-7b-it"
        self.model = AutoModelForCausalLM.from_pretrained(
            self.model_name
        )
        self.tokenizer = AutoTokenizer.from_pretrained(self.model_name)
        super().__init__()


    def generate(self, inpt):
        inputs = self.tokenizer(
            [inpt], max_length=self.getMaxLength(), return_tensors="pt", truncation=True
        )
        summary_ids = self.model.generate(inputs["input_ids"])

        summary = self.tokenizer.decode(summary_ids[0], skip_special_tokens=True)

        return summary


class LLama(LLMModel):
    def __init__(self):
        self.model_name = "meta-llama/Llama-2-7b-chat-hf"
        self.model = AutoModelForCausalLM.from_pretrained(
            self.model_name,
        )
        self.tokenizer = AutoTokenizer.from_pretrained(self.model_name)
        super().__init__()


    def generate(self, inpt):
        inputs = self.tokenizer(
            [inpt], max_length=1024, return_tensors="pt", truncation=True
        )
        summary_ids = self.model.generate(inputs["input_ids"])

        summary = self.tokenizer.decode(summary_ids[0], skip_special_tokens=True)

        return summary


class Opt(LLMModel):
    def __init__(self):
        self.model_name = "facebook/opt-6.7b"
        self.model = AutoModelForCausalLM.from_pretrained(self.model_name)
        self.tokenizer = AutoTokenizer.from_pretrained(self.model_name)
        super().__init__()


    def generate(self, inpt):
        inputs = self.tokenizer(
            [inpt], max_length=self.getMaxLength(), return_tensors="pt", truncation=True
        )
        summary_ids = self.model.generate(inputs["input_ids"])

        summary = self.tokenizer.decode(summary_ids[0], skip_special_tokens=True)

        return summary


class Gptj(LLMModel):
    def __init__(self):
        self.model_name = "EleutherAI/gpt-j-6B"
        self.model = AutoModelForCausalLM.from_pretrained(self.model_name)
        self.tokenizer = AutoTokenizer.from_pretrained(self.model_name)
        super().__init__()


    def generate(self, inpt):
        inputs = self.tokenizer(
            [inpt], max_length=self.getMaxLength(), return_tensors="pt", truncation=True
        )
        summary_ids = self.model.generate(inputs["input_ids"])

        summary = self.tokenizer.decode(summary_ids[0], skip_special_tokens=True)

        return summary


class BartCNN(LLMModel):
    def __init__(self):
        self.model_name = "facebook/bart-large-cnn"
        self.model = BartForConditionalGeneration.from_pretrained(self.model_name)
        self.tokenizer = BartTokenizer.from_pretrained(self.model_name)
        super().__init__()


    def generate(self, inpt):
        inputs = self.tokenizer(
            [inpt], max_length=self.getMaxLength(), return_tensors="pt", truncation=True
        )
        summary_ids = self.model.generate(inputs["input_ids"])

        summary = self.tokenizer.decode(summary_ids[0], skip_special_tokens=True)

        return summary

class GPT2Generator(LLMModel):
    def __init__(self):
        self.model_name = "gpt2-large"
        self.model = GPT2LMHeadModel.from_pretrained(self.model_name)
        self.tokenizer = GPT2Tokenizer.from_pretrained(self.model_name)
        super().__init__()

    def generate(self, inpt):
        inputs = self.tokenizer.encode(
            inpt, return_tensors="pt", max_length=self.getMaxLength(), truncation=True
        )
        output_ids = self.model.generate(
            inputs, max_length=1024, num_return_sequences=1
        )
        output = self.tokenizer.decode(output_ids[0], skip_special_tokens=True)
        return output


class LED(LLMModel):
    def __init__(self):
        self.model_name = "allenai/led-large-16384-arxiv"
        self.model = LEDForConditionalGeneration.from_pretrained(self.model_name)
        self.tokenizer = LEDTokenizer.from_pretrained(self.model_name)
        super().__init__()

    def generate(self, inpt):
        inputs = self.tokenizer(
            [inpt], max_length=self.getMaxLength(), return_tensors="pt", truncation=True
        )
        summary_ids = self.model.generate(inputs["input_ids"])

        summary = self.tokenizer.decode(summary_ids[0], skip_special_tokens=True)

        return summary

# %% [markdown]
# # The Dictionary `features_to_extract` defines which features will be use in this experiment.
#
# ## Features Meaning:
#
# - `mtp` : Take the minimum of the probabilities that the LLM_E gives to the tokens on the generated-text.
# - `avgtp` : Take the average of the probabilities that the LLM_E
# gives to the tokens on the generated-text.
# - `MDVTP` : Take the maximum from all the differences
# between the token with the highest probability
# according to LLM_E at position i and the
# assigned probability from LLM_E to the token at position i in the generated_text.
# - `MMDVP` : Take the maximum from all the differences between the token with the highest probability according to $LLM_E$ at position $i$ ($v^*$) and the token with the lowest probability according to $LLM_E$ at position $i$ ($v^-$).

# %%
feature_to_extract = 'all'

available_features_to_extract = ["mtp", "avgtp", "MDVTP", "MMDVP"]
if feature_to_extract == 'all':
    features_to_extract = {
        feature: True for feature in available_features_to_extract
    }
else:
    features_to_extract = {
        feature: True if feature == feature_to_extract else False
        for feature in available_features_to_extract
    }

features_to_extract
# Out:
# {'mtp': True, 'avgtp': True, 'MDVTP': True, 'MMDVP': True}

# %% [markdown]
# ## Cleaning Cache on GPU to save memory

# %%
import torch
import gc

gc.collect()
torch.cuda.empty_cache()

# %% [markdown]
# ## This cell is to instantiate the model you intend to use for the experiment

# %%
# model = BartCNN()
# model = LED()
model = GPT2Generator()
# model = LLama()
# model = Gemma()
# model = Opt()
# model = Gptj()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:112: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/666 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.25G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/436 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %% [markdown]
# ## This cell creates the dataset separation of `10%` for training and `90%` for testing depending on what task you are addressing. The following explanation is what happens if summarization is the task used. But the same explanation applies to all tasks and also you cand pass as parameter how many data points you want to include in training.
#
# ## Example: The data is separated on 2000 (1000 of document with right summary and 1000 with the same document but with the hallucinated summary). The rest which is 18000 is used to for testing.
#
# ### As expected from previous cells the task string expected are:
# - `summarization`
# - `qa`
# - `dialogue`
# - `general`

# %%
import random


# Load the data depending on the task
def loadRowData(taskName, row, includeKnowledge=False):
    if taskName == "summarization":
        return "", row["document"], row["right_summary"], row["hallucinated_summary"]
    elif taskName == "qa":
        if includeKnowledge:
            return (
                row["knowledge"],
                row["question"],
                row["right_answer"],
                row["hallucinated_answer"],
            )
        else:
            return "", row["question"], row["right_answer"], row["hallucinated_answer"]

    elif taskName == "dialogue":
        if includeKnowledge:
            return (
                row["knowledge"],
                row["dialogue_history"],
                row["right_response"],
                row["hallucinated_response"],
            )
        else:
            return (
                "",
                row["dialogue_history"],
                row["right_response"],
                row["hallucinated_response"],
            )

    elif taskName == "general":
        return (
            "",
            row["user_query"],
            row["chatgpt_response"],
            row["hallucination_label"],
        )

    else:
        raise Exception("Task not supported")


# Adapt the dataset to have a data point of conditioned-text with right-generation and another with the same conditioned-text and tha hallucinated answer.
def adaptDataset(data, taskName):
    datasetAdapted = None
    if taskName == "general":
        # There is data point that is filling the <mask> token but that gives error with some LLMs
        datasetAdapted = [
            (
                (knowledge, document, response, 1)
                if hallu == "yes"
                else (knowledge, document, response, 0)
            )
            for knowledge, document, response, hallu in data
            if "<mask>" not in document and "<mask>" not in response
        ]

    elif taskName == "summarization" or taskName == "qa" or taskName == "dialogue":
        datasetAdapted = [
            (knowledge, document, right, 1)
            for knowledge, document, right, hallu in data
        ] + [
            (knowledge, document, hallu, 0)
            for knowledge, document, right, hallu in data
        ]

    else:
        raise Exception("Task not supported")

    #random.shuffle(datasetAdapted)
    return datasetAdapted

# %%
def splitDataset(
    data: pd.DataFrame,
    taskName: str,
    trainingSize: int,
    valSize: int,
    includeKnowledge=False,
):

    dataset = []
    for _, row in data.iterrows():
        knowledge, text, right, hallu = loadRowData(taskName, row, includeKnowledge)
        dataset.append((knowledge, text, right, hallu))

    #random.shuffle(dataset)

    dataset_train = dataset[:trainingSize]  # Take only trainingSize
    dataset_val = (
        []
    )  # dataset[trainingSize:trainingSize + valSize] # Take only trainingSize
    dataset_test = dataset[trainingSize:]  # Take the rest as testing

    datasetAdaptedTrain = adaptDataset(dataset_train, taskName)
    datasetAdaptedValidation = adaptDataset(dataset_val, taskName)
    datasetAdaptedTest = adaptDataset(dataset_test, taskName)

    X_train = [(x, q, y) for x, q, y, _ in datasetAdaptedTrain]
    Y_train = [z for _, _, _, z in datasetAdaptedTrain]

    X_val = [(x, q, y) for x, q, y, _ in datasetAdaptedValidation]
    Y_val = [z for _, _, _, z in datasetAdaptedValidation]

    X_test = [(x, q, y) for x, q, y, _ in datasetAdaptedTest]
    Y_test = [z for _, _, _, z in datasetAdaptedTest]

    return X_train, Y_train, X_val, Y_val, X_test, Y_test

# %%
includeKnowledge = True
includeConditioned = True

# %%
"""
X_train, Y_train, X_val, Y_val, X_test, Y_test = splitDataset(
    data, task, 2, 0, includeKnowledge=includeKnowledge
)
"""
# Out:
# '\nX_train, Y_train, X_val, Y_val, X_test, Y_test = splitDataset(\n    data, task, 2, 0, includeKnowledge=includeKnowledge\n)\n'

# %%
from sklearn.model_selection import train_test_split

# for now no validation

train_df, test_df = train_test_split(
    data,
    test_size=0.2,  # 20% test
    stratify=data["hallucination_label"],  # VERY important
    random_state=42
)

# %%
def df_to_XY(df):
    X, Y = [], []
    for _, row in df.iterrows():
        X.append(("", row["user_query"], row["chatgpt_response"]))
        Y.append(1 if row["hallucination_label"] == "yes" else 0)
    return X, Y

X_train, Y_train = df_to_XY(train_df)
X_test, Y_test = df_to_XY(test_df)
#X_val, Y_val = df_to_XY(val_df)

X_val = []
Y_val = []

# %%
print(len(X_train), len(Y_train))
print(len(X_val), len(Y_val))
print(len(X_test), len(Y_test))  # verify the sizes look right
# Out:
# 128 128
# 0 0
# 32 32

# %% [markdown]
# ## To Save the separation if needed

# %%
train_df = pd.DataFrame(
    {
        "Knowledge": [x[0] for x in X_train],
        "Conditioned Text": [x[1] for x in X_train],
        "Generated Text": [x[2] for x in X_train],
        "Label": Y_train,
    }
)

val_df = pd.DataFrame(
    {
        "Knowledge": [x[0] for x in X_val],
        "Conditioned Text": [x[1] for x in X_val],
        "Generated Text": [x[2] for x in X_val],
        "Label": Y_val,
    }
)

test_df = pd.DataFrame(
    {
        "Knowledge": [x[0] for x in X_test],
        "Conditioned Text": [x[1] for x in X_test],
        "Generated Text": [x[2] for x in X_test],
        "Label": Y_test,
    }
)

#Export to CSV
if includeKnowledge:
    train_df.to_csv(output_path / (task + '_knowledge_train_data.csv'), index=False)
    test_df.to_csv(output_path / (task + '_knowledge_test_data.csv'), index=False)
else:
    train_df.to_csv(output_path / (task + '_train_data.csv'), index=False)
    val_df.to_csv(output_path / (task + '_val_data.csv'), index=False)
    test_df.to_csv(output_path / (task + '_test_data.csv'), index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_12615/614916898.py in <cell line: 0>()
#      28 #Export to CSV
#      29 if includeKnowledge:
# ---> 30     train_df.to_csv(output_path / (task + '_knowledge_train_data.csv'), index=False)
#      31     test_df.to_csv(output_path / (task + '_knowledge_test_data.csv'), index=False)
#      32 else:
#
# NameError: name 'output_path' is not defined

# %%
def getXY(df: pd.DataFrame, includeKnowledge=True, includeConditioned=True):
    X = []
    Y = []

    # Iterate over rows using itertuples
    for _, row in df.iterrows():
        x, c, g = (
            row["Knowledge"] if includeKnowledge else "",
            row["Conditioned Text"] if includeConditioned else "",
            row["Generated Text"],
        # g = (row["Generated Text"]
        )
        y = row["Label"]

        # Append values to respective lists
        X.append((x, c, g))
        # X.append(g)
        Y.append(y)
    return X, Y

# %%
X_train, Y_train = getXY(
    train_df, includeKnowledge=includeKnowledge, includeConditioned=includeConditioned
)
X_val, Y_val = getXY(
    val_df, includeKnowledge=includeKnowledge, includeConditioned=includeConditioned
)
X_test, Y_test = getXY(
    test_df, includeKnowledge=includeKnowledge, includeConditioned=includeConditioned
)

# %%
print(len(X_train), len(Y_train))
print(len(X_val), len(Y_val))
print(len(X_test), len(Y_test))  # verify the sizes look right
# Out:
# 128 128
# 0 0
# 32 32

# %%
X_test[0]
# Out:
# ('',
#  'Are chromomethylases present in animal genomes?',
#  'Yes, chromomethylases are present in animal genomes. Chromomethylases are enzymes that play a role in DNA methylation, a process that involves adding a methyl group to DNA molecules, thereby affecting gene expression. While it was previously thought that chromomethylases were exclusive to plants and fungi, recent studies have identified similar proteins in a variety of animal species. These animal chromomethylases show similarities to their plant counterparts in terms of protein structure and catalytic activity, suggesting a conservation of function across different organisms. However, the exact roles and mechanisms of chromomethylases in animal genomes are still being studied.')

# %%
Y_test[0]
# Out:
# 1

# %% [markdown]
# ## Extracting the features for the Training Data

# %%
import torch
from tqdm import tqdm


def extract_features(
    knowledge: str,
    conditioned_text: str,
    generated_text: str,
    features_to_extract: dict[str, bool],
):
    return model.extractFeatures(
        knowledge, conditioned_text, generated_text, features_to_extract
    )


X_train_features_maps = []

for knowledge, conditioned_text, generated_text in tqdm(X_train, desc="Processing"):
    X_train_features_maps.append(
        extract_features(
            knowledge, conditioned_text, generated_text, features_to_extract
        )
    )
    torch.cuda.empty_cache()  # Clean cache in every step for memory saving.
# Out:
# Processing: 100%|██████████| 128/128 [00:19<00:00,  6.59it/s]

# %%
len(X_train_features_maps)
# Out:
# 128

# %%
X_train_features_maps[0] # for first datapoint
# Out:
# {'mtp': 4.549539411868864e-08,
#  'avgtp': 0.000241697369467759,
#  'MDVTP': 0.979781448841095,
#  'MMDVP': 0.09856486320495605}

# %%
X_train_features = [list(dic.values()) for dic in X_train_features_maps]

# %%
len(X_train_features) # 4 features for each datapoint
# Out:
# 128

# %%
X_train_features[0]
# Out:
# [4.549539411868864e-08,
#  0.000241697369467759,
#  0.979781448841095,
#  0.09856486320495605]

# %% [markdown]
# ## Training Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression(verbose=1)
"""verbose=1 in logistic regression
(specifically in libraries like scikit-learn) enables the display of progress information,
such as iteration counts and loss values, during the model training process.
It is used to monitor convergence, especially during long training sessions."""

clf.fit(X_train_features, Y_train) # len(X_train_features) = len(Y_train)
# Out:
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# LogisticRegression(verbose=1)

# %% [markdown]
# ## Evaluate accuracy of Logistic Regression on the training set

# %%
from sklearn.metrics import accuracy_score

# Y_Pred = clf.predict(X_train_features)
# NOTE: this is wrong: should be Y_Pred = clf.predict(X_test_features)
# accuracy = accuracy_score(Y_test, Y_Pred)
# could add: model.predict_proba(X_test)


# accuracy = accuracy_score(Y_train, Y_Pred)
# print(f"Accuracy: {accuracy * 100:.2f}%")

# %% [markdown]
# logit(p) = w1 x1 ​+ w2 x2 + w3 x3 + w4 x4 + b

# %%
## they are global weights learnt from entire training data:

# if my features are on different scale:
# from sklearn.preprocessing import StandardScaler

log_odds = clf.coef_[0] # clf.coef_[0] = clf.coef_
odds = np.exp(clf.coef_[0])


""" Safer to know the order:
feature_names = ["mtp", "avgtp", "Mpd", "mps"]

lr_features_log = dict(zip(feature_names, log_odds))
lr_features_no_log = dict(zip(feature_names, odds))
"""


lr_features_log = {k: v for k, v in zip(X_train_features_maps[0].keys(), log_odds)}
lr_features_no_log = {k: v for k, v in zip(X_train_features_maps[0].keys(), odds)}

print("log", lr_features_log)
print("no_log", lr_features_no_log)
# Out:
# log {'mtp': np.float64(-1.0435336213256333e-06), 'avgtp': np.float64(0.07251480419914413), 'MDVTP': np.float64(0.04318709362140292), 'MMDVP': np.float64(-0.04869500832840711)}
# no_log {'mtp': np.float64(0.9999989564669232), 'avgtp': np.float64(1.0752087235763972), 'MDVTP': np.float64(1.0441332272440325), 'MMDVP': np.float64(0.9524715813033195)}

# %% [markdown]
# ## Extracting the Features of the Validation Set

# %%
X_val_features_map = []

for knowledge, conditioned_text, generated_text in tqdm(X_val, desc="Processing"):
    X_val_features_map.append(
        extract_features(
            knowledge, conditioned_text, generated_text, features_to_extract
        )
    )
    torch.cuda.empty_cache()
# Out:
# Processing: 0it [00:00, ?it/s]

# %%
X_val_features = [list(dic.values()) for dic in X_val_features_map]

# %% [markdown]
# ## Uncomment next cell if you have a validation set and you want to see LR accuracy on it.

# %%
# from sklearn.metrics import accuracy_score

# Y_Pred = clf.predict(X_val_features)

# accuracy = accuracy_score(Y_val, Y_Pred)
# print(f"Accuracy: {accuracy * 100:.2f}%")

# %% [markdown]
# ## Extracting the Features of the Test Set

# %%
from tqdm import tqdm

X_test_features_map = []

for knowledge, conditioned_text, generated_text in tqdm(X_test, desc="Processing"):
    X_test_features_map.append(
        extract_features(
            knowledge, conditioned_text, generated_text, features_to_extract
        )
    )
    torch.cuda.empty_cache()
# Out:
# Processing: 100%|██████████| 32/32 [00:05<00:00,  5.91it/s]

# %%
X_test_features = [list(dic.values()) for dic in X_test_features_map]

# %% [markdown]
# ## Evaluate accuracy of the LogisticRegression on the testing set

# %%
from sklearn.metrics import accuracy_score

Y_Pred = clf.predict(X_test_features)

lr_accuracy = accuracy_score(Y_test, Y_Pred)
print(f"Accuracy: {lr_accuracy * 100:.2f}%")
# Out:
# Accuracy: 50.00%

# %%
log_odds = clf.coef_[0]
pd.DataFrame(log_odds, X_train_features_maps[0].keys(), columns=["coef"]).sort_values(
    by="coef", ascending=False
)
# Out:
#            coef
# avgtp  0.072515
# MDVTP  0.043187
# mtp   -0.000001
# MMDVP -0.048695

# %%
odds = np.exp(clf.coef_[0])
pd.DataFrame(odds, X_train_features_maps[0].keys(), columns=["coef"]).sort_values(
    by="coef", ascending=False
)
# Out:
#            coef
# avgtp  1.075209
# MDVTP  1.044133
# mtp    0.999999
# MMDVP  0.952472

# %% [markdown]
# ## Simple Dense NN

# %%
import torch.nn as nn


class SimpleDenseNet(nn.Module):
    def __init__(self, input_dim: int, hidden_dim: int, output_dim=1, dropout_prob=0.3):
        super(SimpleDenseNet, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, output_dim)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        x = self.relu(x)
        x = self.fc3(x)
        x = self.sigmoid(x)
        return x

# %%
denseModel = SimpleDenseNet(
    input_dim=np.array([v for v in features_to_extract.values()]).sum(), hidden_dim=512
).to(device)

# %% [markdown]
# # Code declaring and computing all the metrics to measure

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    roc_auc_score,
    precision_recall_curve,
    auc
)


def compute_metrics(model, input_tensor, true_labels):
    with torch.no_grad(): # torch.no_grad : disable gradient calculation
        outputs = model(input_tensor)
        predicted_probs = torch.sigmoid(outputs).cpu().numpy()
        predicted = (outputs > 0.5).float().cpu().numpy()

        true_labels = true_labels.cpu().numpy()

        acc = accuracy_score(true_labels, predicted)
        precision = precision_score(true_labels, predicted)
        recall = recall_score(true_labels, predicted)
        f1 = f1_score(true_labels, predicted)

        precision_negative = precision_score(true_labels, predicted, pos_label=0)
        recall_negative = recall_score(true_labels, predicted, pos_label=0)
        f1_negative = f1_score(true_labels, predicted, pos_label=0)

        tn, fp, fn, tp = confusion_matrix(true_labels, predicted).ravel()
        roc_auc = roc_auc_score(true_labels, predicted_probs)

        P, R, thre = precision_recall_curve(true_labels, predicted, pos_label=1)
        pr_auc = auc(R, P)

        roc_auc_negative = roc_auc_score(
            true_labels, 1 - predicted_probs
        )  # If predicted_probs is the probability of the positive class
        P_neg, R_neg, _ = precision_recall_curve(true_labels, predicted, pos_label=0)
        pr_auc_negative = auc(R_neg, P_neg)

        return {
            "Accuracy": acc,
            "Precision": precision,
            "Recall": recall,
            "F1": f1,
            "TP": tp,
            "TN": tn,
            "FP": fp,
            "FN": fn,
            "ROC AUC": roc_auc,
            "PR AUC": pr_auc,
            "Precision-Negative": precision_negative,
            "Recall-Negative": recall_negative,
            "F1-Negative": f1_negative,
            "ROC AUC-Negative": roc_auc_negative,
            "PR AUC-Negative": pr_auc_negative,
        }

# %% [markdown]
# ## Code for training the Dense Model and getting the result of all metrics corresponding to the Testing Set.

# %%
def compute_accuracy(model, input_tensor, true_labels):
    with torch.no_grad():
        outputs = model(input_tensor)
        predicted = (outputs > 0.5).float()
        correct = (predicted == true_labels).float().sum()
        accuracy = correct / len(true_labels)
        return accuracy.item()


X_train_tensor = torch.tensor(X_train_features, dtype=torch.float32).to(device)
Y_train_tensor = torch.tensor(Y_train, dtype=torch.float32).view(-1, 1).to(device)

print(X_train_tensor.shape, Y_train_tensor.shape)

# Define loss and optimizer
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(denseModel.parameters(), lr=0.001)

bestValAcc = 0
# Training loop
num_epochs = 20000
for epoch in range(num_epochs):
    denseModel.train()
    optimizer.zero_grad()
    outputs = denseModel(X_train_tensor)
    loss = criterion(outputs, Y_train_tensor)
    loss.backward()
    optimizer.step()

    # Compute training accuracy
    train_accuracy = compute_accuracy(denseModel, X_train_tensor, Y_train_tensor)

    # Uncomment this if you want to see how the accuracy of testing improves during the training process.
    ##Compute testing accuracy
    # X_val_tensor = torch.tensor(X_val_features, dtype=torch.float32).to(device)
    # Y_val_tensor = torch.tensor(Y_val, dtype=torch.float32).view(-1, 1).to(device)

    # val_accuracy = compute_accuracy(denseModel, X_val_tensor, Y_val_tensor)

    # if bestValAcc < val_accuracy:
    #     bestValAcc = val_accuracy
    #     print(f'Saving model with best validation accuracy ...')
    #     torch.save(denseModel.state_dict(), 'llama-' + task + '-best-model')

    if (epoch + 1) % 10 == 0:
        print(
            f"Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}, Training Accuracy: {train_accuracy:.4f}"
        )  # , "Validation Accuracy": {val_accuracy:.4f}')
# Out:
# torch.Size([128, 4]) torch.Size([128, 1])
# Epoch [10/20000], Loss: 0.6959, Training Accuracy: 0.5000
# Epoch [20/20000], Loss: 0.6928, Training Accuracy: 0.5000
# Epoch [30/20000], Loss: 0.6929, Training Accuracy: 0.5000
# Epoch [40/20000], Loss: 0.6923, Training Accuracy: 0.5078
# Epoch [50/20000], Loss: 0.6919, Training Accuracy: 0.5547
# Epoch [60/20000], Loss: 0.6915, Training Accuracy: 0.5469
# Epoch [70/20000], Loss: 0.6910, Training Accuracy: 0.5547
# Epoch [80/20000], Loss: 0.6904, Training Accuracy: 0.5547
# Epoch [90/20000], Loss: 0.6896, Training Accuracy: 0.5547
# Epoch [100/20000], Loss: 0.6885, Training Accuracy: 0.5547
# Epoch [110/20000], Loss: 0.6873, Training Accuracy: 0.5547
# Epoch [120/20000], Loss: 0.6857, Training Accuracy: 0.5625
# Epoch [130/20000], Loss: 0.6839, Training Accuracy: 0.5781
# Epoch [140/20000], Loss: 0.6820, Training Accuracy: 0.5781
# Epoch [150/20000], Loss: 0.6803, Training Accuracy: 0.5703
# Epoch [160/20000], Loss: 0.6785, Training Accuracy: 0.5781
# Epoch [170/20000], Loss: 0.6770, Training Accuracy: 0.5703
# Epoch [180/20000], Loss: 0.6768, Training Accuracy: 0.5469
# Epoch [190/20000], Loss: 0.6748, Training Accuracy: 0.5859
# Epoch [200/20000], Loss: 0.6741, Training Accuracy: 0.5781
# Epoch [210/20000], Loss: 0.6736, Training Accuracy: 0.5938
# Epoch [220/20000], Loss: 0.6737, Training Accuracy: 0.5625
# Epoch [230/20000], Loss: 0.6727, Training Accuracy: 0.6016
# Epoch [240/20000], Loss: 0.6723, Training Accuracy: 0.5703
# Epoch [250/20000], Loss: 0.6729, Training Accuracy: 0.5547
# Epoch [260/20000], Loss: 0.6721, Training Accuracy: 0.5703
# Epoch [270/20000], Loss: 0.6714, Training Accuracy: 0.5781
# Epoch [280/20000], Loss: 0.6713, Training Accuracy: 0.5859
# Epoch [290/20000], Loss: 0.6713, Training Accuracy: 0.6016
# Epoch [300/20000], Loss: 0.6722, Training Accuracy: 0.5703
# Epoch [310/20000], Loss: 0.6714, Training Accuracy: 0.5859
# Epoch [320/20000], Loss: 0.6708, Training Accuracy: 0.6016
# Epoch [330/20000], Loss: 0.6707, Training Accuracy: 0.5938
# Epoch [340/20000], Loss: 0.6706, Training Accuracy: 0.5781
# Epoch [350/20000], Loss: 0.6705, Training Accuracy: 0.5781
# Epoch [360/20000], Loss: 0.6704, Training Accuracy: 0.5547
# Epoch [370/20000], Loss: 0.6703, Training Accuracy: 0.5547
# Epoch [380/20000], Loss: 0.6702, Training Accuracy: 0.5625
# Epoch [390/20000], Loss: 0.6702, Training Accuracy: 0.5938
# Epoch [400/20000], Loss: 0.6746, Training Accuracy: 0.5391
# Epoch [410/20000], Loss: 0.6713, Training Accuracy: 0.5703
# Epoch [420/20000], Loss: 0.6704, Training Accuracy: 0.5781
# Epoch [430/20000], Loss: 0.6699, Training Accuracy: 0.5781
# Epoch [440/20000], Loss: 0.6697, Training Accuracy: 0.5703
# Epoch [450/20000], Loss: 0.6696, Training Accuracy: 0.5859
# Epoch [460/20000], Loss: 0.6696, Training Accuracy: 0.5703
# Epoch [470/20000], Loss: 0.6695, Training Accuracy: 0.5781
# Epoch [480/20000], Loss: 0.6694, Training Accuracy: 0.5781
# Epoch [490/20000], Loss: 0.6693, Training Accuracy: 0.5781
# Epoch [500/20000], Loss: 0.6692, Training Accuracy: 0.5781
# Epoch [510/20000], Loss: 0.6691, Training Accuracy: 0.5781
# Epoch [520/20000], Loss: 0.6690, Training Accuracy: 0.5781
# Epoch [530/20000], Loss: 0.6689, Training Accuracy: 0.5859
# Epoch [540/20000], Loss: 0.6688, Training Accuracy: 0.5781
# Epoch [550/20000], Loss: 0.6687, Training Accuracy: 0.5859
# Epoch [560/20000], Loss: 0.6687, Training Accuracy: 0.5703
# Epoch [570/20000], Loss: 0.6722, Training Accuracy: 0.5391
# Epoch [580/20000], Loss: 0.6687, Training Accuracy: 0.5781
# Epoch [590/20000], Loss: 0.6685, Training Accuracy: 0.5938
# Epoch [600/20000], Loss: 0.6683, Training Accuracy: 0.5703
# Epoch [610/20000], Loss: 0.6682, Training Accuracy: 0.5781
# Epoch [620/20000], Loss: 0.6681, Training Accuracy: 0.5781
# Epoch [630/20000], Loss: 0.6680, Training Accuracy: 0.5859
# Epoch [640/20000], Loss: 0.6679, Training Accuracy: 0.5859
# Epoch [650/20000], Loss: 0.6678, Training Accuracy: 0.5781
# Epoch [660/20000], Loss: 0.6679, Training Accuracy: 0.5781
# Epoch [670/20000], Loss: 0.6694, Training Accuracy: 0.5781
# Epoch [680/20000], Loss: 0.6676, Training Accuracy: 0.5703
# Epoch [690/20000], Loss: 0.6677, Training Accuracy: 0.5703
# Epoch [700/20000], Loss: 0.6673, Training Accuracy: 0.5781
# Epoch [710/20000], Loss: 0.6673, Training Accuracy: 0.5781
# Epoch [720/20000], Loss: 0.6672, Training Accuracy: 0.5781
# Epoch [730/20000], Loss: 0.6671, Training Accuracy: 0.5625
# Epoch [740/20000], Loss: 0.6681, Training Accuracy: 0.5938
# Epoch [750/20000], Loss: 0.6670, Training Accuracy: 0.5703
# Epoch [760/20000], Loss: 0.6669, Training Accuracy: 0.5703
# Epoch [770/20000], Loss: 0.6667, Training Accuracy: 0.5781
# Epoch [780/20000], Loss: 0.6666, Training Accuracy: 0.5703
# Epoch [790/20000], Loss: 0.6665, Training Accuracy: 0.5859
# Epoch [800/20000], Loss: 0.6690, Training Accuracy: 0.5781
# Epoch [810/20000], Loss: 0.6671, Training Accuracy: 0.5781
# Epoch [820/20000], Loss: 0.6661, Training Accuracy: 0.5547
# Epoch [830/20000], Loss: 0.6661, Training Accuracy: 0.5703
# Epoch [840/20000], Loss: 0.6660, Training Accuracy: 0.5625
# Epoch [850/20000], Loss: 0.6657, Training Accuracy: 0.5859
# Epoch [860/20000], Loss: 0.6657, Training Accuracy: 0.5859
# Epoch [870/20000], Loss: 0.6675, Training Accuracy: 0.5781
# Epoch [880/20000], Loss: 0.6663, Training Accuracy: 0.5859
# Epoch [890/20000], Loss: 0.6656, Training Accuracy: 0.5859
# Epoch [900/20000], Loss: 0.6651, Training Accuracy: 0.5703
# Epoch [910/20000], Loss: 0.6650, Training Accuracy: 0.5781
# Epoch [920/20000], Loss: 0.6649, Training Accuracy: 0.5547
# Epoch [930/20000], Loss: 0.6671, Training Accuracy: 0.5703
# Epoch [940/20000], Loss: 0.6651, Training Accuracy: 0.5859
# Epoch [950/20000], Loss: 0.6644, Training Accuracy: 0.5938
# Epoch [960/20000], Loss: 0.6642, Training Accuracy: 0.5703
# Epoch [970/20000], Loss: 0.6641, Training Accuracy: 0.5703
# Epoch [980/20000], Loss: 0.6639, Training Accuracy: 0.5938
# Epoch [990/20000], Loss: 0.6683, Training Accuracy: 0.5781
# Epoch [1000/20000], Loss: 0.6638, Training Accuracy: 0.5859
# Epoch [1010/20000], Loss: 0.6640, Training Accuracy: 0.5625
# Epoch [1020/20000], Loss: 0.6635, Training Accuracy: 0.5625
# Epoch [1030/20000], Loss: 0.6632, Training Accuracy: 0.5547
# Epoch [1040/20000], Loss: 0.6630, Training Accuracy: 0.5625
# Epoch [1050/20000], Loss: 0.6628, Training Accuracy: 0.5625
# Epoch [1060/20000], Loss: 0.6627, Training Accuracy: 0.5547
# Epoch [1070/20000], Loss: 0.6653, Training Accuracy: 0.5469
# Epoch [1080/20000], Loss: 0.6635, Training Accuracy: 0.5859
# Epoch [1090/20000], Loss: 0.6626, Training Accuracy: 0.5625
# Epoch [1100/20000], Loss: 0.6623, Training Accuracy: 0.5781
# Epoch [1110/20000], Loss: 0.6618, Training Accuracy: 0.5703
# Epoch [1120/20000], Loss: 0.6615, Training Accuracy: 0.5469
# Epoch [1130/20000], Loss: 0.6640, Training Accuracy: 0.5391
# Epoch [1140/20000], Loss: 0.6648, Training Accuracy: 0.5859
# Epoch [1150/20000], Loss: 0.6622, Training Accuracy: 0.5781
# Epoch [1160/20000], Loss: 0.6612, Training Accuracy: 0.5703
# Epoch [1170/20000], Loss: 0.6607, Training Accuracy: 0.5781
# Epoch [1180/20000], Loss: 0.6605, Training Accuracy: 0.5703
# Epoch [1190/20000], Loss: 0.6602, Training Accuracy: 0.5547
# Epoch [1200/20000], Loss: 0.6600, Training Accuracy: 0.5547
# Epoch [1210/20000], Loss: 0.6598, Training Accuracy: 0.5547
# Epoch [1220/20000], Loss: 0.6601, Training Accuracy: 0.5781
# Epoch [1230/20000], Loss: 0.6611, Training Accuracy: 0.5469
# Epoch [1240/20000], Loss: 0.6593, Training Accuracy: 0.5703
# Epoch [1250/20000], Loss: 0.6601, Training Accuracy: 0.5781
# Epoch [1260/20000], Loss: 0.6587, Training Accuracy: 0.5703
# Epoch [1270/20000], Loss: 0.6604, Training Accuracy: 0.5469
# Epoch [1280/20000], Loss: 0.6584, Training Accuracy: 0.5625
# Epoch [1290/20000], Loss: 0.6588, Training Accuracy: 0.5625
# Epoch [1300/20000], Loss: 0.6587, Training Accuracy: 0.5547
# Epoch [1310/20000], Loss: 0.6586, Training Accuracy: 0.5469
# Epoch [1320/20000], Loss: 0.6574, Training Accuracy: 0.5625
# Epoch [1330/20000], Loss: 0.6575, Training Accuracy: 0.5703
# Epoch [1340/20000], Loss: 0.6574, Training Accuracy: 0.5625
# Epoch [1350/20000], Loss: 0.6570, Training Accuracy: 0.5625
# Epoch [1360/20000], Loss: 0.6574, Training Accuracy: 0.5547
# Epoch [1370/20000], Loss: 0.6577, Training Accuracy: 0.5469
# Epoch [1380/20000], Loss: 0.6568, Training Accuracy: 0.5859
# Epoch [1390/20000], Loss: 0.6565, Training Accuracy: 0.5625
# Epoch [1400/20000], Loss: 0.6560, Training Accuracy: 0.5625
# Epoch [1410/20000], Loss: 0.6578, Training Accuracy: 0.5938
# Epoch [1420/20000], Loss: 0.6554, Training Accuracy: 0.5469
# Epoch [1430/20000], Loss: 0.6549, Training Accuracy: 0.5703
# Epoch [1440/20000], Loss: 0.6554, Training Accuracy: 0.5781
# Epoch [1450/20000], Loss: 0.6545, Training Accuracy: 0.5625
# Epoch [1460/20000], Loss: 0.6564, Training Accuracy: 0.6016
# Epoch [1470/20000], Loss: 0.6538, Training Accuracy: 0.5625
# Epoch [1480/20000], Loss: 0.6535, Training Accuracy: 0.5625
# Epoch [1490/20000], Loss: 0.6534, Training Accuracy: 0.5547
# Epoch [1500/20000], Loss: 0.6538, Training Accuracy: 0.5469
# Epoch [1510/20000], Loss: 0.6560, Training Accuracy: 0.5391
# Epoch [1520/20000], Loss: 0.6541, Training Accuracy: 0.5781
# Epoch [1530/20000], Loss: 0.6533, Training Accuracy: 0.5703
# Epoch [1540/20000], Loss: 0.6525, Training Accuracy: 0.5859
# Epoch [1550/20000], Loss: 0.6533, Training Accuracy: 0.5781
# Epoch [1560/20000], Loss: 0.6527, Training Accuracy: 0.5781
# Epoch [1570/20000], Loss: 0.6527, Training Accuracy: 0.5781
# Epoch [1580/20000], Loss: 0.6529, Training Accuracy: 0.5703
# Epoch [1590/20000], Loss: 0.6518, Training Accuracy: 0.5703
# Epoch [1600/20000], Loss: 0.6519, Training Accuracy: 0.5469
# Epoch [1610/20000], Loss: 0.6524, Training Accuracy: 0.5859
# Epoch [1620/20000], Loss: 0.6508, Training Accuracy: 0.5703
# Epoch [1630/20000], Loss: 0.6522, Training Accuracy: 0.5234
# Epoch [1640/20000], Loss: 0.6512, Training Accuracy: 0.5469
# Epoch [1650/20000], Loss: 0.6506, Training Accuracy: 0.5859
# Epoch [1660/20000], Loss: 0.6516, Training Accuracy: 0.5859
# Epoch [1670/20000], Loss: 0.6498, Training Accuracy: 0.5625
# Epoch [1680/20000], Loss: 0.6543, Training Accuracy: 0.5469
# Epoch [1690/20000], Loss: 0.6513, Training Accuracy: 0.5781
# Epoch [1700/20000], Loss: 0.6503, Training Accuracy: 0.5703
# Epoch [1710/20000], Loss: 0.6494, Training Accuracy: 0.5781
# Epoch [1720/20000], Loss: 0.6488, Training Accuracy: 0.5391
# Epoch [1730/20000], Loss: 0.6492, Training Accuracy: 0.5391
# Epoch [1740/20000], Loss: 0.6522, Training Accuracy: 0.5547
# Epoch [1750/20000], Loss: 0.6487, Training Accuracy: 0.5938
# Epoch [1760/20000], Loss: 0.6481, Training Accuracy: 0.5547
# Epoch [1770/20000], Loss: 0.6480, Training Accuracy: 0.5391
# Epoch [1780/20000], Loss: 0.6483, Training Accuracy: 0.5781
# Epoch [1790/20000], Loss: 0.6476, Training Accuracy: 0.5547
# Epoch [1800/20000], Loss: 0.6497, Training Accuracy: 0.5469
# Epoch [1810/20000], Loss: 0.6478, Training Accuracy: 0.5859
# Epoch [1820/20000], Loss: 0.6484, Training Accuracy: 0.5703
# Epoch [1830/20000], Loss: 0.6476, Training Accuracy: 0.5781
# Epoch [1840/20000], Loss: 0.6470, Training Accuracy: 0.5625
# Epoch [1850/20000], Loss: 0.6470, Training Accuracy: 0.5547
# Epoch [1860/20000], Loss: 0.6472, Training Accuracy: 0.5547
# Epoch [1870/20000], Loss: 0.6491, Training Accuracy: 0.5625
# Epoch [1880/20000], Loss: 0.6476, Training Accuracy: 0.5781
# Epoch [1890/20000], Loss: 0.6462, Training Accuracy: 0.5625
# Epoch [1900/20000], Loss: 0.6464, Training Accuracy: 0.5469
# Epoch [1910/20000], Loss: 0.6460, Training Accuracy: 0.5625
# Epoch [1920/20000], Loss: 0.6513, Training Accuracy: 0.6172
# Epoch [1930/20000], Loss: 0.6474, Training Accuracy: 0.5469
# Epoch [1940/20000], Loss: 0.6458, Training Accuracy: 0.5781
# Epoch [1950/20000], Loss: 0.6449, Training Accuracy: 0.5781
# Epoch [1960/20000], Loss: 0.6475, Training Accuracy: 0.6094
# Epoch [1970/20000], Loss: 0.6444, Training Accuracy: 0.5625
# Epoch [1980/20000], Loss: 0.6448, Training Accuracy: 0.5547
# Epoch [1990/20000], Loss: 0.6459, Training Accuracy: 0.5938
# Epoch [2000/20000], Loss: 0.6446, Training Accuracy: 0.5703
# Epoch [2010/20000], Loss: 0.6443, Training Accuracy: 0.5703
# Epoch [2020/20000], Loss: 0.6443, Training Accuracy: 0.5703
# Epoch [2030/20000], Loss: 0.6466, Training Accuracy: 0.5547
# Epoch [2040/20000], Loss: 0.6438, Training Accuracy: 0.5781
# Epoch [2050/20000], Loss: 0.6440, Training Accuracy: 0.5781
# Epoch [2060/20000], Loss: 0.6432, Training Accuracy: 0.5625
# Epoch [2070/20000], Loss: 0.6443, Training Accuracy: 0.5625
# Epoch [2080/20000], Loss: 0.6435, Training Accuracy: 0.5547
# Epoch [2090/20000], Loss: 0.6430, Training Accuracy: 0.5703
# Epoch [2100/20000], Loss: 0.6434, Training Accuracy: 0.5859
# Epoch [2110/20000], Loss: 0.6429, Training Accuracy: 0.5703
# Epoch [2120/20000], Loss: 0.6426, Training Accuracy: 0.5938
# Epoch [2130/20000], Loss: 0.6422, Training Accuracy: 0.5703
# Epoch [2140/20000], Loss: 0.6434, Training Accuracy: 0.5781
# Epoch [2150/20000], Loss: 0.6425, Training Accuracy: 0.5781
# Epoch [2160/20000], Loss: 0.6420, Training Accuracy: 0.5859
# Epoch [2170/20000], Loss: 0.6438, Training Accuracy: 0.5312
# Epoch [2180/20000], Loss: 0.6421, Training Accuracy: 0.5859
# Epoch [2190/20000], Loss: 0.6417, Training Accuracy: 0.5625
# Epoch [2200/20000], Loss: 0.6420, Training Accuracy: 0.5703
# Epoch [2210/20000], Loss: 0.6411, Training Accuracy: 0.5703
# Epoch [2220/20000], Loss: 0.6437, Training Accuracy: 0.5938
# Epoch [2230/20000], Loss: 0.6408, Training Accuracy: 0.5859
# Epoch [2240/20000], Loss: 0.6419, Training Accuracy: 0.5625
# Epoch [2250/20000], Loss: 0.6404, Training Accuracy: 0.5625
# Epoch [2260/20000], Loss: 0.6409, Training Accuracy: 0.5938
# Epoch [2270/20000], Loss: 0.6450, Training Accuracy: 0.5938
# Epoch [2280/20000], Loss: 0.6415, Training Accuracy: 0.5703
# Epoch [2290/20000], Loss: 0.6403, Training Accuracy: 0.5938
# Epoch [2300/20000], Loss: 0.6399, Training Accuracy: 0.5781
# Epoch [2310/20000], Loss: 0.6399, Training Accuracy: 0.5938
# Epoch [2320/20000], Loss: 0.6402, Training Accuracy: 0.5625
# Epoch [2330/20000], Loss: 0.6457, Training Accuracy: 0.5625
# Epoch [2340/20000], Loss: 0.6411, Training Accuracy: 0.5859
# Epoch [2350/20000], Loss: 0.6399, Training Accuracy: 0.5781
# Epoch [2360/20000], Loss: 0.6393, Training Accuracy: 0.5938
# Epoch [2370/20000], Loss: 0.6393, Training Accuracy: 0.5938
# Epoch [2380/20000], Loss: 0.6402, Training Accuracy: 0.5859
# Epoch [2390/20000], Loss: 0.6411, Training Accuracy: 0.5859
# Epoch [2400/20000], Loss: 0.6387, Training Accuracy: 0.6016
# Epoch [2410/20000], Loss: 0.6394, Training Accuracy: 0.5703
# Epoch [2420/20000], Loss: 0.6410, Training Accuracy: 0.5469
# Epoch [2430/20000], Loss: 0.6386, Training Accuracy: 0.6016
# Epoch [2440/20000], Loss: 0.6384, Training Accuracy: 0.6016
# Epoch [2450/20000], Loss: 0.6386, Training Accuracy: 0.5781
# Epoch [2460/20000], Loss: 0.6423, Training Accuracy: 0.5859
# Epoch [2470/20000], Loss: 0.6379, Training Accuracy: 0.6016
# Epoch [2480/20000], Loss: 0.6393, Training Accuracy: 0.5859
# Epoch [2490/20000], Loss: 0.6391, Training Accuracy: 0.5938
# Epoch [2500/20000], Loss: 0.6387, Training Accuracy: 0.5703
# Epoch [2510/20000], Loss: 0.6377, Training Accuracy: 0.5938
# Epoch [2520/20000], Loss: 0.6376, Training Accuracy: 0.6016
# Epoch [2530/20000], Loss: 0.6371, Training Accuracy: 0.6016
# Epoch [2540/20000], Loss: 0.6380, Training Accuracy: 0.5547
# Epoch [2550/20000], Loss: 0.6403, Training Accuracy: 0.5859
# Epoch [2560/20000], Loss: 0.6371, Training Accuracy: 0.5781
# Epoch [2570/20000], Loss: 0.6380, Training Accuracy: 0.5859
# Epoch [2580/20000], Loss: 0.6370, Training Accuracy: 0.5938
# Epoch [2590/20000], Loss: 0.6367, Training Accuracy: 0.6172
# Epoch [2600/20000], Loss: 0.6366, Training Accuracy: 0.5938
# Epoch [2610/20000], Loss: 0.6363, Training Accuracy: 0.6172
# Epoch [2620/20000], Loss: 0.6365, Training Accuracy: 0.5938
# Epoch [2630/20000], Loss: 0.6373, Training Accuracy: 0.5781
# Epoch [2640/20000], Loss: 0.6378, Training Accuracy: 0.5781
# Epoch [2650/20000], Loss: 0.6359, Training Accuracy: 0.6172
# Epoch [2660/20000], Loss: 0.6359, Training Accuracy: 0.6094
# Epoch [2670/20000], Loss: 0.6391, Training Accuracy: 0.5859
# Epoch [2680/20000], Loss: 0.6356, Training Accuracy: 0.6094
# Epoch [2690/20000], Loss: 0.6370, Training Accuracy: 0.5703
# Epoch [2700/20000], Loss: 0.6353, Training Accuracy: 0.6094
# Epoch [2710/20000], Loss: 0.6366, Training Accuracy: 0.5781
# Epoch [2720/20000], Loss: 0.6358, Training Accuracy: 0.6016
# Epoch [2730/20000], Loss: 0.6359, Training Accuracy: 0.5859
# Epoch [2740/20000], Loss: 0.6354, Training Accuracy: 0.6094
# Epoch [2750/20000], Loss: 0.6349, Training Accuracy: 0.6094
# Epoch [2760/20000], Loss: 0.6364, Training Accuracy: 0.5703
# Epoch [2770/20000], Loss: 0.6352, Training Accuracy: 0.6094
# Epoch [2780/20000], Loss: 0.6353, Training Accuracy: 0.5859
# Epoch [2790/20000], Loss: 0.6359, Training Accuracy: 0.5859
# Epoch [2800/20000], Loss: 0.6341, Training Accuracy: 0.6094
# Epoch [2810/20000], Loss: 0.6360, Training Accuracy: 0.5781
# Epoch [2820/20000], Loss: 0.6348, Training Accuracy: 0.6094
# Epoch [2830/20000], Loss: 0.6358, Training Accuracy: 0.5938
# Epoch [2840/20000], Loss: 0.6336, Training Accuracy: 0.6094
# Epoch [2850/20000], Loss: 0.6342, Training Accuracy: 0.6094
# Epoch [2860/20000], Loss: 0.6343, Training Accuracy: 0.6172
# Epoch [2870/20000], Loss: 0.6337, Training Accuracy: 0.6172
# Epoch [2880/20000], Loss: 0.6375, Training Accuracy: 0.5781
# Epoch [2890/20000], Loss: 0.6331, Training Accuracy: 0.6172
# Epoch [2900/20000], Loss: 0.6337, Training Accuracy: 0.6094
# Epoch [2910/20000], Loss: 0.6334, Training Accuracy: 0.6172
# Epoch [2920/20000], Loss: 0.6340, Training Accuracy: 0.6016
# Epoch [2930/20000], Loss: 0.6329, Training Accuracy: 0.6094
# Epoch [2940/20000], Loss: 0.6325, Training Accuracy: 0.6094
# Epoch [2950/20000], Loss: 0.6329, Training Accuracy: 0.6094
# Epoch [2960/20000], Loss: 0.6455, Training Accuracy: 0.5938
# Epoch [2970/20000], Loss: 0.6328, Training Accuracy: 0.6094
# Epoch [2980/20000], Loss: 0.6337, Training Accuracy: 0.6016
# Epoch [2990/20000], Loss: 0.6323, Training Accuracy: 0.6094
# Epoch [3000/20000], Loss: 0.6319, Training Accuracy: 0.6094
# Epoch [3010/20000], Loss: 0.6318, Training Accuracy: 0.6172
# Epoch [3020/20000], Loss: 0.6317, Training Accuracy: 0.6094
# Epoch [3030/20000], Loss: 0.6315, Training Accuracy: 0.6094
# Epoch [3040/20000], Loss: 0.6314, Training Accuracy: 0.6172
# Epoch [3050/20000], Loss: 0.6315, Training Accuracy: 0.6172
# Epoch [3060/20000], Loss: 0.6403, Training Accuracy: 0.6250
# Epoch [3070/20000], Loss: 0.6342, Training Accuracy: 0.5859
# Epoch [3080/20000], Loss: 0.6325, Training Accuracy: 0.5859
# Epoch [3090/20000], Loss: 0.6314, Training Accuracy: 0.6016
# Epoch [3100/20000], Loss: 0.6307, Training Accuracy: 0.6328
# Epoch [3110/20000], Loss: 0.6307, Training Accuracy: 0.6172
# Epoch [3120/20000], Loss: 0.6305, Training Accuracy: 0.6172
# Epoch [3130/20000], Loss: 0.6339, Training Accuracy: 0.5938
# Epoch [3140/20000], Loss: 0.6304, Training Accuracy: 0.6094
# Epoch [3150/20000], Loss: 0.6308, Training Accuracy: 0.6094
# Epoch [3160/20000], Loss: 0.6306, Training Accuracy: 0.6172
# Epoch [3170/20000], Loss: 0.6307, Training Accuracy: 0.6016
# Epoch [3180/20000], Loss: 0.6298, Training Accuracy: 0.6250
# Epoch [3190/20000], Loss: 0.6297, Training Accuracy: 0.6172
# Epoch [3200/20000], Loss: 0.6326, Training Accuracy: 0.6172
# Epoch [3210/20000], Loss: 0.6297, Training Accuracy: 0.6172
# Epoch [3220/20000], Loss: 0.6294, Training Accuracy: 0.6172
# Epoch [3230/20000], Loss: 0.6293, Training Accuracy: 0.6172
# Epoch [3240/20000], Loss: 0.6295, Training Accuracy: 0.6016
# Epoch [3250/20000], Loss: 0.6292, Training Accuracy: 0.6172
# Epoch [3260/20000], Loss: 0.6305, Training Accuracy: 0.6094
# Epoch [3270/20000], Loss: 0.6312, Training Accuracy: 0.6172
# Epoch [3280/20000], Loss: 0.6288, Training Accuracy: 0.6250
# Epoch [3290/20000], Loss: 0.6286, Training Accuracy: 0.6172
# Epoch [3300/20000], Loss: 0.6305, Training Accuracy: 0.5859
# Epoch [3310/20000], Loss: 0.6307, Training Accuracy: 0.5938
# Epoch [3320/20000], Loss: 0.6287, Training Accuracy: 0.6172
# Epoch [3330/20000], Loss: 0.6281, Training Accuracy: 0.6172
# Epoch [3340/20000], Loss: 0.6280, Training Accuracy: 0.6172
# Epoch [3350/20000], Loss: 0.6281, Training Accuracy: 0.6016
# Epoch [3360/20000], Loss: 0.6277, Training Accuracy: 0.6250
# Epoch [3370/20000], Loss: 0.6280, Training Accuracy: 0.6172
# Epoch [3380/20000], Loss: 0.6332, Training Accuracy: 0.6328
# Epoch [3390/20000], Loss: 0.6281, Training Accuracy: 0.6094
# Epoch [3400/20000], Loss: 0.6279, Training Accuracy: 0.6094
# Epoch [3410/20000], Loss: 0.6278, Training Accuracy: 0.6094
# Epoch [3420/20000], Loss: 0.6292, Training Accuracy: 0.6016
# Epoch [3430/20000], Loss: 0.6277, Training Accuracy: 0.6094
# Epoch [3440/20000], Loss: 0.6273, Training Accuracy: 0.6250
# Epoch [3450/20000], Loss: 0.6306, Training Accuracy: 0.6172
# Epoch [3460/20000], Loss: 0.6265, Training Accuracy: 0.6094
# Epoch [3470/20000], Loss: 0.6281, Training Accuracy: 0.6172
# Epoch [3480/20000], Loss: 0.6262, Training Accuracy: 0.6250
# Epoch [3490/20000], Loss: 0.6275, Training Accuracy: 0.6016
# Epoch [3500/20000], Loss: 0.6291, Training Accuracy: 0.6094
# Epoch [3510/20000], Loss: 0.6296, Training Accuracy: 0.5859
# Epoch [3520/20000], Loss: 0.6279, Training Accuracy: 0.6016
# Epoch [3530/20000], Loss: 0.6260, Training Accuracy: 0.5938
# Epoch [3540/20000], Loss: 0.6256, Training Accuracy: 0.6094
# Epoch [3550/20000], Loss: 0.6258, Training Accuracy: 0.6172
# Epoch [3560/20000], Loss: 0.6316, Training Accuracy: 0.6562
# Epoch [3570/20000], Loss: 0.6259, Training Accuracy: 0.6094
# Epoch [3580/20000], Loss: 0.6250, Training Accuracy: 0.6172
# Epoch [3590/20000], Loss: 0.6259, Training Accuracy: 0.6250
# Epoch [3600/20000], Loss: 0.6246, Training Accuracy: 0.6172
# Epoch [3610/20000], Loss: 0.6254, Training Accuracy: 0.6094
# Epoch [3620/20000], Loss: 0.6295, Training Accuracy: 0.5938
# Epoch [3630/20000], Loss: 0.6280, Training Accuracy: 0.6562
# Epoch [3640/20000], Loss: 0.6278, Training Accuracy: 0.6016
# Epoch [3650/20000], Loss: 0.6264, Training Accuracy: 0.6016
# Epoch [3660/20000], Loss: 0.6247, Training Accuracy: 0.6016
# Epoch [3670/20000], Loss: 0.6242, Training Accuracy: 0.6094
# Epoch [3680/20000], Loss: 0.6237, Training Accuracy: 0.6016
# Epoch [3690/20000], Loss: 0.6234, Training Accuracy: 0.6172
# Epoch [3700/20000], Loss: 0.6233, Training Accuracy: 0.6172
# Epoch [3710/20000], Loss: 0.6247, Training Accuracy: 0.6016
# Epoch [3720/20000], Loss: 0.6295, Training Accuracy: 0.5859
# Epoch [3730/20000], Loss: 0.6266, Training Accuracy: 0.6094
# Epoch [3740/20000], Loss: 0.6250, Training Accuracy: 0.5938
# Epoch [3750/20000], Loss: 0.6232, Training Accuracy: 0.6250
# Epoch [3760/20000], Loss: 0.6227, Training Accuracy: 0.6250
# Epoch [3770/20000], Loss: 0.6225, Training Accuracy: 0.6094
# Epoch [3780/20000], Loss: 0.6249, Training Accuracy: 0.6016
# Epoch [3790/20000], Loss: 0.6234, Training Accuracy: 0.6016
# Epoch [3800/20000], Loss: 0.6221, Training Accuracy: 0.6172
# Epoch [3810/20000], Loss: 0.6244, Training Accuracy: 0.6016
# Epoch [3820/20000], Loss: 0.6229, Training Accuracy: 0.6250
# Epoch [3830/20000], Loss: 0.6215, Training Accuracy: 0.6172
# Epoch [3840/20000], Loss: 0.6224, Training Accuracy: 0.6094
# Epoch [3850/20000], Loss: 0.6297, Training Accuracy: 0.6016
# Epoch [3860/20000], Loss: 0.6255, Training Accuracy: 0.6094
# Epoch [3870/20000], Loss: 0.6234, Training Accuracy: 0.5938
# Epoch [3880/20000], Loss: 0.6213, Training Accuracy: 0.6328
# Epoch [3890/20000], Loss: 0.6208, Training Accuracy: 0.6250
# Epoch [3900/20000], Loss: 0.6209, Training Accuracy: 0.6094
# Epoch [3910/20000], Loss: 0.6234, Training Accuracy: 0.6094
# Epoch [3920/20000], Loss: 0.6228, Training Accuracy: 0.6172
# Epoch [3930/20000], Loss: 0.6204, Training Accuracy: 0.6250
# Epoch [3940/20000], Loss: 0.6220, Training Accuracy: 0.6016
# Epoch [3950/20000], Loss: 0.6231, Training Accuracy: 0.6016
# Epoch [3960/20000], Loss: 0.6198, Training Accuracy: 0.6094
# Epoch [3970/20000], Loss: 0.6201, Training Accuracy: 0.6250
# Epoch [3980/20000], Loss: 0.6285, Training Accuracy: 0.6094
# Epoch [3990/20000], Loss: 0.6208, Training Accuracy: 0.6016
# Epoch [4000/20000], Loss: 0.6194, Training Accuracy: 0.6172
# Epoch [4010/20000], Loss: 0.6213, Training Accuracy: 0.6250
# Epoch [4020/20000], Loss: 0.6191, Training Accuracy: 0.6094
# Epoch [4030/20000], Loss: 0.6189, Training Accuracy: 0.6094
# Epoch [4040/20000], Loss: 0.6225, Training Accuracy: 0.6016
# Epoch [4050/20000], Loss: 0.6187, Training Accuracy: 0.6328
# Epoch [4060/20000], Loss: 0.6186, Training Accuracy: 0.6172
# Epoch [4070/20000], Loss: 0.6185, Training Accuracy: 0.6406
# Epoch [4080/20000], Loss: 0.6183, Training Accuracy: 0.6094
# Epoch [4090/20000], Loss: 0.6180, Training Accuracy: 0.6328
# Epoch [4100/20000], Loss: 0.6186, Training Accuracy: 0.6406
# Epoch [4110/20000], Loss: 0.6192, Training Accuracy: 0.6094
# Epoch [4120/20000], Loss: 0.6216, Training Accuracy: 0.6094
# Epoch [4130/20000], Loss: 0.6175, Training Accuracy: 0.6094
# Epoch [4140/20000], Loss: 0.6215, Training Accuracy: 0.6094
# Epoch [4150/20000], Loss: 0.6175, Training Accuracy: 0.6094
# Epoch [4160/20000], Loss: 0.6202, Training Accuracy: 0.6484
# Epoch [4170/20000], Loss: 0.6171, Training Accuracy: 0.6250
# Epoch [4180/20000], Loss: 0.6170, Training Accuracy: 0.6172
# Epoch [4190/20000], Loss: 0.6169, Training Accuracy: 0.6172
# Epoch [4200/20000], Loss: 0.6166, Training Accuracy: 0.6328
# Epoch [4210/20000], Loss: 0.6166, Training Accuracy: 0.6250
# Epoch [4220/20000], Loss: 0.6167, Training Accuracy: 0.6172
# Epoch [4230/20000], Loss: 0.6182, Training Accuracy: 0.6328
# Epoch [4240/20000], Loss: 0.6168, Training Accuracy: 0.6172
# Epoch [4250/20000], Loss: 0.6186, Training Accuracy: 0.6172
# Epoch [4260/20000], Loss: 0.6183, Training Accuracy: 0.6328
# Epoch [4270/20000], Loss: 0.6157, Training Accuracy: 0.6172
# Epoch [4280/20000], Loss: 0.6215, Training Accuracy: 0.6562
# Epoch [4290/20000], Loss: 0.6154, Training Accuracy: 0.6172
# Epoch [4300/20000], Loss: 0.6182, Training Accuracy: 0.6328
# Epoch [4310/20000], Loss: 0.6157, Training Accuracy: 0.6250
# Epoch [4320/20000], Loss: 0.6164, Training Accuracy: 0.6094
# Epoch [4330/20000], Loss: 0.6158, Training Accuracy: 0.6250
# Epoch [4340/20000], Loss: 0.6181, Training Accuracy: 0.6406
# Epoch [4350/20000], Loss: 0.6159, Training Accuracy: 0.6406
# Epoch [4360/20000], Loss: 0.6162, Training Accuracy: 0.6328
# Epoch [4370/20000], Loss: 0.6167, Training Accuracy: 0.6328
# Epoch [4380/20000], Loss: 0.6150, Training Accuracy: 0.6172
# Epoch [4390/20000], Loss: 0.6165, Training Accuracy: 0.6172
# Epoch [4400/20000], Loss: 0.6142, Training Accuracy: 0.6406
# Epoch [4410/20000], Loss: 0.6147, Training Accuracy: 0.6172
# Epoch [4420/20000], Loss: 0.6215, Training Accuracy: 0.6562
# Epoch [4430/20000], Loss: 0.6151, Training Accuracy: 0.6328
# Epoch [4440/20000], Loss: 0.6146, Training Accuracy: 0.6250
# Epoch [4450/20000], Loss: 0.6133, Training Accuracy: 0.6172
# Epoch [4460/20000], Loss: 0.6137, Training Accuracy: 0.6172
# Epoch [4470/20000], Loss: 0.6166, Training Accuracy: 0.6172
# Epoch [4480/20000], Loss: 0.6164, Training Accuracy: 0.6484
# Epoch [4490/20000], Loss: 0.6145, Training Accuracy: 0.6406
# Epoch [4500/20000], Loss: 0.6125, Training Accuracy: 0.6094
# Epoch [4510/20000], Loss: 0.6124, Training Accuracy: 0.6484
# Epoch [4520/20000], Loss: 0.6125, Training Accuracy: 0.6406
# Epoch [4530/20000], Loss: 0.6120, Training Accuracy: 0.6250
# Epoch [4540/20000], Loss: 0.6126, Training Accuracy: 0.6328
# Epoch [4550/20000], Loss: 0.6134, Training Accuracy: 0.6328
# Epoch [4560/20000], Loss: 0.6154, Training Accuracy: 0.6406
# Epoch [4570/20000], Loss: 0.6114, Training Accuracy: 0.6250
# Epoch [4580/20000], Loss: 0.6142, Training Accuracy: 0.6250
# Epoch [4590/20000], Loss: 0.6133, Training Accuracy: 0.6328
# Epoch [4600/20000], Loss: 0.6111, Training Accuracy: 0.6172
# Epoch [4610/20000], Loss: 0.6128, Training Accuracy: 0.6406
# Epoch [4620/20000], Loss: 0.6155, Training Accuracy: 0.6406
# Epoch [4630/20000], Loss: 0.6150, Training Accuracy: 0.6172
# Epoch [4640/20000], Loss: 0.6128, Training Accuracy: 0.6406
# Epoch [4650/20000], Loss: 0.6109, Training Accuracy: 0.6406
# Epoch [4660/20000], Loss: 0.6112, Training Accuracy: 0.6406
# Epoch [4670/20000], Loss: 0.6109, Training Accuracy: 0.6406
# Epoch [4680/20000], Loss: 0.6151, Training Accuracy: 0.6484
# Epoch [4690/20000], Loss: 0.6103, Training Accuracy: 0.6406
# Epoch [4700/20000], Loss: 0.6134, Training Accuracy: 0.6250
# Epoch [4710/20000], Loss: 0.6098, Training Accuracy: 0.6250
# Epoch [4720/20000], Loss: 0.6127, Training Accuracy: 0.6250
# Epoch [4730/20000], Loss: 0.6103, Training Accuracy: 0.6406
# Epoch [4740/20000], Loss: 0.6096, Training Accuracy: 0.6484
# Epoch [4750/20000], Loss: 0.6157, Training Accuracy: 0.6797
# Epoch [4760/20000], Loss: 0.6090, Training Accuracy: 0.6172
# Epoch [4770/20000], Loss: 0.6115, Training Accuracy: 0.6406
# Epoch [4780/20000], Loss: 0.6088, Training Accuracy: 0.6406
# Epoch [4790/20000], Loss: 0.6100, Training Accuracy: 0.6250
# Epoch [4800/20000], Loss: 0.6137, Training Accuracy: 0.6406
# Epoch [4810/20000], Loss: 0.6083, Training Accuracy: 0.6328
# Epoch [4820/20000], Loss: 0.6136, Training Accuracy: 0.6328
# Epoch [4830/20000], Loss: 0.6080, Training Accuracy: 0.6406
# Epoch [4840/20000], Loss: 0.6100, Training Accuracy: 0.6406
# Epoch [4850/20000], Loss: 0.6107, Training Accuracy: 0.6406
# Epoch [4860/20000], Loss: 0.6080, Training Accuracy: 0.6406
# Epoch [4870/20000], Loss: 0.6107, Training Accuracy: 0.6406
# Epoch [4880/20000], Loss: 0.6095, Training Accuracy: 0.6328
# Epoch [4890/20000], Loss: 0.6086, Training Accuracy: 0.6484
# Epoch [4900/20000], Loss: 0.6091, Training Accuracy: 0.6484
# Epoch [4910/20000], Loss: 0.6072, Training Accuracy: 0.6484
# Epoch [4920/20000], Loss: 0.6131, Training Accuracy: 0.6328
# Epoch [4930/20000], Loss: 0.6070, Training Accuracy: 0.6328
# Epoch [4940/20000], Loss: 0.6091, Training Accuracy: 0.6484
# Epoch [4950/20000], Loss: 0.6072, Training Accuracy: 0.6406
# Epoch [4960/20000], Loss: 0.6094, Training Accuracy: 0.6406
# Epoch [4970/20000], Loss: 0.6088, Training Accuracy: 0.6328
# Epoch [4980/20000], Loss: 0.6065, Training Accuracy: 0.6484
# Epoch [4990/20000], Loss: 0.6101, Training Accuracy: 0.6484
# Epoch [5000/20000], Loss: 0.6071, Training Accuracy: 0.6406
# Epoch [5010/20000], Loss: 0.6096, Training Accuracy: 0.6406
# Epoch [5020/20000], Loss: 0.6062, Training Accuracy: 0.6484
# Epoch [5030/20000], Loss: 0.6072, Training Accuracy: 0.6328
# Epoch [5040/20000], Loss: 0.6067, Training Accuracy: 0.6328
# Epoch [5050/20000], Loss: 0.6104, Training Accuracy: 0.6406
# Epoch [5060/20000], Loss: 0.6053, Training Accuracy: 0.6641
# Epoch [5070/20000], Loss: 0.6055, Training Accuracy: 0.6406
# Epoch [5080/20000], Loss: 0.6114, Training Accuracy: 0.6406
# Epoch [5090/20000], Loss: 0.6049, Training Accuracy: 0.6406
# Epoch [5100/20000], Loss: 0.6080, Training Accuracy: 0.6484
# Epoch [5110/20000], Loss: 0.6045, Training Accuracy: 0.6484
# Epoch [5120/20000], Loss: 0.6076, Training Accuracy: 0.6250
# Epoch [5130/20000], Loss: 0.6061, Training Accuracy: 0.6406
# Epoch [5140/20000], Loss: 0.6089, Training Accuracy: 0.6484
# Epoch [5150/20000], Loss: 0.6043, Training Accuracy: 0.6562
# Epoch [5160/20000], Loss: 0.6068, Training Accuracy: 0.6406
# Epoch [5170/20000], Loss: 0.6042, Training Accuracy: 0.6484
# Epoch [5180/20000], Loss: 0.6063, Training Accuracy: 0.6406
# Epoch [5190/20000], Loss: 0.6083, Training Accuracy: 0.6406
# Epoch [5200/20000], Loss: 0.6057, Training Accuracy: 0.6562
# Epoch [5210/20000], Loss: 0.6037, Training Accuracy: 0.6484
# Epoch [5220/20000], Loss: 0.6048, Training Accuracy: 0.6562
# Epoch [5230/20000], Loss: 0.6068, Training Accuracy: 0.6406
# Epoch [5240/20000], Loss: 0.6029, Training Accuracy: 0.6484
# Epoch [5250/20000], Loss: 0.6028, Training Accuracy: 0.6406
# Epoch [5260/20000], Loss: 0.6157, Training Accuracy: 0.6172
# Epoch [5270/20000], Loss: 0.6077, Training Accuracy: 0.6484
# Epoch [5280/20000], Loss: 0.6053, Training Accuracy: 0.6328
# Epoch [5290/20000], Loss: 0.6036, Training Accuracy: 0.6406
# Epoch [5300/20000], Loss: 0.6027, Training Accuracy: 0.6484
# Epoch [5310/20000], Loss: 0.6023, Training Accuracy: 0.6406
# Epoch [5320/20000], Loss: 0.6019, Training Accuracy: 0.6562
# Epoch [5330/20000], Loss: 0.6019, Training Accuracy: 0.6562
# Epoch [5340/20000], Loss: 0.6115, Training Accuracy: 0.6328
# Epoch [5350/20000], Loss: 0.6017, Training Accuracy: 0.6406
# Epoch [5360/20000], Loss: 0.6021, Training Accuracy: 0.6562
# Epoch [5370/20000], Loss: 0.6037, Training Accuracy: 0.6562
# Epoch [5380/20000], Loss: 0.6026, Training Accuracy: 0.6406
# Epoch [5390/20000], Loss: 0.6020, Training Accuracy: 0.6484
# Epoch [5400/20000], Loss: 0.6015, Training Accuracy: 0.6562
# Epoch [5410/20000], Loss: 0.6066, Training Accuracy: 0.6562
# Epoch [5420/20000], Loss: 0.6015, Training Accuracy: 0.6562
# Epoch [5430/20000], Loss: 0.6026, Training Accuracy: 0.6484
# Epoch [5440/20000], Loss: 0.6030, Training Accuracy: 0.6562
# Epoch [5450/20000], Loss: 0.6010, Training Accuracy: 0.6641
# Epoch [5460/20000], Loss: 0.6087, Training Accuracy: 0.6328
# Epoch [5470/20000], Loss: 0.6003, Training Accuracy: 0.6406
# Epoch [5480/20000], Loss: 0.6016, Training Accuracy: 0.6562
# Epoch [5490/20000], Loss: 0.6004, Training Accuracy: 0.6641
# Epoch [5500/20000], Loss: 0.6024, Training Accuracy: 0.6406
# Epoch [5510/20000], Loss: 0.6036, Training Accuracy: 0.6406
# Epoch [5520/20000], Loss: 0.5995, Training Accuracy: 0.6797
# Epoch [5530/20000], Loss: 0.6010, Training Accuracy: 0.6562
# Epoch [5540/20000], Loss: 0.6070, Training Accuracy: 0.6562
# Epoch [5550/20000], Loss: 0.6006, Training Accuracy: 0.6562
# Epoch [5560/20000], Loss: 0.6005, Training Accuracy: 0.6719
# Epoch [5570/20000], Loss: 0.5993, Training Accuracy: 0.6562
# Epoch [5580/20000], Loss: 0.6036, Training Accuracy: 0.6484
# Epoch [5590/20000], Loss: 0.5993, Training Accuracy: 0.6562
# Epoch [5600/20000], Loss: 0.5997, Training Accuracy: 0.6562
# Epoch [5610/20000], Loss: 0.6050, Training Accuracy: 0.6562
# Epoch [5620/20000], Loss: 0.5987, Training Accuracy: 0.6562
# Epoch [5630/20000], Loss: 0.5994, Training Accuracy: 0.6484
# Epoch [5640/20000], Loss: 0.6054, Training Accuracy: 0.6250
# Epoch [5650/20000], Loss: 0.5981, Training Accuracy: 0.6562
# Epoch [5660/20000], Loss: 0.6022, Training Accuracy: 0.6641
# Epoch [5670/20000], Loss: 0.5982, Training Accuracy: 0.6562
# Epoch [5680/20000], Loss: 0.5999, Training Accuracy: 0.6641
# Epoch [5690/20000], Loss: 0.6044, Training Accuracy: 0.6484
# Epoch [5700/20000], Loss: 0.5975, Training Accuracy: 0.6641
# Epoch [5710/20000], Loss: 0.6011, Training Accuracy: 0.6406
# Epoch [5720/20000], Loss: 0.5985, Training Accuracy: 0.6719
# Epoch [5730/20000], Loss: 0.5971, Training Accuracy: 0.6562
# Epoch [5740/20000], Loss: 0.6054, Training Accuracy: 0.6641
# Epoch [5750/20000], Loss: 0.5968, Training Accuracy: 0.6641
# Epoch [5760/20000], Loss: 0.5982, Training Accuracy: 0.6719
# Epoch [5770/20000], Loss: 0.5967, Training Accuracy: 0.6562
# Epoch [5780/20000], Loss: 0.6005, Training Accuracy: 0.6562
# Epoch [5790/20000], Loss: 0.5989, Training Accuracy: 0.6641
# Epoch [5800/20000], Loss: 0.5962, Training Accuracy: 0.6797
# Epoch [5810/20000], Loss: 0.6014, Training Accuracy: 0.6250
# Epoch [5820/20000], Loss: 0.5984, Training Accuracy: 0.6641
# Epoch [5830/20000], Loss: 0.6017, Training Accuracy: 0.6484
# Epoch [5840/20000], Loss: 0.5957, Training Accuracy: 0.6797
# Epoch [5850/20000], Loss: 0.5981, Training Accuracy: 0.6562
# Epoch [5860/20000], Loss: 0.5972, Training Accuracy: 0.6562
# Epoch [5870/20000], Loss: 0.5991, Training Accuracy: 0.6406
# Epoch [5880/20000], Loss: 0.6003, Training Accuracy: 0.6406
# Epoch [5890/20000], Loss: 0.5951, Training Accuracy: 0.6875
# Epoch [5900/20000], Loss: 0.5980, Training Accuracy: 0.6719
# Epoch [5910/20000], Loss: 0.5987, Training Accuracy: 0.6641
# Epoch [5920/20000], Loss: 0.5948, Training Accuracy: 0.6875
# Epoch [5930/20000], Loss: 0.5956, Training Accuracy: 0.6562
# Epoch [5940/20000], Loss: 0.6112, Training Accuracy: 0.6875
# Epoch [5950/20000], Loss: 0.5999, Training Accuracy: 0.6250
# Epoch [5960/20000], Loss: 0.5952, Training Accuracy: 0.6562
# Epoch [5970/20000], Loss: 0.5944, Training Accuracy: 0.6875
# Epoch [5980/20000], Loss: 0.5959, Training Accuracy: 0.6641
# Epoch [5990/20000], Loss: 0.5946, Training Accuracy: 0.6719
# Epoch [6000/20000], Loss: 0.5938, Training Accuracy: 0.6875
# Epoch [6010/20000], Loss: 0.5939, Training Accuracy: 0.6641
# Epoch [6020/20000], Loss: 0.6252, Training Accuracy: 0.6172
# Epoch [6030/20000], Loss: 0.6071, Training Accuracy: 0.6328
# Epoch [6040/20000], Loss: 0.5960, Training Accuracy: 0.6562
# Epoch [6050/20000], Loss: 0.5934, Training Accuracy: 0.6875
# Epoch [6060/20000], Loss: 0.5932, Training Accuracy: 0.7031
# Epoch [6070/20000], Loss: 0.5932, Training Accuracy: 0.6953
# Epoch [6080/20000], Loss: 0.5931, Training Accuracy: 0.6797
# Epoch [6090/20000], Loss: 0.5929, Training Accuracy: 0.6797
# Epoch [6100/20000], Loss: 0.5939, Training Accuracy: 0.6719
# Epoch [6110/20000], Loss: 0.6086, Training Accuracy: 0.6875
# Epoch [6120/20000], Loss: 0.5969, Training Accuracy: 0.6172
# Epoch [6130/20000], Loss: 0.5924, Training Accuracy: 0.6562
# Epoch [6140/20000], Loss: 0.5930, Training Accuracy: 0.6719
# Epoch [6150/20000], Loss: 0.5925, Training Accuracy: 0.6797
# Epoch [6160/20000], Loss: 0.5933, Training Accuracy: 0.6719
# Epoch [6170/20000], Loss: 0.5955, Training Accuracy: 0.6484
# Epoch [6180/20000], Loss: 0.5977, Training Accuracy: 0.6406
# Epoch [6190/20000], Loss: 0.5924, Training Accuracy: 0.6719
# Epoch [6200/20000], Loss: 0.5938, Training Accuracy: 0.6719
# Epoch [6210/20000], Loss: 0.5922, Training Accuracy: 0.6641
# Epoch [6220/20000], Loss: 0.5924, Training Accuracy: 0.6719
# Epoch [6230/20000], Loss: 0.6028, Training Accuracy: 0.6875
# Epoch [6240/20000], Loss: 0.5910, Training Accuracy: 0.6797
# Epoch [6250/20000], Loss: 0.5918, Training Accuracy: 0.6797
# Epoch [6260/20000], Loss: 0.5903, Training Accuracy: 0.6953
# Epoch [6270/20000], Loss: 0.5904, Training Accuracy: 0.6953
# Epoch [6280/20000], Loss: 0.6072, Training Accuracy: 0.6172
# Epoch [6290/20000], Loss: 0.5941, Training Accuracy: 0.6797
# Epoch [6300/20000], Loss: 0.5917, Training Accuracy: 0.6641
# Epoch [6310/20000], Loss: 0.5905, Training Accuracy: 0.6641
# Epoch [6320/20000], Loss: 0.5897, Training Accuracy: 0.6953
# Epoch [6330/20000], Loss: 0.5906, Training Accuracy: 0.6719
# Epoch [6340/20000], Loss: 0.5905, Training Accuracy: 0.6797
# Epoch [6350/20000], Loss: 0.5948, Training Accuracy: 0.6250
# Epoch [6360/20000], Loss: 0.5910, Training Accuracy: 0.6797
# Epoch [6370/20000], Loss: 0.5902, Training Accuracy: 0.6641
# Epoch [6380/20000], Loss: 0.5962, Training Accuracy: 0.6875
# Epoch [6390/20000], Loss: 0.5889, Training Accuracy: 0.6953
# Epoch [6400/20000], Loss: 0.5916, Training Accuracy: 0.6562
# Epoch [6410/20000], Loss: 0.5940, Training Accuracy: 0.6562
# Epoch [6420/20000], Loss: 0.5885, Training Accuracy: 0.6953
# Epoch [6430/20000], Loss: 0.5888, Training Accuracy: 0.6797
# Epoch [6440/20000], Loss: 0.6034, Training Accuracy: 0.6875
# Epoch [6450/20000], Loss: 0.5913, Training Accuracy: 0.6250
# Epoch [6460/20000], Loss: 0.5883, Training Accuracy: 0.6719
# Epoch [6470/20000], Loss: 0.5880, Training Accuracy: 0.6953
# Epoch [6480/20000], Loss: 0.5882, Training Accuracy: 0.7031
# Epoch [6490/20000], Loss: 0.5896, Training Accuracy: 0.6719
# Epoch [6500/20000], Loss: 0.5881, Training Accuracy: 0.6797
# Epoch [6510/20000], Loss: 0.5902, Training Accuracy: 0.6875
# Epoch [6520/20000], Loss: 0.5945, Training Accuracy: 0.6875
# Epoch [6530/20000], Loss: 0.5875, Training Accuracy: 0.6875
# Epoch [6540/20000], Loss: 0.5917, Training Accuracy: 0.6562
# Epoch [6550/20000], Loss: 0.5882, Training Accuracy: 0.6875
# Epoch [6560/20000], Loss: 0.5881, Training Accuracy: 0.6875
# Epoch [6570/20000], Loss: 0.5997, Training Accuracy: 0.6250
# Epoch [6580/20000], Loss: 0.5883, Training Accuracy: 0.6719
# Epoch [6590/20000], Loss: 0.5879, Training Accuracy: 0.6797
# Epoch [6600/20000], Loss: 0.5865, Training Accuracy: 0.7031
# Epoch [6610/20000], Loss: 0.5897, Training Accuracy: 0.6562
# Epoch [6620/20000], Loss: 0.5929, Training Accuracy: 0.6562
# Epoch [6630/20000], Loss: 0.5875, Training Accuracy: 0.6641
# Epoch [6640/20000], Loss: 0.5896, Training Accuracy: 0.6719
# Epoch [6650/20000], Loss: 0.5858, Training Accuracy: 0.6953
# Epoch [6660/20000], Loss: 0.5870, Training Accuracy: 0.6719
# Epoch [6670/20000], Loss: 0.5997, Training Accuracy: 0.6328
# Epoch [6680/20000], Loss: 0.5873, Training Accuracy: 0.6797
# Epoch [6690/20000], Loss: 0.5865, Training Accuracy: 0.6797
# Epoch [6700/20000], Loss: 0.5884, Training Accuracy: 0.6719
# Epoch [6710/20000], Loss: 0.5855, Training Accuracy: 0.7031
# Epoch [6720/20000], Loss: 0.5854, Training Accuracy: 0.7031
# Epoch [6730/20000], Loss: 0.5910, Training Accuracy: 0.6406
# Epoch [6740/20000], Loss: 0.5884, Training Accuracy: 0.6875
# Epoch [6750/20000], Loss: 0.5907, Training Accuracy: 0.6875
# Epoch [6760/20000], Loss: 0.5854, Training Accuracy: 0.6875
# Epoch [6770/20000], Loss: 0.5857, Training Accuracy: 0.6875
# Epoch [6780/20000], Loss: 0.5857, Training Accuracy: 0.6875
# Epoch [6790/20000], Loss: 0.5925, Training Accuracy: 0.6406
# Epoch [6800/20000], Loss: 0.5844, Training Accuracy: 0.6953
# Epoch [6810/20000], Loss: 0.5845, Training Accuracy: 0.6875
# Epoch [6820/20000], Loss: 0.5937, Training Accuracy: 0.6250
# Epoch [6830/20000], Loss: 0.5841, Training Accuracy: 0.6953
# Epoch [6840/20000], Loss: 0.5869, Training Accuracy: 0.6797
# Epoch [6850/20000], Loss: 0.5858, Training Accuracy: 0.6719
# Epoch [6860/20000], Loss: 0.5846, Training Accuracy: 0.6719
# Epoch [6870/20000], Loss: 0.5938, Training Accuracy: 0.7188
# Epoch [6880/20000], Loss: 0.5831, Training Accuracy: 0.6953
# Epoch [6890/20000], Loss: 0.5888, Training Accuracy: 0.6641
# Epoch [6900/20000], Loss: 0.5851, Training Accuracy: 0.6797
# Epoch [6910/20000], Loss: 0.5837, Training Accuracy: 0.6797
# Epoch [6920/20000], Loss: 0.5826, Training Accuracy: 0.7031
# Epoch [6930/20000], Loss: 0.5827, Training Accuracy: 0.7031
# Epoch [6940/20000], Loss: 0.6018, Training Accuracy: 0.6172
# Epoch [6950/20000], Loss: 0.5865, Training Accuracy: 0.7031
# Epoch [6960/20000], Loss: 0.5828, Training Accuracy: 0.6953
# Epoch [6970/20000], Loss: 0.5827, Training Accuracy: 0.6953
# Epoch [6980/20000], Loss: 0.5846, Training Accuracy: 0.6641
# Epoch [6990/20000], Loss: 0.5819, Training Accuracy: 0.7031
# Epoch [7000/20000], Loss: 0.5854, Training Accuracy: 0.6562
# Epoch [7010/20000], Loss: 0.5859, Training Accuracy: 0.6641
# Epoch [7020/20000], Loss: 0.5828, Training Accuracy: 0.6875
# Epoch [7030/20000], Loss: 0.5865, Training Accuracy: 0.6484
# Epoch [7040/20000], Loss: 0.5841, Training Accuracy: 0.6953
# Epoch [7050/20000], Loss: 0.5810, Training Accuracy: 0.6875
# Epoch [7060/20000], Loss: 0.5845, Training Accuracy: 0.7031
# Epoch [7070/20000], Loss: 0.5896, Training Accuracy: 0.6953
# Epoch [7080/20000], Loss: 0.5883, Training Accuracy: 0.6484
# Epoch [7090/20000], Loss: 0.5831, Training Accuracy: 0.6719
# Epoch [7100/20000], Loss: 0.5806, Training Accuracy: 0.6953
# Epoch [7110/20000], Loss: 0.5810, Training Accuracy: 0.6875
# Epoch [7120/20000], Loss: 0.5872, Training Accuracy: 0.6484
# Epoch [7130/20000], Loss: 0.5821, Training Accuracy: 0.6875
# Epoch [7140/20000], Loss: 0.5804, Training Accuracy: 0.6875
# Epoch [7150/20000], Loss: 0.5914, Training Accuracy: 0.6406
# Epoch [7160/20000], Loss: 0.5797, Training Accuracy: 0.6875
# Epoch [7170/20000], Loss: 0.5870, Training Accuracy: 0.7031
# Epoch [7180/20000], Loss: 0.5796, Training Accuracy: 0.6953
# Epoch [7190/20000], Loss: 0.5845, Training Accuracy: 0.6484
# Epoch [7200/20000], Loss: 0.5804, Training Accuracy: 0.6875
# Epoch [7210/20000], Loss: 0.5833, Training Accuracy: 0.6484
# Epoch [7220/20000], Loss: 0.5844, Training Accuracy: 0.6562
# Epoch [7230/20000], Loss: 0.5792, Training Accuracy: 0.7031
# Epoch [7240/20000], Loss: 0.5842, Training Accuracy: 0.6562
# Epoch [7250/20000], Loss: 0.5818, Training Accuracy: 0.7031
# Epoch [7260/20000], Loss: 0.5787, Training Accuracy: 0.6875
# Epoch [7270/20000], Loss: 0.5886, Training Accuracy: 0.7188
# Epoch [7280/20000], Loss: 0.5790, Training Accuracy: 0.6875
# Epoch [7290/20000], Loss: 0.5859, Training Accuracy: 0.6562
# Epoch [7300/20000], Loss: 0.5779, Training Accuracy: 0.6953
# Epoch [7310/20000], Loss: 0.5839, Training Accuracy: 0.7031
# Epoch [7320/20000], Loss: 0.5787, Training Accuracy: 0.6797
# Epoch [7330/20000], Loss: 0.5820, Training Accuracy: 0.7109
# Epoch [7340/20000], Loss: 0.5806, Training Accuracy: 0.6719
# Epoch [7350/20000], Loss: 0.5774, Training Accuracy: 0.7109
# Epoch [7360/20000], Loss: 0.5844, Training Accuracy: 0.6484
# Epoch [7370/20000], Loss: 0.5783, Training Accuracy: 0.7109
# Epoch [7380/20000], Loss: 0.5861, Training Accuracy: 0.7031
# Epoch [7390/20000], Loss: 0.5791, Training Accuracy: 0.6797
# Epoch [7400/20000], Loss: 0.5779, Training Accuracy: 0.6953
# Epoch [7410/20000], Loss: 0.5785, Training Accuracy: 0.6719
# Epoch [7420/20000], Loss: 0.5834, Training Accuracy: 0.7031
# Epoch [7430/20000], Loss: 0.5764, Training Accuracy: 0.6953
# Epoch [7440/20000], Loss: 0.5784, Training Accuracy: 0.6875
# Epoch [7450/20000], Loss: 0.5879, Training Accuracy: 0.7031
# Epoch [7460/20000], Loss: 0.5783, Training Accuracy: 0.6719
# Epoch [7470/20000], Loss: 0.5774, Training Accuracy: 0.7031
# Epoch [7480/20000], Loss: 0.5756, Training Accuracy: 0.6953
# Epoch [7490/20000], Loss: 0.5852, Training Accuracy: 0.7031
# Epoch [7500/20000], Loss: 0.5758, Training Accuracy: 0.7109
# Epoch [7510/20000], Loss: 0.5813, Training Accuracy: 0.6719
# Epoch [7520/20000], Loss: 0.5762, Training Accuracy: 0.6797
# Epoch [7530/20000], Loss: 0.5790, Training Accuracy: 0.6953
# Epoch [7540/20000], Loss: 0.5766, Training Accuracy: 0.6797
# Epoch [7550/20000], Loss: 0.5779, Training Accuracy: 0.6953
# Epoch [7560/20000], Loss: 0.5831, Training Accuracy: 0.7031
# Epoch [7570/20000], Loss: 0.5748, Training Accuracy: 0.6953
# Epoch [7580/20000], Loss: 0.5819, Training Accuracy: 0.6562
# Epoch [7590/20000], Loss: 0.5746, Training Accuracy: 0.7031
# Epoch [7600/20000], Loss: 0.5771, Training Accuracy: 0.6719
# Epoch [7610/20000], Loss: 0.5817, Training Accuracy: 0.6641
# Epoch [7620/20000], Loss: 0.5762, Training Accuracy: 0.6953
# Epoch [7630/20000], Loss: 0.5773, Training Accuracy: 0.6875
# Epoch [7640/20000], Loss: 0.5769, Training Accuracy: 0.6719
# Epoch [7650/20000], Loss: 0.5757, Training Accuracy: 0.7031
# Epoch [7660/20000], Loss: 0.5738, Training Accuracy: 0.6875
# Epoch [7670/20000], Loss: 0.5871, Training Accuracy: 0.6875
# Epoch [7680/20000], Loss: 0.5730, Training Accuracy: 0.7188
# Epoch [7690/20000], Loss: 0.5802, Training Accuracy: 0.6562
# Epoch [7700/20000], Loss: 0.5730, Training Accuracy: 0.7109
# Epoch [7710/20000], Loss: 0.5737, Training Accuracy: 0.6797
# Epoch [7720/20000], Loss: 0.5868, Training Accuracy: 0.7031
# Epoch [7730/20000], Loss: 0.5731, Training Accuracy: 0.6953
# Epoch [7740/20000], Loss: 0.5784, Training Accuracy: 0.6719
# Epoch [7750/20000], Loss: 0.5726, Training Accuracy: 0.6875
# Epoch [7760/20000], Loss: 0.5810, Training Accuracy: 0.7109
# Epoch [7770/20000], Loss: 0.5718, Training Accuracy: 0.6953
# Epoch [7780/20000], Loss: 0.5744, Training Accuracy: 0.6719
# Epoch [7790/20000], Loss: 0.5796, Training Accuracy: 0.6719
# Epoch [7800/20000], Loss: 0.5716, Training Accuracy: 0.6875
# Epoch [7810/20000], Loss: 0.5795, Training Accuracy: 0.7031
# Epoch [7820/20000], Loss: 0.5723, Training Accuracy: 0.6875
# Epoch [7830/20000], Loss: 0.5712, Training Accuracy: 0.6875
# Epoch [7840/20000], Loss: 0.5855, Training Accuracy: 0.7031
# Epoch [7850/20000], Loss: 0.5709, Training Accuracy: 0.7109
# Epoch [7860/20000], Loss: 0.5744, Training Accuracy: 0.6875
# Epoch [7870/20000], Loss: 0.5742, Training Accuracy: 0.6953
# Epoch [7880/20000], Loss: 0.5717, Training Accuracy: 0.6875
# Epoch [7890/20000], Loss: 0.5714, Training Accuracy: 0.7031
# Epoch [7900/20000], Loss: 0.5766, Training Accuracy: 0.6797
# Epoch [7910/20000], Loss: 0.5716, Training Accuracy: 0.7031
# Epoch [7920/20000], Loss: 0.5698, Training Accuracy: 0.6953
# Epoch [7930/20000], Loss: 0.5734, Training Accuracy: 0.7109
# Epoch [7940/20000], Loss: 0.5781, Training Accuracy: 0.6797
# Epoch [7950/20000], Loss: 0.5813, Training Accuracy: 0.6562
# Epoch [7960/20000], Loss: 0.5731, Training Accuracy: 0.7031
# Epoch [7970/20000], Loss: 0.5692, Training Accuracy: 0.7031
# Epoch [7980/20000], Loss: 0.5730, Training Accuracy: 0.6719
# Epoch [7990/20000], Loss: 0.5702, Training Accuracy: 0.7031
# Epoch [8000/20000], Loss: 0.5744, Training Accuracy: 0.6797
# Epoch [8010/20000], Loss: 0.5733, Training Accuracy: 0.6719
# ...
# Epoch [17390/20000], Loss: 0.4627, Training Accuracy: 0.7422
# Epoch [17400/20000], Loss: 0.4416, Training Accuracy: 0.8125
# Epoch [17410/20000], Loss: 0.4383, Training Accuracy: 0.7969
# Epoch [17420/20000], Loss: 0.4554, Training Accuracy: 0.7422
# Epoch [17430/20000], Loss: 0.4339, Training Accuracy: 0.8047
# Epoch [17440/20000], Loss: 0.4593, Training Accuracy: 0.7812
# Epoch [17450/20000], Loss: 0.4334, Training Accuracy: 0.7969
# Epoch [17460/20000], Loss: 0.4665, Training Accuracy: 0.7266
# Epoch [17470/20000], Loss: 0.4338, Training Accuracy: 0.7969
# Epoch [17480/20000], Loss: 0.4554, Training Accuracy: 0.7969
# Epoch [17490/20000], Loss: 0.4338, Training Accuracy: 0.7578
# Epoch [17500/20000], Loss: 0.4598, Training Accuracy: 0.7422
# Epoch [17510/20000], Loss: 0.4378, Training Accuracy: 0.8203
# Epoch [17520/20000], Loss: 0.4420, Training Accuracy: 0.7969
# Epoch [17530/20000], Loss: 0.4479, Training Accuracy: 0.7500
# Epoch [17540/20000], Loss: 0.4331, Training Accuracy: 0.7891
# Epoch [17550/20000], Loss: 0.4636, Training Accuracy: 0.7656
# Epoch [17560/20000], Loss: 0.4336, Training Accuracy: 0.7578
# Epoch [17570/20000], Loss: 0.4431, Training Accuracy: 0.7500
# Epoch [17580/20000], Loss: 0.4523, Training Accuracy: 0.7891
# Epoch [17590/20000], Loss: 0.4337, Training Accuracy: 0.7891
# Epoch [17600/20000], Loss: 0.4489, Training Accuracy: 0.7969
# Epoch [17610/20000], Loss: 0.4324, Training Accuracy: 0.7969
# Epoch [17620/20000], Loss: 0.4518, Training Accuracy: 0.7500
# Epoch [17630/20000], Loss: 0.4314, Training Accuracy: 0.7969
# Epoch [17640/20000], Loss: 0.4656, Training Accuracy: 0.7812
# Epoch [17650/20000], Loss: 0.4364, Training Accuracy: 0.7578
# Epoch [17660/20000], Loss: 0.4388, Training Accuracy: 0.7578
# Epoch [17670/20000], Loss: 0.4468, Training Accuracy: 0.8125
# Epoch [17680/20000], Loss: 0.4306, Training Accuracy: 0.7891
# Epoch [17690/20000], Loss: 0.4595, Training Accuracy: 0.7500
# Epoch [17700/20000], Loss: 0.4313, Training Accuracy: 0.7969
# Epoch [17710/20000], Loss: 0.4631, Training Accuracy: 0.7812
# Epoch [17720/20000], Loss: 0.4413, Training Accuracy: 0.7500
# Epoch [17730/20000], Loss: 0.4356, Training Accuracy: 0.7891
# Epoch [17740/20000], Loss: 0.4524, Training Accuracy: 0.7812
# Epoch [17750/20000], Loss: 0.4308, Training Accuracy: 0.7578
# Epoch [17760/20000], Loss: 0.4428, Training Accuracy: 0.7578
# Epoch [17770/20000], Loss: 0.4348, Training Accuracy: 0.8203
# Epoch [17780/20000], Loss: 0.4403, Training Accuracy: 0.8125
# Epoch [17790/20000], Loss: 0.4392, Training Accuracy: 0.7422
# Epoch [17800/20000], Loss: 0.4338, Training Accuracy: 0.7891
# Epoch [17810/20000], Loss: 0.4352, Training Accuracy: 0.8203
# Epoch [17820/20000], Loss: 0.4353, Training Accuracy: 0.7969
# Epoch [17830/20000], Loss: 0.4585, Training Accuracy: 0.7266
# Epoch [17840/20000], Loss: 0.4306, Training Accuracy: 0.8047
# Epoch [17850/20000], Loss: 0.4420, Training Accuracy: 0.8203
# Epoch [17860/20000], Loss: 0.4436, Training Accuracy: 0.7500
# Epoch [17870/20000], Loss: 0.4286, Training Accuracy: 0.7969
# Epoch [17880/20000], Loss: 0.4502, Training Accuracy: 0.8203
# Epoch [17890/20000], Loss: 0.4391, Training Accuracy: 0.7422
# Epoch [17900/20000], Loss: 0.4325, Training Accuracy: 0.7969
# Epoch [17910/20000], Loss: 0.4347, Training Accuracy: 0.8125
# Epoch [17920/20000], Loss: 0.4315, Training Accuracy: 0.7734
# Epoch [17930/20000], Loss: 0.4539, Training Accuracy: 0.7500
# Epoch [17940/20000], Loss: 0.4359, Training Accuracy: 0.8047
# Epoch [17950/20000], Loss: 0.4287, Training Accuracy: 0.7969
# Epoch [17960/20000], Loss: 0.4489, Training Accuracy: 0.7500
# Epoch [17970/20000], Loss: 0.4271, Training Accuracy: 0.7969
# Epoch [17980/20000], Loss: 0.4504, Training Accuracy: 0.7344
# Epoch [17990/20000], Loss: 0.4270, Training Accuracy: 0.7812
# Epoch [18000/20000], Loss: 0.4508, Training Accuracy: 0.8047
# Epoch [18010/20000], Loss: 0.4310, Training Accuracy: 0.7578
# Epoch [18020/20000], Loss: 0.4358, Training Accuracy: 0.7734
# Epoch [18030/20000], Loss: 0.4550, Training Accuracy: 0.7812
# Epoch [18040/20000], Loss: 0.4265, Training Accuracy: 0.7969
# Epoch [18050/20000], Loss: 0.4593, Training Accuracy: 0.7422
# Epoch [18060/20000], Loss: 0.4275, Training Accuracy: 0.7891
# Epoch [18070/20000], Loss: 0.4503, Training Accuracy: 0.7969
# Epoch [18080/20000], Loss: 0.4260, Training Accuracy: 0.7969
# Epoch [18090/20000], Loss: 0.4710, Training Accuracy: 0.7266
# Epoch [18100/20000], Loss: 0.4418, Training Accuracy: 0.7969
# Epoch [18110/20000], Loss: 0.4265, Training Accuracy: 0.7969
# Epoch [18120/20000], Loss: 0.4456, Training Accuracy: 0.7500
# Epoch [18130/20000], Loss: 0.4254, Training Accuracy: 0.7969
# Epoch [18140/20000], Loss: 0.4580, Training Accuracy: 0.7969
# Epoch [18150/20000], Loss: 0.4289, Training Accuracy: 0.7500
# Epoch [18160/20000], Loss: 0.4369, Training Accuracy: 0.7578
# Epoch [18170/20000], Loss: 0.4317, Training Accuracy: 0.8203
# Epoch [18180/20000], Loss: 0.4363, Training Accuracy: 0.8125
# Epoch [18190/20000], Loss: 0.4243, Training Accuracy: 0.7969
# Epoch [18200/20000], Loss: 0.4255, Training Accuracy: 0.7891
# Epoch [18210/20000], Loss: 0.4485, Training Accuracy: 0.8203
# Epoch [18220/20000], Loss: 0.4634, Training Accuracy: 0.7266
# Epoch [18230/20000], Loss: 0.4331, Training Accuracy: 0.8281
# Epoch [18240/20000], Loss: 0.4270, Training Accuracy: 0.7812
# Epoch [18250/20000], Loss: 0.4387, Training Accuracy: 0.7578
# Epoch [18260/20000], Loss: 0.4270, Training Accuracy: 0.7969
# Epoch [18270/20000], Loss: 0.4376, Training Accuracy: 0.8047
# Epoch [18280/20000], Loss: 0.4239, Training Accuracy: 0.7969
# Epoch [18290/20000], Loss: 0.4389, Training Accuracy: 0.7578
# Epoch [18300/20000], Loss: 0.4335, Training Accuracy: 0.8125
# Epoch [18310/20000], Loss: 0.4290, Training Accuracy: 0.7812
# Epoch [18320/20000], Loss: 0.4237, Training Accuracy: 0.7734
# Epoch [18330/20000], Loss: 0.4648, Training Accuracy: 0.7891
# Epoch [18340/20000], Loss: 0.4402, Training Accuracy: 0.7578
# Epoch [18350/20000], Loss: 0.4249, Training Accuracy: 0.8047
# Epoch [18360/20000], Loss: 0.4456, Training Accuracy: 0.7891
# Epoch [18370/20000], Loss: 0.4245, Training Accuracy: 0.7891
# Epoch [18380/20000], Loss: 0.4491, Training Accuracy: 0.7344
# Epoch [18390/20000], Loss: 0.4239, Training Accuracy: 0.8047
# Epoch [18400/20000], Loss: 0.4317, Training Accuracy: 0.7969
# Epoch [18410/20000], Loss: 0.4495, Training Accuracy: 0.7422
# Epoch [18420/20000], Loss: 0.4223, Training Accuracy: 0.7891
# Epoch [18430/20000], Loss: 0.4449, Training Accuracy: 0.8281
# Epoch [18440/20000], Loss: 0.4338, Training Accuracy: 0.7734
# Epoch [18450/20000], Loss: 0.4257, Training Accuracy: 0.7891
# Epoch [18460/20000], Loss: 0.4497, Training Accuracy: 0.7891
# Epoch [18470/20000], Loss: 0.4222, Training Accuracy: 0.7891
# Epoch [18480/20000], Loss: 0.4401, Training Accuracy: 0.7656
# Epoch [18490/20000], Loss: 0.4354, Training Accuracy: 0.7969
# Epoch [18500/20000], Loss: 0.4230, Training Accuracy: 0.7891
# Epoch [18510/20000], Loss: 0.4222, Training Accuracy: 0.7891
# Epoch [18520/20000], Loss: 0.4554, Training Accuracy: 0.7578
# Epoch [18530/20000], Loss: 0.4455, Training Accuracy: 0.7891
# Epoch [18540/20000], Loss: 0.4249, Training Accuracy: 0.7578
# Epoch [18550/20000], Loss: 0.4246, Training Accuracy: 0.8047
# Epoch [18560/20000], Loss: 0.4417, Training Accuracy: 0.8047
# Epoch [18570/20000], Loss: 0.4211, Training Accuracy: 0.7969
# Epoch [18580/20000], Loss: 0.4485, Training Accuracy: 0.7422
# Epoch [18590/20000], Loss: 0.4206, Training Accuracy: 0.7969
# Epoch [18600/20000], Loss: 0.4314, Training Accuracy: 0.8125
# Epoch [18610/20000], Loss: 0.4217, Training Accuracy: 0.7891
# Epoch [18620/20000], Loss: 0.4475, Training Accuracy: 0.7734
# Epoch [18630/20000], Loss: 0.4259, Training Accuracy: 0.8203
# Epoch [18640/20000], Loss: 0.4263, Training Accuracy: 0.7891
# Epoch [18650/20000], Loss: 0.4510, Training Accuracy: 0.7500
# Epoch [18660/20000], Loss: 0.4209, Training Accuracy: 0.7891
# Epoch [18670/20000], Loss: 0.4413, Training Accuracy: 0.8281
# Epoch [18680/20000], Loss: 0.4205, Training Accuracy: 0.7891
# Epoch [18690/20000], Loss: 0.4570, Training Accuracy: 0.7891
# Epoch [18700/20000], Loss: 0.4332, Training Accuracy: 0.7500
# Epoch [18710/20000], Loss: 0.4194, Training Accuracy: 0.7969
# Epoch [18720/20000], Loss: 0.4474, Training Accuracy: 0.8047
# Epoch [18730/20000], Loss: 0.4208, Training Accuracy: 0.7891
# Epoch [18740/20000], Loss: 0.4400, Training Accuracy: 0.7656
# Epoch [18750/20000], Loss: 0.4356, Training Accuracy: 0.8047
# Epoch [18760/20000], Loss: 0.4198, Training Accuracy: 0.7969
# Epoch [18770/20000], Loss: 0.4202, Training Accuracy: 0.7812
# Epoch [18780/20000], Loss: 0.4480, Training Accuracy: 0.8203
# Epoch [18790/20000], Loss: 0.4421, Training Accuracy: 0.7422
# Epoch [18800/20000], Loss: 0.4190, Training Accuracy: 0.7812
# Epoch [18810/20000], Loss: 0.4361, Training Accuracy: 0.8203
# Epoch [18820/20000], Loss: 0.4571, Training Accuracy: 0.7422
# Epoch [18830/20000], Loss: 0.4325, Training Accuracy: 0.8047
# Epoch [18840/20000], Loss: 0.4183, Training Accuracy: 0.7969
# Epoch [18850/20000], Loss: 0.4415, Training Accuracy: 0.7734
# Epoch [18860/20000], Loss: 0.4180, Training Accuracy: 0.7969
# Epoch [18870/20000], Loss: 0.4522, Training Accuracy: 0.7422
# Epoch [18880/20000], Loss: 0.4186, Training Accuracy: 0.7891
# Epoch [18890/20000], Loss: 0.4418, Training Accuracy: 0.8203
# Epoch [18900/20000], Loss: 0.4171, Training Accuracy: 0.7969
# Epoch [18910/20000], Loss: 0.4502, Training Accuracy: 0.7344
# Epoch [18920/20000], Loss: 0.4203, Training Accuracy: 0.8203
# Epoch [18930/20000], Loss: 0.4226, Training Accuracy: 0.7812
# Epoch [18940/20000], Loss: 0.4476, Training Accuracy: 0.7500
# Epoch [18950/20000], Loss: 0.4174, Training Accuracy: 0.7891
# Epoch [18960/20000], Loss: 0.4348, Training Accuracy: 0.8203
# Epoch [18970/20000], Loss: 0.4372, Training Accuracy: 0.7500
# Epoch [18980/20000], Loss: 0.4170, Training Accuracy: 0.7969
# Epoch [18990/20000], Loss: 0.4422, Training Accuracy: 0.7812
# Epoch [19000/20000], Loss: 0.4194, Training Accuracy: 0.7734
# Epoch [19010/20000], Loss: 0.4179, Training Accuracy: 0.7969
# Epoch [19020/20000], Loss: 0.4433, Training Accuracy: 0.8047
# Epoch [19030/20000], Loss: 0.4266, Training Accuracy: 0.7734
# Epoch [19040/20000], Loss: 0.4168, Training Accuracy: 0.7969
# Epoch [19050/20000], Loss: 0.4452, Training Accuracy: 0.8047
# Epoch [19060/20000], Loss: 0.4156, Training Accuracy: 0.7891
# Epoch [19070/20000], Loss: 0.4515, Training Accuracy: 0.7344
# Epoch [19080/20000], Loss: 0.4158, Training Accuracy: 0.7891
# Epoch [19090/20000], Loss: 0.4368, Training Accuracy: 0.8281
# Epoch [19100/20000], Loss: 0.4178, Training Accuracy: 0.7969
# Epoch [19110/20000], Loss: 0.4366, Training Accuracy: 0.7734
# Epoch [19120/20000], Loss: 0.4411, Training Accuracy: 0.7969
# Epoch [19130/20000], Loss: 0.4146, Training Accuracy: 0.7969
# Epoch [19140/20000], Loss: 0.4512, Training Accuracy: 0.7344
# Epoch [19150/20000], Loss: 0.4151, Training Accuracy: 0.7812
# Epoch [19160/20000], Loss: 0.4386, Training Accuracy: 0.8359
# Epoch [19170/20000], Loss: 0.4142, Training Accuracy: 0.8125
# Epoch [19180/20000], Loss: 0.4512, Training Accuracy: 0.7578
# Epoch [19190/20000], Loss: 0.4170, Training Accuracy: 0.8125
# Epoch [19200/20000], Loss: 0.4292, Training Accuracy: 0.8203
# Epoch [19210/20000], Loss: 0.4326, Training Accuracy: 0.7578
# Epoch [19220/20000], Loss: 0.4140, Training Accuracy: 0.7969
# Epoch [19230/20000], Loss: 0.4453, Training Accuracy: 0.7891
# Epoch [19240/20000], Loss: 0.4135, Training Accuracy: 0.8125
# Epoch [19250/20000], Loss: 0.4403, Training Accuracy: 0.7812
# Epoch [19260/20000], Loss: 0.4247, Training Accuracy: 0.8281
# Epoch [19270/20000], Loss: 0.4156, Training Accuracy: 0.7891
# Epoch [19280/20000], Loss: 0.4420, Training Accuracy: 0.7578
# Epoch [19290/20000], Loss: 0.4128, Training Accuracy: 0.7969
# Epoch [19300/20000], Loss: 0.4454, Training Accuracy: 0.7891
# Epoch [19310/20000], Loss: 0.4159, Training Accuracy: 0.7812
# Epoch [19320/20000], Loss: 0.4168, Training Accuracy: 0.8125
# Epoch [19330/20000], Loss: 0.4446, Training Accuracy: 0.7969
# Epoch [19340/20000], Loss: 0.4123, Training Accuracy: 0.7891
# Epoch [19350/20000], Loss: 0.4477, Training Accuracy: 0.7344
# Epoch [19360/20000], Loss: 0.4144, Training Accuracy: 0.8047
# Epoch [19370/20000], Loss: 0.4226, Training Accuracy: 0.8125
# Epoch [19380/20000], Loss: 0.4155, Training Accuracy: 0.8047
# Epoch [19390/20000], Loss: 0.4270, Training Accuracy: 0.7891
# Epoch [19400/20000], Loss: 0.4307, Training Accuracy: 0.8203
# Epoch [19410/20000], Loss: 0.4140, Training Accuracy: 0.7734
# Epoch [19420/20000], Loss: 0.4250, Training Accuracy: 0.7578
# Epoch [19430/20000], Loss: 0.4116, Training Accuracy: 0.7812
# Epoch [19440/20000], Loss: 0.4260, Training Accuracy: 0.8047
# Epoch [19450/20000], Loss: 0.4458, Training Accuracy: 0.7578
# Epoch [19460/20000], Loss: 0.4190, Training Accuracy: 0.8281
# Epoch [19470/20000], Loss: 0.4132, Training Accuracy: 0.7969
# Epoch [19480/20000], Loss: 0.4404, Training Accuracy: 0.7500
# Epoch [19490/20000], Loss: 0.4109, Training Accuracy: 0.7891
# Epoch [19500/20000], Loss: 0.4475, Training Accuracy: 0.7812
# Epoch [19510/20000], Loss: 0.4141, Training Accuracy: 0.7891
# Epoch [19520/20000], Loss: 0.4178, Training Accuracy: 0.8047
# Epoch [19530/20000], Loss: 0.4343, Training Accuracy: 0.7969
# Epoch [19540/20000], Loss: 0.4108, Training Accuracy: 0.7969
# Epoch [19550/20000], Loss: 0.4466, Training Accuracy: 0.7344
# Epoch [19560/20000], Loss: 0.4119, Training Accuracy: 0.7891
# Epoch [19570/20000], Loss: 0.4263, Training Accuracy: 0.8203
# Epoch [19580/20000], Loss: 0.4106, Training Accuracy: 0.8125
# Epoch [19590/20000], Loss: 0.4434, Training Accuracy: 0.7656
# Epoch [19600/20000], Loss: 0.4497, Training Accuracy: 0.7891
# Epoch [19610/20000], Loss: 0.4237, Training Accuracy: 0.7578
# Epoch [19620/20000], Loss: 0.4103, Training Accuracy: 0.7812
# Epoch [19630/20000], Loss: 0.4204, Training Accuracy: 0.7812
# Epoch [19640/20000], Loss: 0.4420, Training Accuracy: 0.7422
# Epoch [19650/20000], Loss: 0.4194, Training Accuracy: 0.8359
# Epoch [19660/20000], Loss: 0.4094, Training Accuracy: 0.7891
# Epoch [19670/20000], Loss: 0.4331, Training Accuracy: 0.7734
# Epoch [19680/20000], Loss: 0.4366, Training Accuracy: 0.7969
# Epoch [19690/20000], Loss: 0.4110, Training Accuracy: 0.7812
# Epoch [19700/20000], Loss: 0.4209, Training Accuracy: 0.7969
# Epoch [19710/20000], Loss: 0.4194, Training Accuracy: 0.8281
# Epoch [19720/20000], Loss: 0.4104, Training Accuracy: 0.7969
# Epoch [19730/20000], Loss: 0.4304, Training Accuracy: 0.7500
# Epoch [19740/20000], Loss: 0.4098, Training Accuracy: 0.7969
# Epoch [19750/20000], Loss: 0.4105, Training Accuracy: 0.8047
# Epoch [19760/20000], Loss: 0.4214, Training Accuracy: 0.7891
# Epoch [19770/20000], Loss: 0.4508, Training Accuracy: 0.7969
# Epoch [19780/20000], Loss: 0.4224, Training Accuracy: 0.7734
# Epoch [19790/20000], Loss: 0.4082, Training Accuracy: 0.7891
# Epoch [19800/20000], Loss: 0.4331, Training Accuracy: 0.8359
# Epoch [19810/20000], Loss: 0.4092, Training Accuracy: 0.7969
# Epoch [19820/20000], Loss: 0.4403, Training Accuracy: 0.7734
# Epoch [19830/20000], Loss: 0.4298, Training Accuracy: 0.7969
# Epoch [19840/20000], Loss: 0.4077, Training Accuracy: 0.7969
# Epoch [19850/20000], Loss: 0.4339, Training Accuracy: 0.7734
# Epoch [19860/20000], Loss: 0.4132, Training Accuracy: 0.8203
# Epoch [19870/20000], Loss: 0.4196, Training Accuracy: 0.8203
# Epoch [19880/20000], Loss: 0.4106, Training Accuracy: 0.7812
# Epoch [19890/20000], Loss: 0.4231, Training Accuracy: 0.8047
# Epoch [19900/20000], Loss: 0.4289, Training Accuracy: 0.8203
# Epoch [19910/20000], Loss: 0.4084, Training Accuracy: 0.7969
# Epoch [19920/20000], Loss: 0.4354, Training Accuracy: 0.7500
# Epoch [19930/20000], Loss: 0.4073, Training Accuracy: 0.7891
# Epoch [19940/20000], Loss: 0.4315, Training Accuracy: 0.8281
# Epoch [19950/20000], Loss: 0.4068, Training Accuracy: 0.7891
# Epoch [19960/20000], Loss: 0.4506, Training Accuracy: 0.7344
# Epoch [19970/20000], Loss: 0.4134, Training Accuracy: 0.8203
# Epoch [19980/20000], Loss: 0.4117, Training Accuracy: 0.7812
# Epoch [19990/20000], Loss: 0.4171, Training Accuracy: 0.7812
# Epoch [20000/20000], Loss: 0.4091, Training Accuracy: 0.7969

# %% [markdown]
# ## Uncomment next cell if you want to load a particular model you already trained.

# %%
# loaded_model = SimpleDenseNet(input_dim=len(list(features_to_extract.keys())), hidden_dim=512).to(device)
# loaded_model.load_state_dict(torch.load('llama-' + task + '-best-model'))

# # Set the model to evaluation mode"
# loaded_model.eval()

# %% [markdown]
# #Compute the metrics using the model on the Test Set.

# %%
# basically getting test performance:

X_test_tensor = torch.tensor(X_test_features, dtype=torch.float32).to(device)
Y_test_tensor = torch.tensor(Y_test, dtype=torch.float32).view(-1, 1).to(device)

test_metrics = compute_metrics(denseModel, X_test_tensor, Y_test_tensor)

print(
    f"Testing - Accuracy: {test_metrics['Accuracy']:.4f}, Precision: {test_metrics['Precision']:.4f}, Recall: {test_metrics['Recall']:.4f}, F1: {test_metrics['F1']:.4f}, ROC AUC: {test_metrics['ROC AUC']:.4f}, PR AUC: {test_metrics['PR AUC']:.4f}"
)
print(
    f"Testing - Negative: {test_metrics['Accuracy']:.4f}, Precision-Negative: {test_metrics['Precision-Negative']:.4f}, Recall-Negative: {test_metrics['Recall-Negative']:.4f}, F1-Negative: {test_metrics['F1-Negative']:.4f}, ROC AUC-Negative: {test_metrics['ROC AUC-Negative']:.4f}, PR AUC-Negative: {test_metrics['PR AUC-Negative']:.4f}"
)
# Out:
# Testing - Accuracy: 0.5625, Precision: 0.5714, Recall: 0.5000, F1: 0.5333, ROC AUC: 0.5781, PR AUC: 0.6607
# Testing - Negative: 0.5625, Precision-Negative: 0.5556, Recall-Negative: 0.6250, F1-Negative: 0.5882, ROC AUC-Negative: 0.4219, PR AUC-Negative: 0.5580

# %% [markdown]
# ## Save the results on a CSV if you want.

# %%
model_dataframe = pd.DataFrame(
    columns=[
        "features",
        "model_name",
        "feature_to_extract",
        "method",
        "accuracy",
        "precision",
        "recall",
        "roc auc",
        "pr auc",
        "negative",
        "precision-negative",
        "recall-negative",
        "negative f1",
        "lr_accuracy",
        "lr_features_log",
        "lr_features_no_log",
    ]
)

# %%
d = {
    "features": features_to_extract,
    "model_name": str(model.getName()),
    "feature_to_extract": feature_to_extract,
    "method": "TEST",
    "accuracy": test_metrics["Accuracy"],
    "precision": test_metrics["Precision"],
    "recall": test_metrics["Recall"],
    "f1": test_metrics["F1"],
    "pr auc": test_metrics["PR AUC"],
    "precision-negative": test_metrics["Precision-Negative"],
    "recall-negative": test_metrics["Recall-Negative"],
    "negative-f1": test_metrics["F1-Negative"],
    "lr_accuracy": lr_accuracy,
    "lr_features_log": lr_features_log,
    "lr_features_no_log": lr_features_no_log,
}

model_dataframe.loc[len(model_dataframe.index)] = d

# %%
model_dataframe.head()
# Out:
#                                             features  model_name  \
# 0  {'mtp': True, 'avgtp': True, 'MDVTP': True, 'M...  gpt2-large
#
#   feature_to_extract method  accuracy  precision  recall  roc auc    pr auc  \
# 0                all   TEST    0.5625   0.571429     0.5      NaN  0.660714
#
#    negative  precision-negative  recall-negative  negative f1  lr_accuracy  \
# 0       NaN            0.555556            0.625          NaN          0.5
#
#                                      lr_features_log  \
# 0  {'mtp': -1.0435336213256333e-06, 'avgtp': 0.07...
#
#                                   lr_features_no_log
# 0  {'mtp': 0.9999989564669232, 'avgtp': 1.0752087...

# %%
csv_name = f"{model.getSanitizedName()}_{task}_{includeKnowledge=}_{includeConditioned=}_{'_'.join([f'{k}={v}' for k, v in features_to_extract.items()])}.csv"
model_dataframe.to_csv(output_path / csv_name, index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_12615/524906203.py in <cell line: 0>()
#       1 csv_name = f"{model.getSanitizedName()}_{task}_{includeKnowledge=}_{includeConditioned=}_{'_'.join([f'{k}={v}' for k, v in features_to_extract.items()])}.csv"
# ----> 2 model_dataframe.to_csv(output_path / csv_name, index=False)
#
# NameError: name 'output_path' is not defined
